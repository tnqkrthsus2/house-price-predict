# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final3_english.csv',encoding='cp949')

# %%
df
# Out:
#        apart_code  YYYYMM            apart__name        sigungu town_name  \
# 0       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 1       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 2       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 3       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 4       A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동       종암동
# ...           ...     ...                    ...            ...       ...
# 725063  A15776004  202207                    현대3  서울특별시 강서구 염창동       염창동
# 725064  A15807701  202207                  세양청마루  서울특별시 양천구 신정동       신정동
# 725065  A15882107  202207                    금호1   서울특별시 양천구 목동        목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동       진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동       진관동
#
#                        address sale_type  area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양   101.81      1        1978  ...
# 1            서울특별시 서초구 효령로 391     임대+분양   101.10     11        1978  ...
# 2            서울특별시 서초구 효령로 391     임대+분양    77.71      6        1978  ...
# 3            서울특별시 서초구 효령로 391     임대+분양   101.10      3        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대    84.73      5        2005  ...
# ...                        ...       ...      ...    ...         ...  ...
# 725063     서울특별시 강서구 양천로75길 60        분양    59.92      1        1996  ...
# 725064  서울특별시 양천구 목동남로2길 60-30        분양    84.98      9        2006  ...
# 725065      서울특별시 양천구 목동동로 258        분양    84.96     22        1997  ...
# 725066     서울특별시 은평구 진관2로 57-7        분양    84.54      8        2009  ...
# 725067     서울특별시 은평구 연서로48길 12        분양   101.83      5        2010  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 1       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 2       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 3       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 725063       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725064       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725065       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725066       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725067       NaN       NaN       NaN  108.740           NaN  2,451.50
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 1       1757058.7       106.0  1890.0   81200
# 2       1757058.7       106.0  1890.0   64000
# 3       1757058.7       106.0  1890.0   78800
# 4       1757058.7       106.0  1890.0   46000
# ...           ...         ...     ...     ...
# 725063        NaN         NaN     NaN   64600
# 725064        NaN         NaN     NaN   95000
# 725065        NaN         NaN     NaN  115000
# 725066        NaN         NaN     NaN   93000
# 725067        NaN         NaN     NaN  103000
#
# [725068 rows x 37 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df_vary = df.drop_duplicates(['apart_code'])

# %%
df_vary
# Out:
#        apart_code  YYYYMM apart__name         sigungu town_name  \
# 0       A10024240  201201         무지개   서울특별시 서초구 서초동       서초동
# 4       A10024603  201201   아이파크종암동2차   서울특별시 성북구 종암동       종암동
# 7       A10024621  201201          태흥   서울특별시 관악구 신림동       신림동
# 8       A10024636  201201       세양청마루   서울특별시 노원구 월계동       월계동
# 9       A10024638  201201    관악월드메르디앙   서울특별시 관악구 봉천동       봉천동
# ...           ...     ...         ...             ...       ...
# 721832  A10025013  202204  사당롯데캐슬골든포레   서울특별시 동작구 사당동       사당동
# 723079  A10024098  202205  보라매자이더포레스트  서울특별시 동작구 신대방동      신대방동
# 724205  A10023926  202206    롯데캐슬클라시아   서울특별시 성북구 길음동       길음동
# 724206  A10023959  202206  홍제역해링턴플레이스  서울특별시 서대문구 홍제동       홍제동
# 724210  A10024408  202206    공덕SK리더스뷰   서울특별시 마포구 공덕동       공덕동
#
#                        address sale_type   area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양  101.8100      1        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대   84.7300      5        2005  ...
# 7            서울특별시 관악구 호암로 541        분양   59.8600     18        1995  ...
# 8          서울특별시 노원구 석계로13길 35        분양   64.1830      8        2005  ...
# 9          서울특별시 관악구 관악로28길 80        분양   79.2700      6        2005  ...
# ...                        ...       ...       ...    ...         ...  ...
# 721832        서울특별시 동작구 사당로 90        분양   59.9775      7        2021  ...
# 723079  서울특별시 동작구 여의대방로22길 121     임대+분양   59.9365     15        2021  ...
# 724205      서울특별시 성북구 숭인로8길 80     임대+분양   59.8745     15        2022  ...
# 724206     서울특별시 서대문구 세무서8길 30     임대+분양   59.9900     10        2021  ...
# 724210      서울특별시 마포구 백범로31길 7     임대+분양   84.9300     12        2021  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 7       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 8       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 9       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 721832  492124.3  464761.5       0.0  106.850          3.57  2,695.05
# 723079  492124.3  464761.5       0.0  107.560          3.68  2,685.90
# 724205  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724206  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724210  492124.3  464761.5       0.0  108.220          3.90  2,332.64
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 4       1757058.7       106.0  1890.0   46000
# 7       1757058.7       106.0  1890.0   23100
# 8       1757058.7       106.0  1890.0   25700
# 9       1757058.7       106.0  1890.0   35000
# ...           ...         ...     ...     ...
# 721832  3675828.7       110.8   360.0  110000
# 723079  3694489.3       105.2   688.0  115000
# 724205  3714442.7        99.8   719.0  110800
# 724206  3714442.7        99.8   719.0  116000
# 724210  3714442.7        99.8   719.0  190000
#
# [2385 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# apart_code          0
# YYYYMM              0
# apart__name         0
# sigungu             0
# town_name           0
# address             0
# sale_type        2628
# area_m3             0
# floor               0
# const_year          0
# parking          1926
# GPS_X               0
# GPS_Y               0
# crime_rate          0
# building_year       0
# market_dist         0
# busstop_dist        0
# subway_dist         0
# school_dist         0
# kinder_dist         0
# hospital_dist       0
# ASPI                0
# YYYY                0
# MM                  0
# HAI              3269
# PIR              4222
# LIR              4222
# GDP               228
# GDI               228
# GNI               228
# CPI                 0
# avg_interest      228
# cospi               0
# M2                228
# house_CCSI        228
# unsold            228
# prices              0
# dtype: int64

# %%
df = df[df['sale_type'].notna()]
df = df[df['parking'].notna()]
df = df[df['HAI'].notna()]
df = df[df['M2'].notna()]

# %% [markdown]
# 주변의 아파트 구하기

# %%
df_range = df_vary[['apart_code','GPS_X','GPS_Y']]

# %% [markdown]
# A10024240 단지를 중심으로(다음 행 아파트 코드 하나만 수정할시 전체 값 변화)

# %%
gizun_code = 'A41279924'
gizun = df_range[df_range['apart_code']==gizun_code]

# %%
from haversine import haversine

# %% [markdown]
# 주변 거리 2km 이내로 변경

# %%
start = (float(gizun['GPS_Y']),float(gizun['GPS_X']))
near_apts = []
for i in df_range.index:
    goal = (float(df_range['GPS_Y'][i]),float(df_range['GPS_X'][i]))
    if haversine(start, goal) < 2:
        near_apts.append(df_range['apart_code'][i])
near_df = pd.DataFrame()
near_df['apart_code'] = near_apts

# %%
near_df
# Out:
#    apart_code
# 0   A12204002
# 1   A41279902
# 2   A41279910
# 3   A41279918
# 4   A41279920
# 5   A41279923
# 6   A41279924
# 7   A41279927
# 8   A12220004
# 9   A41279901
# 10  A41279904
# 11  A41279907
# 12  A41279908
# 13  A41279909
# 14  A41279922
# 15  A41279925
# 16  A41279926
# 17  A41279929
# 18  A12220005
# 19  A41279903
# 20  A41279911
# 21  A41279912
# 22  A41279913
# 23  A41279915
# 24  A12220001
# 25  A41279905
# 26  A41279914
# 27  A12204001
# 28  A12220003
# 29  A41279906
# 30  A41279916
# 31  A12220002
# 32  A41279917
# 33  A41279932
# 34  A10026414
# 35  A10025765

# %% [markdown]
# near_df 데이터에서 세대수 찾기

# %%
many_df = pd.read_csv('서울시아파트(기준).csv',encoding='cp949')

# %%
near_df = pd.merge(near_df,many_df,left_on='apart_code',right_on='k-아파트코드',how='left')

# %%
near_df
# Out:
#    apart_code     번호    k-아파트코드  k-전체세대수       k-건설사(시공사)
# 0   A12204002    502  A12204002    256.0             대창건설
# 1   A41279902   1808  A41279902    318.0           대우푸르지오
# 2   A41279910   1935  A41279910    947.0               현대
# 3   A41279918   2005  A41279918    472.0             두산건설
# 4   A41279920   2033  A41279920    486.0             삼성건설
# 5   A41279923   2067  A41279923    330.0  (주)대우건설 (주)태영건설
# 6   A41279924   2068  A41279924    571.0          현대건설(주)
# 7   A41279927   2103  A41279927    334.0         벽산건설금호건설
# 8   A12220004   1149  A12220004    551.0          (주)롯데건설
# 9   A41279901   1798  A41279901    300.0           현대산업개발
# 10  A41279904   1817  A41279904    379.0           대우푸르지오
# 11  A41279907   1832  A41279907    187.0           현대산업개발
# 12  A41279908   1856  A41279908    255.0       현대산업개발주식회사
# 13  A41279909   1934  A41279909    162.0             현대건설
# 14  A41279922   2063  A41279922    175.0          대우건설(주)
# 15  A41279925   2074  A41279925    189.0          대우푸르지오
# 16  A41279926   2077  A41279926    126.0             현대건설
# 17  A41279929   2118  A41279929    412.0             대우건설
# 18  A12220005   1320  A12220005    707.0             삼환기업
# 19  A41279903   1811  A41279903    378.0           대우푸르지오
# 20  A41279911   2284  A41279911    660.0             현대건설
# 21  A41279912   1995  A41279912    659.0            포스코건설
# 22  A41279913   1996  A41279913    469.0          동부건걸(주)
# 23  A41279915   2002  A41279915    448.0             금호건설
# 24  A12220001    316  A12220001    208.0           대우푸르지오
# 25  A41279905   1825  A41279905    241.0           현대산업개발
# 26  A41279914   1999  A41279914    434.0             동부건설
# 27  A12204001     37  A12204001    155.0               한양
# 28  A12220003    719  A12220003    335.0          롯데건설(주)
# 29  A41279906   1831  A41279906    230.0           현대산업개발
# 30  A41279916   2003  A41279916    387.0       두산건설포스코 건설
# 31  A12220002    651  A12220002    298.0             SH공사
# 32  A41279917   2004  A41279917    353.0               SH
# 33  A41279932   6381  A41279932    426.0               한라
# 34  A10026414  19260  A10026414    260.0          (주)삼전건설
# 35  A10025765  20822  A10025765    361.0            GS 건설

# %%
near_df = near_df[['apart_code','k-전체세대수']]

# %% [markdown]
# 더 적은 세대수 아파트 삭제

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 0   A12204002    256.0
# 1   A41279902    318.0
# 2   A41279910    947.0
# 3   A41279918    472.0
# 4   A41279920    486.0
# 5   A41279923    330.0
# 6   A41279924    571.0
# 7   A41279927    334.0
# 8   A12220004    551.0
# 9   A41279901    300.0
# 10  A41279904    379.0
# 11  A41279907    187.0
# 12  A41279908    255.0
# 13  A41279909    162.0
# 14  A41279922    175.0
# 15  A41279925    189.0
# 16  A41279926    126.0
# 17  A41279929    412.0
# 18  A12220005    707.0
# 19  A41279903    378.0
# 20  A41279911    660.0
# 21  A41279912    659.0
# 22  A41279913    469.0
# 23  A41279915    448.0
# 24  A12220001    208.0
# 25  A41279905    241.0
# 26  A41279914    434.0
# 27  A12204001    155.0
# 28  A12220003    335.0
# 29  A41279906    230.0
# 30  A41279916    387.0
# 31  A12220002    298.0
# 32  A41279917    353.0
# 33  A41279932    426.0
# 34  A10026414    260.0
# 35  A10025765    361.0

# %%
gizun_count = near_df[near_df['apart_code']==gizun_code].iloc[0][1]
gizun_count
# Out:
# 571.0

# %%
indexNames = near_df[near_df['k-전체세대수'] < gizun_count].index
near_df.drop(indexNames , inplace=True)
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 2   A41279910    947.0
# 6   A41279924    571.0
# 18  A12220005    707.0
# 20  A41279911    660.0
# 21  A41279912    659.0

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df = df.astype({'prices':'float64'})

# %%
df['area_m3']=df['area_m3'].round(-1)

# %%
df['prices']=df.groupby(['YYYYMM','apart_code','area_m3'])['prices'].transform('mean')

# %% [markdown]
# 근처에 있는 아파트의 데이터 프레임 생성

# %%
df = pd.merge(near_df,df,on='apart_code')

# %%
df = df.rename(columns={'k-전체세대수':'resident_count'})
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices'],
#       dtype='object')

# %%
df['apart_code_area'] = df['apart_code'].map(str) +'_' +df['area_m3'].map(int).map(str)

# %%
df
# Out:
#      apart_code  resident_count  YYYYMM          apart__name        sigungu  \
# 0     A41279910           947.0  201201  은평뉴타운박석고개(힐스테이트1단지)  서울특별시 은평구 진관동
# 1     A41279910           947.0  201201  은평뉴타운박석고개(힐스테이트1단지)  서울특별시 은평구 진관동
# 2     A41279910           947.0  201201  은평뉴타운박석고개(힐스테이트1단지)  서울특별시 은평구 진관동
# 3     A41279910           947.0  201202  은평뉴타운박석고개(힐스테이트1단지)  서울특별시 은평구 진관동
# 4     A41279910           947.0  201203  은평뉴타운박석고개(힐스테이트1단지)  서울특별시 은평구 진관동
# ...         ...             ...     ...                  ...            ...
# 1140  A41279912           659.0  202107    은평뉴타운마고정(센트레빌3단지)  서울특별시 은평구 진관동
# 1141  A41279912           659.0  202107    은평뉴타운마고정(센트레빌3단지)  서울특별시 은평구 진관동
# 1142  A41279912           659.0  202107    은평뉴타운마고정(센트레빌3단지)  서울특별시 은평구 진관동
# 1143  A41279912           659.0  202108    은평뉴타운마고정(센트레빌3단지)  서울특별시 은평구 진관동
# 1144  A41279912           659.0  202109    은평뉴타운마고정(센트레빌3단지)  서울특별시 은평구 진관동
#
#      town_name               address sale_type  area_m3  floor  ...       GDI  \
# 0          진관동  서울특별시 은평구 진관1로 21-10     임대+분양     60.0      3  ...  343229.4
# 1          진관동  서울특별시 은평구 진관1로 21-10     임대+분양     60.0      5  ...  343229.4
# 2          진관동  서울특별시 은평구 진관1로 21-10     임대+분양     60.0      6  ...  343229.4
# 3          진관동  서울특별시 은평구 진관1로 21-10     임대+분양     60.0      8  ...  343229.4
# 4          진관동  서울특별시 은평구 진관1로 21-10     임대+분양     60.0      5  ...  343229.4
# ...        ...                   ...       ...      ...    ...  ...       ...
# 1140       진관동     서울특별시 은평구 진관2로 90     임대+분양     80.0      5  ...  466346.0
# 1141       진관동     서울특별시 은평구 진관2로 90     임대+분양    130.0      8  ...  466346.0
# 1142       진관동     서울특별시 은평구 진관2로 90     임대+분양     80.0      2  ...  466346.0
# 1143       진관동     서울특별시 은평구 진관2로 90     임대+분양     80.0      4  ...  466346.0
# 1144       진관동     서울특별시 은평구 진관2로 90     임대+분양     80.0      4  ...  466346.0
#
#            GNI      CPI  avg_interest     cospi         M2  house_CCSI  \
# 0     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 1     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 2     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 3     345819.5   91.588          5.71  2,030.25  1762988.4       111.3
# 4     345819.5   91.614          5.74  2,014.04  1773172.9       107.1
# ...        ...      ...           ...       ...        ...         ...
# 1140  471235.4  102.260          2.77  3,202.32  3445243.0       133.3
# 1141  471235.4  102.260          2.77  3,202.32  3445243.0       133.3
# 1142  471235.4  102.260          2.77  3,202.32  3445243.0       133.3
# 1143  471235.4  102.750          2.87  3,199.27  3487634.1       135.1
# 1144  471235.4  103.170          2.96  3,068.82  3513680.6       131.8
#
#       unsold         prices  apart_code_area
# 0     1890.0   39566.666667     A41279910_60
# 1     1890.0   39566.666667     A41279910_60
# 2     1890.0   39566.666667     A41279910_60
# 3     1703.0   39700.000000     A41279910_60
# 4     1732.0   37000.000000     A41279910_60
# ...      ...            ...              ...
# 1140    59.0  103000.000000     A41279912_80
# 1141    59.0  140000.000000    A41279912_130
# 1142    59.0  103000.000000     A41279912_80
# 1143    55.0   92500.000000     A41279912_80
# 1144    55.0   97700.000000     A41279912_80
#
# [1145 rows x 39 columns]

# %%
df = df.drop_duplicates(subset=['apart_code_area','YYYYMM'])

# %%
df = df.sort_values(by=["apart_code_area", "YYYYMM"], ascending=[True, True])

# %%
df
# Out:
#     apart_code  resident_count  YYYYMM         apart__name        sigungu  \
# 595  A12220005           707.0  201207  은평뉴타운상림마을(롯데캐슬A-1)  서울특별시 은평구 진관동
# 602  A12220005           707.0  201305  은평뉴타운상림마을(롯데캐슬A-1)  서울특별시 은평구 진관동
# 607  A12220005           707.0  201310  은평뉴타운상림마을(롯데캐슬A-1)  서울특별시 은평구 진관동
# 613  A12220005           707.0  201406  은평뉴타운상림마을(롯데캐슬A-1)  서울특별시 은평구 진관동
# 620  A12220005           707.0  201410  은평뉴타운상림마을(롯데캐슬A-1)  서울특별시 은평구 진관동
# ..         ...             ...     ...                 ...            ...
# 578  A41279924           571.0  201907  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 579  A41279924           571.0  202008  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 582  A41279924           571.0  202101  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 585  A41279924           571.0  202102  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 586  A41279924           571.0  202103  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
#
#     town_name             address sale_type  area_m3  floor  ...       GDI  \
# 595       진관동   서울특별시 은평구 진관4로 17     임대+분양    100.0      1  ...  361011.4
# 602       진관동   서울특별시 은평구 진관4로 17     임대+분양    100.0      6  ...  373324.7
# 607       진관동   서울특별시 은평구 진관4로 17     임대+분양    100.0      2  ...  398164.5
# 613       진관동   서울특별시 은평구 진관4로 17     임대+분양    100.0      3  ...  387259.3
# 620       진관동   서울특별시 은평구 진관4로 17     임대+분양    100.0      3  ...  412302.4
# ..        ...                 ...       ...      ...    ...  ...       ...
# 578       진관동  서울특별시 은평구 연서로44길 7        분양    170.0      4  ...  450519.4
# 579       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     16  ...  454712.9
# 582       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     11  ...  450518.8
# 585       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     10  ...  450518.8
# 586       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     11  ...  450518.8
#
#           GNI      CPI  avg_interest     cospi         M2  house_CCSI  unsold  \
# 595  364909.7   91.432          5.45  1,881.99  1807289.2        97.8  3146.0
# 602  375206.0   92.823          4.62  2,001.05  1870289.7       115.8  2908.0
# 607  401514.4   93.134          4.46  2,030.09  1908557.6       130.1  3808.0
# 613  388676.8   94.248          4.40  2,002.21  1999376.3       110.4  2601.0
# 620  416210.3   94.205          4.00  1,964.43  2051149.8       132.2  1724.0
# ..        ...      ...           ...       ...        ...         ...     ...
# 578  458809.4   99.187          3.40  2,024.55  2811543.7       109.4   190.0
# 579  458855.5  100.190          2.63  2,326.17  3100373.4       127.7    56.0
# 582  457211.8  101.040          2.72  2,976.21  3223486.7       131.5    49.0
# 585  457211.8  101.580          2.74  3,012.95  3271405.8       129.5    88.0
# 586  457211.8  101.840          2.77  3,061.42  3313182.2       123.5    82.0
#
#        prices  apart_code_area
# 595   40000.0    A12220005_100
# 602   52350.0    A12220005_100
# 607   47600.0    A12220005_100
# 613   52800.0    A12220005_100
# 620   52850.0    A12220005_100
# ..        ...              ...
# 578  101500.0    A41279924_170
# 579  130000.0    A41279924_170
# 582  140000.0    A41279924_170
# 585  144500.0    A41279924_170
# 586  150000.0    A41279924_170
#
# [600 rows x 39 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices', 'apart_code_area'],
#       dtype='object')

# %%
df = df[['apart_code_area','resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
       'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
       'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
       'house_CCSI', 'unsold', 'prices']]

# %% [markdown]
# 분양타입 변경

# %%
df['sale_type']
# Out:
# 595    임대+분양
# 602    임대+분양
# 607    임대+분양
# 613    임대+분양
# 620    임대+분양
#        ...
# 578       분양
# 579       분양
# 582       분양
# 585       분양
# 586       분양
# Name: sale_type, Length: 600, dtype: object

# %%
df.loc[df['sale_type'] == '분양', 'sale_type'] = 0
df.loc[df['sale_type'] == '임대+분양', 'sale_type'] = 1
df.loc[df['sale_type'] == '임대', 'sale_type'] = 2
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df
# Out:
#     apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 595   A12220005_100           707.0         1  201207    100.0      1
# 602   A12220005_100           707.0         1  201305    100.0      6
# 607   A12220005_100           707.0         1  201310    100.0      2
# 613   A12220005_100           707.0         1  201406    100.0      3
# 620   A12220005_100           707.0         1  201410    100.0      3
# ..              ...             ...       ...     ...      ...    ...
# 578   A41279924_170           571.0         0  201907    170.0      4
# 579   A41279924_170           571.0         0  202008    170.0     16
# 582   A41279924_170           571.0         0  202101    170.0     11
# 585   A41279924_170           571.0         0  202102    170.0     10
# 586   A41279924_170           571.0         0  202103    170.0     11
#
#      parking  crime_rate  building_year  market_dist  ...       GDP       GDI  \
# 595    883.0    0.710015              5     0.835298  ...  376867.9  361011.4
# 602    883.0    0.710015              5     0.835298  ...  390130.2  373324.7
# 607    883.0    0.710015              5     0.835298  ...  412498.2  398164.5
# 613    883.0    0.710015              5     0.835298  ...  403578.9  387259.3
# 620    883.0    0.710015              5     0.835298  ...  423220.2  412302.4
# ..       ...         ...            ...          ...  ...       ...       ...
# 578   1119.0    0.710015              9     1.771677  ...  463965.5  450519.4
# 579   1119.0    0.710015              9     1.771677  ...  459981.3  454712.9
# 582   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
# 585   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
# 586   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
#
#           GNI      CPI  avg_interest     cospi         M2  house_CCSI  unsold  \
# 595  364909.7   91.432          5.45  1,881.99  1807289.2        97.8  3146.0
# 602  375206.0   92.823          4.62  2,001.05  1870289.7       115.8  2908.0
# 607  401514.4   93.134          4.46  2,030.09  1908557.6       130.1  3808.0
# 613  388676.8   94.248          4.40  2,002.21  1999376.3       110.4  2601.0
# 620  416210.3   94.205          4.00  1,964.43  2051149.8       132.2  1724.0
# ..        ...      ...           ...       ...        ...         ...     ...
# 578  458809.4   99.187          3.40  2,024.55  2811543.7       109.4   190.0
# 579  458855.5  100.190          2.63  2,326.17  3100373.4       127.7    56.0
# 582  457211.8  101.040          2.72  2,976.21  3223486.7       131.5    49.0
# 585  457211.8  101.580          2.74  3,012.95  3271405.8       129.5    88.0
# 586  457211.8  101.840          2.77  3,061.42  3313182.2       123.5    82.0
#
#        prices
# 595   40000.0
# 602   52350.0
# 607   47600.0
# 613   52800.0
# 620   52850.0
# ..        ...
# 578  101500.0
# 579  130000.0
# 582  140000.0
# 585  144500.0
# 586  150000.0
#
# [600 rows x 31 columns]

# %% [markdown]
# df를 csv파일로 내보낸다

# %%
#df.to_csv('반경3km위주의 상관관계확인.csv')

# %%
#코스피 행 변환
for i in df.index:
    if type(df['cospi'][i]) == str:
        df['cospi'][i] = df['cospi'][i].replace(',','')
    else: 
        df['cospi'][i] = df['cospi'][i]
df
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#     apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 595   A12220005_100           707.0         1  201207    100.0      1
# 602   A12220005_100           707.0         1  201305    100.0      6
# 607   A12220005_100           707.0         1  201310    100.0      2
# 613   A12220005_100           707.0         1  201406    100.0      3
# 620   A12220005_100           707.0         1  201410    100.0      3
# ..              ...             ...       ...     ...      ...    ...
# 578   A41279924_170           571.0         0  201907    170.0      4
# 579   A41279924_170           571.0         0  202008    170.0     16
# 582   A41279924_170           571.0         0  202101    170.0     11
# 585   A41279924_170           571.0         0  202102    170.0     10
# 586   A41279924_170           571.0         0  202103    170.0     11
#
#      parking  crime_rate  building_year  market_dist  ...       GDP       GDI  \
# 595    883.0    0.710015              5     0.835298  ...  376867.9  361011.4
# 602    883.0    0.710015              5     0.835298  ...  390130.2  373324.7
# 607    883.0    0.710015              5     0.835298  ...  412498.2  398164.5
# 613    883.0    0.710015              5     0.835298  ...  403578.9  387259.3
# 620    883.0    0.710015              5     0.835298  ...  423220.2  412302.4
# ..       ...         ...            ...          ...  ...       ...       ...
# 578   1119.0    0.710015              9     1.771677  ...  463965.5  450519.4
# 579   1119.0    0.710015              9     1.771677  ...  459981.3  454712.9
# 582   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
# 585   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
# 586   1119.0    0.710015              9     1.771677  ...  453751.7  450518.8
#
#           GNI      CPI  avg_interest    cospi         M2  house_CCSI  unsold  \
# 595  364909.7   91.432          5.45  1881.99  1807289.2        97.8  3146.0
# 602  375206.0   92.823          4.62  2001.05  1870289.7       115.8  2908.0
# 607  401514.4   93.134          4.46  2030.09  1908557.6       130.1  3808.0
# 613  388676.8   94.248          4.40  2002.21  1999376.3       110.4  2601.0
# 620  416210.3   94.205          4.00  1964.43  2051149.8       132.2  1724.0
# ..        ...      ...           ...      ...        ...         ...     ...
# 578  458809.4   99.187          3.40  2024.55  2811543.7       109.4   190.0
# 579  458855.5  100.190          2.63  2326.17  3100373.4       127.7    56.0
# 582  457211.8  101.040          2.72  2976.21  3223486.7       131.5    49.0
# 585  457211.8  101.580          2.74  3012.95  3271405.8       129.5    88.0
# 586  457211.8  101.840          2.77  3061.42  3313182.2       123.5    82.0
#
#        prices
# 595   40000.0
# 602   52350.0
# 607   47600.0
# 613   52800.0
# 620   52850.0
# ..        ...
# 578  101500.0
# 579  130000.0
# 582  140000.0
# 585  144500.0
# 586  150000.0
#
# [600 rows x 31 columns]

# %%
codes = df['apart_code_area'].unique()
groups = df.groupby(df.apart_code_area)
for i in codes:
    globals()['df_'+i] = groups.get_group(i)

# %%
codes
# Out:
# array(['A12220005_100', 'A12220005_130', 'A12220005_80', 'A41279910_100',
#        'A41279910_130', 'A41279910_60', 'A41279910_80', 'A41279911_130',
#        'A41279911_60', 'A41279911_80', 'A41279912_100', 'A41279912_130',
#        'A41279912_170', 'A41279912_60', 'A41279912_80', 'A41279924_100',
#        'A41279924_130', 'A41279924_170'], dtype=object)

# %% [markdown]
# df_A10024240_100를 테스트 데이터로 선택

# %%
gizun_code_area = df[df['apart_code_area'].str.contains(gizun_code)]['apart_code_area'].iloc[0]
gizun_df = globals()['df_'+gizun_code_area]

# %%
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow import keras
import numpy as np
from numpy import concatenate
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
  n_vars = 1 if type(data) is list else data.shape[1]
  df = pd.DataFrame(data)
  cols, names = list(), list()
  # input sequence (t-n, ... t-1)
  for i in range(n_in, 0, -1):
      cols.append(df.shift(i))
      names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
  # forecast sequence (t, t+1, ... t+n)
  for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
          names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
          names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
  # put it all together
  agg = pd.concat(cols, axis=1)
  agg.columns = names
  # drop rows with NaN values
  if dropnan:
      agg.dropna(inplace=True)
  return agg

# %% [markdown]
# 행 변환하기

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df_all = pd.DataFrame()
#코드에서 해당 아파트 제거
deleted_code = 'df_'+gizun_code_area
codes = np.delete(codes, np.where(codes == deleted_code))
for i in codes:
    df1 = globals()['df_'+i]
    df1 = df1[['resident_count','sale_type',
    'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
    'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
    'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
    'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
    'house_CCSI', 'unsold', 'sale_type','prices']]
    values = df1.values
    values = values.astype('float32')
    reframed = series_to_supervised(values, 3, 1)
    reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
    reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
    reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
    df_all = pd.concat([reframed,df_all])

# %%
df_all
# Out:
#       var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3   78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4   81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5   74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6   73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7   67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..           ...            ...            ...      ...      ...       ...
# 17  72250.000000   78000.000000   77500.000000    707.0      1.0  202010.0
# 18  78000.000000   77500.000000   97500.000000    707.0      1.0  202011.0
# 19  77500.000000   97500.000000   97000.000000    707.0      1.0  202012.0
# 20  97500.000000   97000.000000  106000.000000    707.0      1.0  202103.0
# 21  97000.000000  106000.000000  108000.000000    707.0      1.0  202109.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 17    100.0      9.0    883.0  0.710015  ...  480138.68750  486940.59375
# 18    100.0      9.0    883.0  0.710015  ...  480138.68750  486940.59375
# 19    100.0      7.0    883.0  0.710015  ...  480138.68750  486940.59375
# 20    100.0      4.0    883.0  0.710015  ...  450518.81250  457211.81250
# 21    100.0      9.0    883.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 17  100.180000      2.66  2267.149902  3152811.500  132.000000      52.0
# 18  100.089996      2.71  2591.340088  3183501.000  134.500000      52.0
# 19  100.330002      2.74  2873.469971  3197671.250  133.500000      49.0
# 20  101.839996      2.77  3061.419922  3313182.250  123.500000      82.0
# 21  103.169998      2.96  3068.820068  3513680.500  131.800003      55.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 17       1.0   97500.000000
# 18       1.0   97000.000000
# 19       1.0  106000.000000
# 20       1.0  108000.000000
# 21       1.0  138000.000000
#
# [545 rows x 34 columns]

# %%
train_set = df_all[df_all['var3(t)']<202000]

# %%
df_test = gizun_df
df_test = df_test[['resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
'house_CCSI', 'unsold', 'sale_type','prices']]
values = df_test.values
values = values.astype('float32')
reframed = series_to_supervised(values, 3, 1)
reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
test_set = reframed[reframed['var3(t)']>=202000]

# %%
df_set = pd.concat([train_set,test_set])
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4    81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5    74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6    73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7    67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..            ...            ...            ...      ...      ...       ...
# 50   79500.000000   84000.000000   90000.000000    571.0      0.0  202010.0
# 51   84000.000000   90000.000000   98000.000000    571.0      0.0  202105.0
# 52   90000.000000   98000.000000  110000.000000    571.0      0.0  202106.0
# 53   98000.000000  110000.000000  114000.000000    571.0      0.0  202107.0
# 54  110000.000000  114000.000000  115000.000000    571.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 50    100.0     12.0   1119.0  0.710015  ...  480138.68750  486940.59375
# 51    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 52    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 53    100.0      9.0   1119.0  0.710015  ...  466346.00000  471235.40625
# 54    100.0     14.0   1119.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 50  100.180000      2.66  2267.149902  3152811.500  132.000000      52.0
# 51  102.050003      2.72  3203.919922  3379754.000  127.500000      71.0
# 52  102.050003      2.77  3296.679932  3413899.750  131.300003      65.0
# 53  102.260002      2.77  3202.320068  3445243.000  133.300003      59.0
# 54  102.750000      2.87  3199.270020  3487634.000  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 50       0.0   98000.000000
# 51       0.0  110000.000000
# 52       0.0  114000.000000
# 53       0.0  115000.000000
# 54       0.0  129000.000000
#
# [478 rows x 34 columns]

# %%
test_set
# Out:
#     var31(t-3)  var31(t-2)  var31(t-1)  var1(t)  var2(t)   var3(t)  var4(t)  \
# 49     84000.0     79500.0     84000.0    571.0      0.0  202008.0    100.0
# 50     79500.0     84000.0     90000.0    571.0      0.0  202010.0    100.0
# 51     84000.0     90000.0     98000.0    571.0      0.0  202105.0    100.0
# 52     90000.0     98000.0    110000.0    571.0      0.0  202106.0    100.0
# 53     98000.0    110000.0    114000.0    571.0      0.0  202107.0    100.0
# 54    110000.0    114000.0    115000.0    571.0      0.0  202108.0    100.0
#
#     var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)    var24(t)  \
# 49     12.0   1119.0  0.710015  ...  454712.90625  458855.50000  100.190002
# 50     12.0   1119.0  0.710015  ...  480138.68750  486940.59375  100.180000
# 51      9.0   1119.0  0.710015  ...  467060.31250  470984.90625  102.050003
# 52      9.0   1119.0  0.710015  ...  467060.31250  470984.90625  102.050003
# 53      9.0   1119.0  0.710015  ...  466346.00000  471235.40625  102.260002
# 54     14.0   1119.0  0.710015  ...  466346.00000  471235.40625  102.750000
#
#     var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  var30(t)  \
# 49      2.63  2326.169922  3100373.50  127.699997      56.0       0.0
# 50      2.66  2267.149902  3152811.50  132.000000      52.0       0.0
# 51      2.72  3203.919922  3379754.00  127.500000      71.0       0.0
# 52      2.77  3296.679932  3413899.75  131.300003      65.0       0.0
# 53      2.77  3202.320068  3445243.00  133.300003      59.0       0.0
# 54      2.87  3199.270020  3487634.00  135.100006      55.0       0.0
#
#     var31(t)
# 49   90000.0
# 50   98000.0
# 51  110000.0
# 52  114000.0
# 53  115000.0
# 54  129000.0
#
# [6 rows x 34 columns]

# %% [markdown]
# test

# %%
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4    81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5    74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6    73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7    67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..            ...            ...            ...      ...      ...       ...
# 50   79500.000000   84000.000000   90000.000000    571.0      0.0  202010.0
# 51   84000.000000   90000.000000   98000.000000    571.0      0.0  202105.0
# 52   90000.000000   98000.000000  110000.000000    571.0      0.0  202106.0
# 53   98000.000000  110000.000000  114000.000000    571.0      0.0  202107.0
# 54  110000.000000  114000.000000  115000.000000    571.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 50    100.0     12.0   1119.0  0.710015  ...  480138.68750  486940.59375
# 51    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 52    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 53    100.0      9.0   1119.0  0.710015  ...  466346.00000  471235.40625
# 54    100.0     14.0   1119.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 50  100.180000      2.66  2267.149902  3152811.500  132.000000      52.0
# 51  102.050003      2.72  3203.919922  3379754.000  127.500000      71.0
# 52  102.050003      2.77  3296.679932  3413899.750  131.300003      65.0
# 53  102.260002      2.77  3202.320068  3445243.000  133.300003      59.0
# 54  102.750000      2.87  3199.270020  3487634.000  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 50       0.0   98000.000000
# 51       0.0  110000.000000
# 52       0.0  114000.000000
# 53       0.0  115000.000000
# 54       0.0  129000.000000
#
# [478 rows x 34 columns]

# %%
train_days =  len(train_set)
df_set[:train_days]
# Out:
#       var31(t-3)    var31(t-2)    var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3   78008.000000  81027.000000  74729.500000    571.0      0.0  201207.0
# 4   81027.000000  74729.500000  73718.000000    571.0      0.0  201211.0
# 5   74729.500000  73718.000000  67214.664062    571.0      0.0  201212.0
# 6   73718.000000  67214.664062  66197.335938    571.0      0.0  201301.0
# 7   67214.664062  66197.335938  67502.000000    571.0      0.0  201303.0
# ..           ...           ...           ...      ...      ...       ...
# 12  61500.000000  60000.000000  58500.000000    707.0      1.0  201610.0
# 13  60000.000000  58500.000000  65300.000000    707.0      1.0  201611.0
# 14  58500.000000  65300.000000  65000.000000    707.0      1.0  201808.0
# 15  65300.000000  65000.000000  72250.000000    707.0      1.0  201811.0
# 16  65000.000000  72250.000000  78000.000000    707.0      1.0  201812.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 12    100.0      9.0    883.0  0.710015  ...  452807.50000  454234.09375
# 13    100.0      6.0    883.0  0.710015  ...  452807.50000  454234.09375
# 14    100.0      8.0    883.0  0.710015  ...  452819.18750  456622.68750
# 15    100.0      5.0    883.0  0.710015  ...  472209.31250  475563.81250
# 16    100.0      5.0    883.0  0.710015  ...  472209.31250  475563.81250
#
#      var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3   91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4   92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5   92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6   92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7   92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..        ...       ...          ...          ...         ...       ...
# 12  96.378998      3.29  2008.189941  2391059.250  129.800003     283.0
# 13  96.237000      3.36  1983.479980  2406393.500  116.500000     268.0
# 14  99.461998      3.63  2322.879883  2651503.500  115.900002      39.0
# 15  99.330002      3.66  2096.860107  2692974.750  100.199997      28.0
# 16  98.987999      3.72  2041.040039  2699882.250   91.199997      27.0
#
#     var30(t)      var31(t)
# 3        0.0  73718.000000
# 4        0.0  67214.664062
# 5        0.0  66197.335938
# 6        0.0  67502.000000
# 7        0.0  67592.000000
# ..       ...           ...
# 12       1.0  65300.000000
# 13       1.0  65000.000000
# 14       1.0  72250.000000
# 15       1.0  78000.000000
# 16       1.0  77500.000000
#
# [472 rows x 34 columns]

# %%
values=df_set.values
values.shape
# Out:
# (478, 34)

# %%
values
# Out:
# array([[7.8008000e+04, 8.1027000e+04, 7.4729500e+04, ..., 3.1460000e+03,
#         0.0000000e+00, 7.3718000e+04],
#        [8.1027000e+04, 7.4729500e+04, 7.3718000e+04, ..., 3.5940000e+03,
#         0.0000000e+00, 6.7214664e+04],
#        [7.4729500e+04, 7.3718000e+04, 6.7214664e+04, ..., 3.4810000e+03,
#         0.0000000e+00, 6.6197336e+04],
#        ...,
#        [9.0000000e+04, 9.8000000e+04, 1.1000000e+05, ..., 6.5000000e+01,
#         0.0000000e+00, 1.1400000e+05],
#        [9.8000000e+04, 1.1000000e+05, 1.1400000e+05, ..., 5.9000000e+01,
#         0.0000000e+00, 1.1500000e+05],
#        [1.1000000e+05, 1.1400000e+05, 1.1500000e+05, ..., 5.5000000e+01,
#         0.0000000e+00, 1.2900000e+05]], dtype=float32)

# %%
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days]
test = values[train_days:]

# %%
test.shape
# Out:
# (6, 34)

# %%
values=df_set.values
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days, :]
test = values[train_days:, :]

# %%
test
# Out:
# array([[0.67088616, 0.58433735, 0.63095236, 0.        , 0.        ,
#         0.8893738 , 0.36363637, 0.57894737, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.9007633 , 0.9234694 , 0.7804413 , 0.7988639 ,
#         0.7860451 , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        , 0.60204077],
#        [0.61392415, 0.6385543 , 0.7023809 , 0.        , 0.        ,
#         0.8915863 , 0.36363637, 0.57894737, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.6942791 , 0.8888855 , 0.8181819 ,
#         0.1742487 , 1.        , 0.9183675 , 1.0000002 , 1.0000002 ,
#         1.        , 0.7729273 , 0.00974023, 0.29154766, 0.8042568 ,
#         0.82330084, 0.00580855, 0.        , 0.6836734 ],
#        [0.67088616, 0.7108434 , 0.797619  , 0.        , 0.        ,
#         0.9966736 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.8955189 , 1.        , 0.36363637,
#         0.0268203 , 0.8778622 , 0.93877566, 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.02922076, 0.9361688 , 0.9369314 ,
#         0.73592234, 0.01022305, 0.        , 0.8061224 ],
#        [0.7468355 , 0.80722886, 0.9404762 , 0.        , 0.        ,
#         0.9977875 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8625951 , 0.9030613 , 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        , 0.8469387 ],
#        [0.8481014 , 0.9518072 , 0.98809516, 0.        , 0.        ,
#         0.9988861 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.94274783, 0.9234694 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        , 0.8571428 ],
#        [1.        , 1.        , 1.        , 0.        , 0.        ,
#         1.        , 0.36363637, 0.68421054, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.9732821 , 1.0000001 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        , 1.        ]], dtype=float32)

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
train_y
# Out:
# array([0.43589792, 0.36953738, 0.35915646, 0.37246934, 0.37338772,
#        0.40503058, 0.34683672, 0.35438773, 0.36091837, 0.39795914,
#        0.34444895, 0.4395459 , 0.36814424, 0.37262753, 0.3318163 ,
#        0.44021937, 0.42738774, 0.37144384, 0.3819932 , 0.43973467,
#        0.5816326 , 0.54591835, 0.38985714, 0.39326015, 0.43690816,
#        0.47306117, 0.5918367 , 0.63775504, 0.6       , 0.48335204,
#        0.47199997, 0.4732245 , 0.6428571 , 0.75      , 0.75510204,
#        0.71938777, 0.7244898 , 0.71938777, 0.36224487, 0.40816322,
#        0.377551  , 0.5153061 , 0.4897959 , 0.49999997, 0.53775513,
#        0.54591835, 0.62755096, 0.24489793, 0.27959183, 0.23027208,
#        0.2397959 , 0.29081628, 0.26275507, 0.2142857 , 0.24693874,
#        0.3112245 , 0.28571424, 0.29081628, 0.29234692, 0.2918367 ,
#        0.27125844, 0.34183672, 0.29413262, 0.3040816 , 0.29540816,
#        0.22959182, 0.26020405, 0.27040812, 0.2860544 , 0.2571428 ,
#        0.2648979 , 0.2879592 , 0.29834184, 0.33163264, 0.2695578 ,
#        0.31428567, 0.24489793, 0.29336736, 0.33503398, 0.3023809 ,
#        0.30612245, 0.31666663, 0.32993194, 0.32346937, 0.4163265 ,
#        0.34693876, 0.43367347, 0.3408163 , 0.47448978, 0.5510204 ,
#        0.5408163 , 0.49489793, 0.5408163 , 0.11632651, 0.1377551 ,
#        0.12755102, 0.12959182, 0.15221089, 0.15306121, 0.1390306 ,
#        0.14632651, 0.10714284, 0.1377551 , 0.15816325, 0.1377551 ,
#        0.18571427, 0.14693877, 0.19183674, 0.18979588, 0.23163262,
#        0.1772959 , 0.16870746, 0.20663264, 0.22193876, 0.19132653,
#        0.19183674, 0.2397959 , 0.23214284, 0.22448978, 0.21734694,
#        0.2311224 , 0.22142854, 0.23367342, 0.2163265 , 0.19387755,
#        0.19387755, 0.31632653, 0.34693876, 0.34489796, 0.03010204,
#        0.01020408, 0.02551019, 0.        , 0.03639457, 0.04523808,
#        0.0395408 , 0.0635204 , 0.05612245, 0.04795918, 0.0535714 ,
#        0.04234692, 0.08265305, 0.09081632, 0.07142857, 0.08775508,
#        0.06632653, 0.1030612 , 0.09604591, 0.09999999, 0.07704079,
#        0.11581632, 0.12517008, 0.11173469, 0.11938775, 0.12040815,
#        0.15408161, 0.17142856, 0.15816325, 0.17142856, 0.16122448,
#        0.19285712, 0.28826526, 0.27551016, 0.27755103, 0.35643873,
#        0.42346933, 0.3555918 , 0.36847958, 0.38422957, 0.47388265,
#        0.35702547, 0.37448975, 0.4387755 , 0.36347958, 0.3985918 ,
#        0.40762857, 0.40229997, 0.4457449 , 0.65306115, 0.60204077,
#        0.63775504, 0.43367347, 0.41326526, 0.44489792, 0.45408162,
#        0.4489796 , 0.44591835, 0.53571427, 0.49999997, 0.47959182,
#        0.61224484, 0.29591838, 0.44387755, 0.5153061 , 0.11224487,
#        0.14285713, 0.16326529, 0.17959183, 0.12244895, 0.09183672,
#        0.16122448, 0.20102039, 0.17244896, 0.12755102, 0.17346936,
#        0.18367344, 0.1755102 , 0.19183674, 0.19557825, 0.19285712,
#        0.22244897, 0.19693878, 0.20714286, 0.21734694, 0.20408162,
#        0.21938774, 0.22448978, 0.20918366, 0.21088436, 0.2270408 ,
#        0.18265304, 0.23214284, 0.23299316, 0.27040812, 0.23877552,
#        0.29489794, 0.27551016, 0.2938775 , 0.29489794, 0.28877547,
#        0.32142857, 0.35224488, 0.5102041 , 0.38775507, 0.33163264,
#        0.43673465, 0.05102038, 0.03061223, 0.04081631, 0.04081631,
#        0.06615645, 0.06505102, 0.07142857, 0.04081631, 0.06887755,
#        0.09693876, 0.08775508, 0.1020408 , 0.11224487, 0.11632651,
#        0.10969386, 0.10714284, 0.14285713, 0.15306121, 0.13265306,
#        0.19387755, 0.19897959, 0.19387755, 0.31632653, 0.3265306 ,
#        0.4897959 , 0.16326529, 0.11479589, 0.1280612 , 0.12244895,
#        0.1645408 , 0.16326529, 0.14999998, 0.18877551, 0.1785714 ,
#        0.18010202, 0.1397959 , 0.16496599, 0.15918365, 0.1785714 ,
#        0.19183674, 0.15561223, 0.18979588, 0.20918366, 0.10867345,
#        0.22806123, 0.22479591, 0.22448978, 0.22448978, 0.2397959 ,
#        0.2418367 , 0.24234691, 0.20918366, 0.24285713, 0.25816324,
#        0.27040812, 0.2397959 , 0.24632654, 0.26326528, 0.22244897,
#        0.28163263, 0.3158163 , 0.29948977, 0.29438773, 0.33367345,
#        0.33469388, 0.27551016, 0.34693876, 0.41326526, 0.3673469 ,
#        0.55306125, 0.49897954, 0.4897959 , 0.4785714 , 0.08061224,
#        0.06479591, 0.05306122, 0.07142857, 0.0267857 , 0.02925169,
#        0.05340132, 0.04183671, 0.05887753, 0.06377551, 0.07295918,
#        0.06394559, 0.05510202, 0.05272108, 0.0377551 , 0.06632653,
#        0.06969386, 0.07040817, 0.06918365, 0.06045917, 0.06479591,
#        0.07117346, 0.0787755 , 0.07142857, 0.087585  , 0.07959181,
#        0.09591836, 0.08571428, 0.07653061, 0.09863946, 0.08163264,
#        0.09504372, 0.1020408 , 0.11326531, 0.11462581, 0.13061222,
#        0.12244895, 0.10663265, 0.13265306, 0.125     , 0.11275509,
#        0.14285713, 0.17142856, 0.16403061, 0.17193875, 0.16326529,
#        0.18877551, 0.18877551, 0.18367344, 0.16326529, 0.19727889,
#        0.18197277, 0.20408162, 0.21352038, 0.3153061 , 0.3479592 ,
#        0.29591838, 0.30867347, 0.3673469 , 0.4387755 , 0.49489793,
#        0.2938775 , 0.27040812, 0.24489793, 0.27040812, 0.24489793,
#        0.25204077, 0.2938775 , 0.252551  , 0.24489793, 0.28571424,
#        0.2806122 , 0.29234692, 0.2806122 , 0.3132653 , 0.33418366,
#        0.29081628, 0.3265306 , 0.34387752, 0.39591834, 0.3395408 ,
#        0.38775507, 0.4183673 , 0.38163266, 0.41530612, 0.46556118,
#        0.5969387 , 0.5510204 , 0.56122446, 0.5918367 , 0.6       ,
#        0.09999999, 0.12755102, 0.1010204 , 0.07857141, 0.09183672,
#        0.07653061, 0.14183673, 0.15306121, 0.14591834, 0.13265306,
#        0.14795917, 0.1260204 , 0.1658163 , 0.16071427, 0.15561223,
#        0.15714285, 0.14693877, 0.14897957, 0.17959183, 0.20204082,
#        0.14285713, 0.18367344, 0.19727889, 0.18367344, 0.21173468,
#        0.19931969, 0.2142857 , 0.15816325, 0.24489793, 0.24489793,
#        0.25612244, 0.24387756, 0.24489793, 0.20765302, 0.26326528,
#        0.24489793, 0.39591834, 0.34693876, 0.27551016, 0.50170064,
#        0.3265306 , 0.377551  , 0.30612245, 0.35969386, 0.22959182,
#        0.31632653, 0.34693876, 0.34183672, 0.34489796, 0.35969386,
#        0.3265306 , 0.377551  , 0.37244895, 0.39795914, 0.52040815,
#        0.5510204 , 0.52040815, 0.52040815, 0.22244897, 0.22295919,
#        0.24285713, 0.15306121, 0.21938774, 0.2806122 , 0.3112245 ,
#        0.29591838, 0.2806122 , 0.35      , 0.34693876, 0.42091832,
#        0.47959182, 0.47448978], dtype=float32)

# %%
test_y
# Out:
# array([0.60204077, 0.6836734 , 0.8061224 , 0.8469387 , 0.8571428 ,
#        1.        ], dtype=float32)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=50, batch_size=72, 
        validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 7/7 - 4s - loss: 0.2868 - val_loss: 0.6298 - 4s/epoch - 600ms/step
# Epoch 2/50
# 7/7 - 0s - loss: 0.1281 - val_loss: 0.3807 - 69ms/epoch - 10ms/step
# Epoch 3/50
# 7/7 - 0s - loss: 0.1012 - val_loss: 0.2403 - 118ms/epoch - 17ms/step
# Epoch 4/50
# 7/7 - 0s - loss: 0.0999 - val_loss: 0.2401 - 132ms/epoch - 19ms/step
# Epoch 5/50
# 7/7 - 0s - loss: 0.0782 - val_loss: 0.2742 - 114ms/epoch - 16ms/step
# Epoch 6/50
# 7/7 - 0s - loss: 0.0652 - val_loss: 0.2504 - 114ms/epoch - 16ms/step
# Epoch 7/50
# 7/7 - 0s - loss: 0.0572 - val_loss: 0.1657 - 111ms/epoch - 16ms/step
# Epoch 8/50
# 7/7 - 0s - loss: 0.0508 - val_loss: 0.1049 - 96ms/epoch - 14ms/step
# Epoch 9/50
# 7/7 - 0s - loss: 0.0470 - val_loss: 0.0900 - 86ms/epoch - 12ms/step
# Epoch 10/50
# 7/7 - 0s - loss: 0.0426 - val_loss: 0.0779 - 108ms/epoch - 15ms/step
# Epoch 11/50
# 7/7 - 0s - loss: 0.0403 - val_loss: 0.0730 - 104ms/epoch - 15ms/step
# Epoch 12/50
# 7/7 - 0s - loss: 0.0377 - val_loss: 0.0746 - 96ms/epoch - 14ms/step
# Epoch 13/50
# 7/7 - 0s - loss: 0.0355 - val_loss: 0.0770 - 104ms/epoch - 15ms/step
# Epoch 14/50
# 7/7 - 0s - loss: 0.0336 - val_loss: 0.0903 - 98ms/epoch - 14ms/step
# Epoch 15/50
# 7/7 - 0s - loss: 0.0319 - val_loss: 0.0958 - 104ms/epoch - 15ms/step
# Epoch 16/50
# 7/7 - 0s - loss: 0.0307 - val_loss: 0.0960 - 92ms/epoch - 13ms/step
# Epoch 17/50
# 7/7 - 0s - loss: 0.0298 - val_loss: 0.0965 - 74ms/epoch - 11ms/step
# Epoch 18/50
# 7/7 - 0s - loss: 0.0290 - val_loss: 0.1017 - 114ms/epoch - 16ms/step
# Epoch 19/50
# 7/7 - 0s - loss: 0.0285 - val_loss: 0.0932 - 82ms/epoch - 12ms/step
# Epoch 20/50
# 7/7 - 0s - loss: 0.0279 - val_loss: 0.0924 - 85ms/epoch - 12ms/step
# Epoch 21/50
# 7/7 - 0s - loss: 0.0276 - val_loss: 0.0944 - 120ms/epoch - 17ms/step
# Epoch 22/50
# 7/7 - 0s - loss: 0.0274 - val_loss: 0.0985 - 85ms/epoch - 12ms/step
# Epoch 23/50
# 7/7 - 0s - loss: 0.0273 - val_loss: 0.0893 - 76ms/epoch - 11ms/step
# Epoch 24/50
# 7/7 - 0s - loss: 0.0270 - val_loss: 0.0832 - 64ms/epoch - 9ms/step
# Epoch 25/50
# 7/7 - 0s - loss: 0.0267 - val_loss: 0.0975 - 59ms/epoch - 8ms/step
# Epoch 26/50
# 7/7 - 0s - loss: 0.0268 - val_loss: 0.0938 - 70ms/epoch - 10ms/step
# Epoch 27/50
# 7/7 - 0s - loss: 0.0264 - val_loss: 0.0695 - 63ms/epoch - 9ms/step
# Epoch 28/50
# 7/7 - 0s - loss: 0.0264 - val_loss: 0.0831 - 60ms/epoch - 9ms/step
# Epoch 29/50
# 7/7 - 0s - loss: 0.0265 - val_loss: 0.1082 - 58ms/epoch - 8ms/step
# Epoch 30/50
# 7/7 - 0s - loss: 0.0270 - val_loss: 0.0555 - 62ms/epoch - 9ms/step
# Epoch 31/50
# 7/7 - 0s - loss: 0.0263 - val_loss: 0.0788 - 61ms/epoch - 9ms/step
# Epoch 32/50
# 7/7 - 0s - loss: 0.0259 - val_loss: 0.0929 - 69ms/epoch - 10ms/step
# Epoch 33/50
# 7/7 - 0s - loss: 0.0260 - val_loss: 0.0622 - 60ms/epoch - 9ms/step
# Epoch 34/50
# 7/7 - 0s - loss: 0.0258 - val_loss: 0.0638 - 64ms/epoch - 9ms/step
# Epoch 35/50
# 7/7 - 0s - loss: 0.0263 - val_loss: 0.1170 - 58ms/epoch - 8ms/step
# Epoch 36/50
# 7/7 - 0s - loss: 0.0280 - val_loss: 0.0568 - 64ms/epoch - 9ms/step
# Epoch 37/50
# 7/7 - 0s - loss: 0.0262 - val_loss: 0.0532 - 70ms/epoch - 10ms/step
# Epoch 38/50
# 7/7 - 0s - loss: 0.0276 - val_loss: 0.1275 - 57ms/epoch - 8ms/step
# Epoch 39/50
# 7/7 - 0s - loss: 0.0290 - val_loss: 0.0608 - 64ms/epoch - 9ms/step
# Epoch 40/50
# 7/7 - 0s - loss: 0.0250 - val_loss: 0.0559 - 63ms/epoch - 9ms/step
# Epoch 41/50
# 7/7 - 0s - loss: 0.0254 - val_loss: 0.0900 - 53ms/epoch - 8ms/step
# Epoch 42/50
# 7/7 - 0s - loss: 0.0258 - val_loss: 0.0637 - 74ms/epoch - 11ms/step
# Epoch 43/50
# 7/7 - 0s - loss: 0.0252 - val_loss: 0.0509 - 61ms/epoch - 9ms/step
# Epoch 44/50
# 7/7 - 0s - loss: 0.0260 - val_loss: 0.1065 - 66ms/epoch - 9ms/step
# Epoch 45/50
# 7/7 - 0s - loss: 0.0269 - val_loss: 0.0561 - 55ms/epoch - 8ms/step
# Epoch 46/50
# 7/7 - 0s - loss: 0.0256 - val_loss: 0.0464 - 65ms/epoch - 9ms/step
# Epoch 47/50
# 7/7 - 0s - loss: 0.0273 - val_loss: 0.1221 - 60ms/epoch - 9ms/step
# Epoch 48/50
# 7/7 - 0s - loss: 0.0283 - val_loss: 0.0561 - 61ms/epoch - 9ms/step
# Epoch 49/50
# 7/7 - 0s - loss: 0.0248 - val_loss: 0.0545 - 67ms/epoch - 10ms/step
# Epoch 50/50
# 7/7 - 0s - loss: 0.0260 - val_loss: 0.1056 - 57ms/epoch - 8ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# Out:
# 1/1 [==============================] - 1s 987ms/step

# %%
test_X.shape
# Out:
# (6, 33)

# %%
yhat
# Out:
# array([[0.5376386 ],
#        [0.57139975],
#        [0.69045347],
#        [0.750331  ],
#        [0.7835301 ],
#        [0.8287145 ]], dtype=float32)

# %%
test_X
# Out:
# array([[0.67088616, 0.58433735, 0.63095236, 0.        , 0.        ,
#         0.8893738 , 0.36363637, 0.57894737, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.9007633 , 0.9234694 , 0.7804413 , 0.7988639 ,
#         0.7860451 , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        ],
#        [0.61392415, 0.6385543 , 0.7023809 , 0.        , 0.        ,
#         0.8915863 , 0.36363637, 0.57894737, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.6942791 , 0.8888855 , 0.8181819 ,
#         0.1742487 , 1.        , 0.9183675 , 1.0000002 , 1.0000002 ,
#         1.        , 0.7729273 , 0.00974023, 0.29154766, 0.8042568 ,
#         0.82330084, 0.00580855, 0.        ],
#        [0.67088616, 0.7108434 , 0.797619  , 0.        , 0.        ,
#         0.9966736 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.8955189 , 1.        , 0.36363637,
#         0.0268203 , 0.8778622 , 0.93877566, 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.02922076, 0.9361688 , 0.9369314 ,
#         0.73592234, 0.01022305, 0.        ],
#        [0.7468355 , 0.80722886, 0.9404762 , 0.        , 0.        ,
#         0.9977875 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8625951 , 0.9030613 , 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        ],
#        [0.8481014 , 0.9518072 , 0.98809516, 0.        , 0.        ,
#         0.9988861 , 0.36363637, 0.42105263, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.94274783, 0.9234694 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        ],
#        [1.        , 1.        , 1.        , 0.        , 0.        ,
#         1.        , 0.36363637, 0.68421054, 1.        , 0.        ,
#         1.        , 0.99999994, 0.        , 0.99999994, 1.        ,
#         1.        , 0.99999994, 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.9732821 , 1.0000001 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        ]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((test_X[:, 0:],yhat), axis=1)

# %%
inv_yhat.shape
# Out:
# (6, 34)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
inv_yhat = inv_yhat[:,-1]
inv_yhat
# Out:
# array([ 83688.586,  86997.18 ,  98664.445, 104532.445, 107785.95 ,
#        112214.02 ], dtype=float32)

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_X[:, 0:],test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
# calculate RMSE

# %%
inv_y
# Out:
# array([ 89999.99,  97999.99, 110000.  , 114000.  , 114999.99, 129000.  ],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.plot(inv_y)
plt.plot(inv_yhat)
plt.show()

# %%
#실제값
inv_y
# Out:
# array([ 89999.99,  97999.99, 110000.  , 114000.  , 114999.99, 129000.  ],
#       dtype=float32)

# %%
#예측치
inv_yhat
# Out:
# array([ 83688.586,  86997.18 ,  98664.445, 104532.445, 107785.95 ,
#        112214.02 ], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
RMSE = mean_squared_error(inv_y, inv_yhat)**0.5

# %%
RMSE
# Out:
# 10899.820182003004
