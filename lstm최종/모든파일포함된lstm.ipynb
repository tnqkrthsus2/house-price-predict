# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('데이터_변수_0812_final2.csv',encoding='cp949')

# %%
df
# Out:
#             아파트코드    계약년월                    단지명            시군구  읍면동  \
# 0       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 1       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 2       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 3       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 4       A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동  종암동
# ...           ...     ...                    ...            ...  ...
# 725063  A15776004  202207                    현대3  서울특별시 강서구 염창동  염창동
# 725064  A15807701  202207                  세양청마루  서울특별시 양천구 신정동  신정동
# 725065  A15882107  202207                    금호1   서울특별시 양천구 목동   목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동  진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동  진관동
#
#                      kapt도로명주소   분양형태    전용면적   층  건축년도  ...    주택구매력지수   PIR  \
# ...

# %%
df.keys()
# Out:
# Index(['아파트코드', '계약년월', '단지명', '시군구', '읍면동', 'kapt도로명주소', '분양형태', '전용면적', '층',
#        '건축년도', '주차대수', '좌표X', '좌표Y', '범죄율', '건물연식', '대규모점포_거리', '버스정류장_거리',
#        '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '거래금액', '아파트매매가격지수', '년도', '월',
#        '주택구매력지수', 'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '대출평균',
#        '주택담보대출금리', '평균코스피지수'],
#       dtype='object')

# %%
a = pd.read_excel('A(m2,소비자심리,미분양).xlsx')

# %%
df = pd.merge(df, a, on = '계약년월', how = 'left')
df
# Out:
#             아파트코드    계약년월                    단지명            시군구  읍면동  \
# 0       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 1       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 2       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 3       A10024240  201201                    무지개  서울특별시 서초구 서초동  서초동
# 4       A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동  종암동
# ...           ...     ...                    ...            ...  ...
# 725063  A15776004  202207                    현대3  서울특별시 강서구 염창동  염창동
# 725064  A15807701  202207                  세양청마루  서울특별시 양천구 신정동  신정동
# 725065  A15882107  202207                    금호1   서울특별시 양천구 목동   목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동  진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동  진관동
#
#                      kapt도로명주소   분양형태    전용면적   층  건축년도  ...       GDP  \
# ...

# %%
df.keys()
# Out:
# Index(['아파트코드', '계약년월', '단지명', '시군구', '읍면동', 'kapt도로명주소', '분양형태', '전용면적', '층',
#        '건축년도', '주차대수', '좌표X', '좌표Y', '범죄율', '건물연식', '대규모점포_거리', '버스정류장_거리',
#        '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '거래금액', '아파트매매가격지수', '년도', '월',
#        '주택구매력지수', 'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '대출평균',
#        '주택담보대출금리', '평균코스피지수', 'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양'],
#       dtype='object')

# %%
print(df[df['GNI'].isnull()])
# Out:
#             아파트코드    계약년월                    단지명              시군구   읍면동  \
# 724840  A10023891  202207               청계푸르지오시티  서울특별시 동대문구 답십리동  답십리동
# 724841  A10023891  202207               청계푸르지오시티  서울특별시 동대문구 답십리동  답십리동
# 724842  A10023891  202207               청계푸르지오시티  서울특별시 동대문구 답십리동  답십리동
# 724843  A10023926  202207               롯데캐슬클라시아    서울특별시 성북구 길음동   길음동
# 724844  A10024131  202207                래미안라클래시    서울특별시 강남구 삼성동   삼성동
# ...           ...     ...                    ...              ...   ...
# 725063  A15776004  202207                    현대3    서울특별시 강서구 염창동   염창동
# 725064  A15807701  202207                  세양청마루    서울특별시 양천구 신정동   신정동
# 725065  A15882107  202207                    금호1     서울특별시 양천구 목동    목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)    서울특별시 은평구 진관동   진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)    서울특별시 은평구 진관동   진관동
#
#                      kapt도로명주소   분양형태      전용면적   층  건축년도  ...  GDP  GDI  GNI  \
# ...

# %%
from sklearn import linear_model
lin_reg = linear_model.LinearRegression()

# %%
df.dtypes
# Out:
# 아파트코드             object
# 계약년월               int64
# 단지명               object
# 시군구               object
# 읍면동               object
# kapt도로명주소         object
# 분양형태              object
# 전용면적             float64
# 층                  int64
# 건축년도               int64
# 주차대수             float64
# 좌표X              float64
# 좌표Y              float64
# 범죄율              float64
# 건물연식               int64
# 대규모점포_거리         float64
# 버스정류장_거리         float64
# 지하철역_거리          float64
# 학교_거리            float64
# 유치원_거리           float64
# 병원_거리            float64
# 거래금액               int64
# 아파트매매가격지수        float64
# 년도                 int64
# 월                  int64
# 주택구매력지수          float64
# PIR              float64
# LIR              float64
# GDP              float64
# GDI              float64
# GNI              float64
# 소비자물가지수          float64
# 대출평균             float64
# 주택담보대출금리         float64
# 평균코스피지수            int64
# M2통화량(평잔,십억원)    float64
# 주택시장소비심리지수       float64
# ...

# %%
df = df.astype({'평균코스피지수':'float64'})

# %% [markdown]
# 필요없는 변수 제거

# %%
df.pop('주택담보대출금리')
# Out:
# 0         5.06
# 1         5.06
# 2         5.06
# 3         5.06
# 4         5.06
#           ...
# 725063     NaN
# 725064     NaN
# 725065     NaN
# 725066     NaN
# 725067     NaN
# Name: 주택담보대출금리, Length: 725068, dtype: float64

# %%
df.pop('대출평균')
# Out:
# 0         5.79
# 1         5.79
# 2         5.79
# 3         5.79
# 4         5.79
#           ...
# 725063     NaN
# 725064     NaN
# 725065     NaN
# 725066     NaN
# 725067     NaN
# Name: 대출평균, Length: 725068, dtype: float64

# %%
df.isnull().sum()
# Out:
# 아파트코드               0
# 계약년월                0
# 단지명                 0
# 시군구                 0
# 읍면동                 0
# kapt도로명주소           0
# 분양형태             2628
# 전용면적                0
# 층                   0
# 건축년도                0
# 주차대수             1926
# 좌표X                 0
# 좌표Y                 0
# 범죄율                 0
# 건물연식                0
# 대규모점포_거리            0
# 버스정류장_거리            0
# 지하철역_거리             0
# 학교_거리               0
# 유치원_거리              0
# 병원_거리               0
# 거래금액                0
# 아파트매매가격지수           0
# 년도                  0
# 월                   0
# 주택구매력지수          3269
# PIR              4222
# LIR              4222
# GDP               228
# GDI               228
# GNI               228
# 소비자물가지수             0
# 평균코스피지수             0
# M2통화량(평잔,십억원)     228
# 주택시장소비심리지수        228
# 미분양               228
# dtype: int64

# %%
df.keys()
# Out:
# Index(['아파트코드', '계약년월', '단지명', '시군구', '읍면동', 'kapt도로명주소', '분양형태', '전용면적', '층',
#        '건축년도', '주차대수', '좌표X', '좌표Y', '범죄율', '건물연식', '대규모점포_거리', '버스정류장_거리',
#        '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '거래금액', '아파트매매가격지수', '년도', '월',
#        '주택구매력지수', 'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수',
#        'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양'],
#       dtype='object')

# %% [markdown]
# 결측치 행 삭제

# %%
df = df[df['주차대수'].notna()]
df = df[df['분양형태'].notna()]
df = df[df['M2통화량(평잔,십억원)'].notna()]
df = df[df['주택시장소비심리지수'].notna()]
df = df[df['미분양'].notna()]

# %%
df = df[df['PIR'].notna()]
df = df[df['LIR'].notna()]
df = df[df['주택구매력지수'].notna()]

# %%
df.isnull().sum()
# Out:
# 아파트코드            0
# 계약년월             0
# 단지명              0
# 시군구              0
# 읍면동              0
# kapt도로명주소        0
# 분양형태             0
# 전용면적             0
# 층                0
# 건축년도             0
# 주차대수             0
# 좌표X              0
# 좌표Y              0
# 범죄율              0
# 건물연식             0
# 대규모점포_거리         0
# 버스정류장_거리         0
# 지하철역_거리          0
# 학교_거리            0
# 유치원_거리           0
# 병원_거리            0
# 거래금액             0
# 아파트매매가격지수        0
# 년도               0
# 월                0
# 주택구매력지수          0
# PIR              0
# LIR              0
# GDP              0
# GDI              0
# GNI              0
# 소비자물가지수          0
# 평균코스피지수          0
# M2통화량(평잔,십억원)    0
# 주택시장소비심리지수       0
# 미분양              0
# dtype: int64

# %% [markdown]
# 원핫인코딩으로 더미 변수 생성

# %%
df.dtypes
# Out:
# 아파트코드             object
# 계약년월               int64
# 단지명               object
# 시군구               object
# 읍면동               object
# kapt도로명주소         object
# 분양형태              object
# 전용면적             float64
# 층                  int64
# 건축년도               int64
# 주차대수             float64
# 좌표X              float64
# 좌표Y              float64
# 범죄율              float64
# 건물연식               int64
# 대규모점포_거리         float64
# 버스정류장_거리         float64
# 지하철역_거리          float64
# 학교_거리            float64
# 유치원_거리           float64
# 병원_거리            float64
# 거래금액               int64
# 아파트매매가격지수        float64
# 년도                 int64
# 월                  int64
# 주택구매력지수          float64
# PIR              float64
# LIR              float64
# GDP              float64
# GDI              float64
# GNI              float64
# 소비자물가지수          float64
# 평균코스피지수          float64
# M2통화량(평잔,십억원)    float64
# 주택시장소비심리지수       float64
# 미분양              float64
# dtype: object

# %%
df = pd.get_dummies(df,columns=['분양형태'])

# %%
df
# Out:
#             아파트코드    계약년월                  단지명            시군구  읍면동  \
# 0       A10024240  201201                  무지개  서울특별시 서초구 서초동  서초동
# 1       A10024240  201201                  무지개  서울특별시 서초구 서초동  서초동
# 2       A10024240  201201                  무지개  서울특별시 서초구 서초동  서초동
# 3       A10024240  201201                  무지개  서울특별시 서초구 서초동  서초동
# 4       A10024603  201201            아이파크종암동2차  서울특별시 성북구 종암동  종암동
# ...           ...     ...                  ...            ...  ...
# 720841  A15884703  202202                 신월시영  서울특별시 양천구 신월동  신월동
# 720842  A15886505  202202                푸른마을4  서울특별시 양천구 신정동  신정동
# 720843  A15886508  202202                푸른마을2  서울특별시 양천구 신정동  신정동
# 720844  A41279927  202202  은평뉴타운구파발(금호어울림10단지)  서울특별시 은평구 진관동  진관동
# 720845  B13307001  202202                 두산위브  서울특별시 성동구 행당동  행당동
#
#                    kapt도로명주소    전용면적   층  건축년도    주차대수  ...       GNI  \
# 0          서울특별시 서초구 효령로 391  101.81   1  1978  2886.0  ...  345819.5
# ...

# %%
df.keys()
# Out:
# Index(['아파트코드', '계약년월', '단지명', '시군구', '읍면동', 'kapt도로명주소', '전용면적', '층', '건축년도',
#        '주차대수', '좌표X', '좌표Y', '범죄율', '건물연식', '대규모점포_거리', '버스정류장_거리', '지하철역_거리',
#        '학교_거리', '유치원_거리', '병원_거리', '거래금액', '아파트매매가격지수', '년도', '월', '주택구매력지수',
#        'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수',
#        'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', '분양형태_임대',
#        '분양형태_임대+분양'],
#       dtype='object')

# %%
df = df[['아파트코드', '계약년월', '시군구', '읍면동', '전용면적', '층', '건축년도',
       '주차대수', '범죄율', '건물연식', '대규모점포_거리', '버스정류장_거리', '지하철역_거리',
       '학교_거리', '유치원_거리', '병원_거리', '거래금액', '아파트매매가격지수', '년도', '월',
       '주택구매력지수','PIR','LIR','GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수',
       'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', 
       '분양형태_임대','분양형태_임대+분양']]

# %%
df['area']=df['전용면적'].round(-1)
df.pop('전용면적')
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0         101.81
# 1         101.10
# 2          77.71
# 3         101.10
# 4          84.73
#            ...
# 720841     50.67
# 720842     84.99
# 720843     59.85
# 720844    134.56
# 720845     84.99
# Name: 전용면적, Length: 716316, dtype: float64

# %%
df['price'] = 0
for i in df.index:
    if type(df['거래금액'][i]) == str:
        df['price'][i] = df['거래금액'][i].replace(',','')
    else:
        df['price'][i] = df['거래금액'][i]
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22052\634229943.py in <module>
# ...

# %% [markdown]
# 같은 아파트 묶기

# %%
df = df.astype({'price':'float64'})
df['price']=df.groupby(['계약년월','아파트코드','area'])['price'].transform('mean')
df['아파트구분'] = df['아파트코드'].map(str) +'_' +df['area'].map(int).map(str)
df = df.drop_duplicates(subset=['아파트구분','계약년월'])
df.pop('거래금액')
# Out:
# 0          79000
# 2          64000
# 4          46000
# 6          31800
# 7          23100
#            ...
# 720839     71000
# 720842     90000
# 720843     69000
# 720844    120000
# 720845    129900
# Name: 거래금액, Length: 278384, dtype: int64

# %%
df['date'] = df['계약년월']
df = df.set_index('계약년월')
df = df.sort_values(by=["아파트구분", "date"], ascending=[True, True])

# %%
df
# Out:
#             아파트코드            시군구  읍면동   층  건축년도    주차대수       범죄율  건물연식  \
# 계약년월
# 201202  A10023859  서울특별시 동작구 대방동  대방동   4  2005   997.0  0.810248     0
# 201205  A10023859  서울특별시 동작구 대방동  대방동  10  2005   997.0  0.810248     0
# 201302  A10023859  서울특별시 동작구 대방동  대방동   8  2005   997.0  0.810248     0
# 201303  A10023859  서울특별시 동작구 대방동  대방동  18  2005   997.0  0.810248     0
# 201304  A10023859  서울특별시 동작구 대방동  대방동   1  2005   997.0  0.810248     0
# ...           ...            ...  ...  ..   ...     ...       ...   ...
# 202103  A15681110  서울특별시 동작구 대방동  대방동   7  1993  1795.0  0.810248     3
# 202105  A15681110  서울특별시 동작구 대방동  대방동  12  1993  1795.0  0.810248     3
# 202106  A15681110  서울특별시 동작구 대방동  대방동  15  1993  1795.0  0.810248     3
# 202107  A15681110  서울특별시 동작구 대방동  대방동   5  1993  1795.0  0.810248     3
# 202109  A15681110  서울특별시 동작구 대방동  대방동  18  1993  1795.0  0.810248     3
#
#         대규모점포_거리  버스정류장_거리  ...  주택시장소비심리지수     미분양  분양형태_분양  분양형태_영구임대  \
# ...

# %% [markdown]
# df저장

# %%
df.to_csv('8.15완성df.csv')

# %%
dongs = df['읍면동'].unique()
groups = df.groupby(df.읍면동)
for i in dongs:
    globals()['df_'+i] = groups.get_group(i)

# %%
codes = df['아파트구분']
apart_groups = df.groupby(df.아파트구분)
for i in codes:
    globals()['df_'+i] = apart_groups.get_group(i)

# %%
codes
# Out:
# array(['A10023858_70', 'A10025533_110', 'A10025533_60', 'A10025533_80',
#        'A10025898_60', 'A10025898_80', 'A14074101_110', 'A14074101_60',
#        'A14074101_80'], dtype=object)

# %%
df
# Out:
#             아파트코드            시군구  읍면동   층  건축년도   주차대수       범죄율  건물연식  \
# 계약년월
# 201312  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201506  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201603  A10023858  서울특별시 용산구 효창동  효창동   2  1972  465.0  1.255041     0
# 201604  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201611  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# ...           ...            ...  ...  ..   ...    ...       ...   ...
# 202105  B13307002  서울특별시 성동구 행당동  행당동   2  2011   99.0  0.811542     9
# 202106  B13307002  서울특별시 성동구 행당동  행당동   8  2011   99.0  0.811542     9
# 202107  B13307002  서울특별시 성동구 행당동  행당동  11  2011   99.0  0.811542     9
# 202108  B13307002  서울특별시 성동구 행당동  행당동   2  2011   99.0  0.811542     9
# 202109  B13307002  서울특별시 성동구 행당동  행당동   1  2011   99.0  0.811542     9
#
#         대규모점포_거리  버스정류장_거리  ...  주택시장소비심리지수     미분양  분양형태_분양  분양형태_영구임대  \
# 계약년월                        ...
# ...

# %%
df_효창동
# Out:
#             아파트코드            시군구  읍면동   층  건축년도   주차대수       범죄율  건물연식  \
# 계약년월
# 201312  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201506  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201603  A10023858  서울특별시 용산구 효창동  효창동   2  1972  465.0  1.255041     0
# 201604  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# 201611  A10023858  서울특별시 용산구 효창동  효창동   5  1972  465.0  1.255041     0
# ...           ...            ...  ...  ..   ...    ...       ...   ...
# 201705  A14074101  서울특별시 용산구 효창동  효창동  13  2010  342.0  1.255041     9
# 202008  A14074101  서울특별시 용산구 효창동  효창동  18  2010  342.0  1.255041     9
# 202101  A14074101  서울특별시 용산구 효창동  효창동  14  2010  342.0  1.255041     9
# 202103  A14074101  서울특별시 용산구 효창동  효창동  12  2010  342.0  1.255041     9
# 202107  A14074101  서울특별시 용산구 효창동  효창동   6  2010  342.0  1.255041     9
#
#         대규모점포_거리  버스정류장_거리  ...  주택시장소비심리지수     미분양  분양형태_분양  분양형태_영구임대  \
# 계약년월                        ...
# ...

# %% [markdown]
# 함수 정의하기

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow import keras
import numpy as np
from numpy import concatenate
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
  n_vars = 1 if type(data) is list else data.shape[1]
  df = pd.DataFrame(data)
  cols, names = list(), list()
  # input sequence (t-n, ... t-1)
  for i in range(n_in, 0, -1):
      cols.append(df.shift(i))
      names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
  # forecast sequence (t, t+1, ... t+n)
  for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
          names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
          names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
  # put it all together
  agg = pd.concat(cols, axis=1)
  agg.columns = names
  # drop rows with NaN values
  if dropnan:
      agg.dropna(inplace=True)
  return agg

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 하나 대상 예측하기

# %%
dongs
# Out:
# array(['효창동', '대방동', '답십리동', '삼성동', '공릉동', '개포동', '논현동', '자양동', '방배동',
#        '일원동', '서초동', '사당동', '반포동', '양평동1가', '정동', '상도동', '신정동', '마곡동',
#        '북가좌동', '면목동', '상일동', '장위동', '성수동1가', '방화동', '상계동', '고덕동',
#        '영등포동7가', '증산동', '종암동', '신길동', '홍제동', '신림동', '월계동', '봉천동', '청담동',
#        '구의동', '한강로3가', '대림동', '신대방동', '광장동', '순화동', '당산동5가', '도곡동', '대치동',
#        '황학동', '역삼동', '신사동', '방학동', '목동', '쌍문동', '수색동', '응암동', '항동', '신월동',
#        '잠원동', '길동', '남가좌동', '신수동', '대흥동', '휘경동', '독산동', '홍은동', '암사동',
#        '풍납동', '충무로5가', '장안동', '미아동', '석관동', '신당동', '화양동', '명일동', '염창동',
#        '창전동', '길음동', '오금동', '마포동', '무악동', '진관동', '흑석동', '연희동', '녹번동',
#        '가락동', '묵동', '염리동', '중화동', '망원동', '창동', '전농동', '문래동5가', '행당동',
#        '영등포동', '북아현동', '금호동1가', '금호동4가', '만리동2가', '옥수동', '한강로2가', '시흥동',
#        '당산동4가', '묵정동', '천호동', '하왕십리동', '교남동', '한남동', '아현동', '평동', '홍파동',
#        '효제동', '보문동6가', '장지동', '돈암동', '신내동', '합정동', '성내동', '수서동', '금호동2가',
# ...

# %%
df_대방동
# Out:
#             아파트코드            시군구  읍면동   층  건축년도    주차대수       범죄율  건물연식  \
# 계약년월
# 201202  A10023859  서울특별시 동작구 대방동  대방동   4  2005   997.0  0.810248     0
# 201205  A10023859  서울특별시 동작구 대방동  대방동  10  2005   997.0  0.810248     0
# 201302  A10023859  서울특별시 동작구 대방동  대방동   8  2005   997.0  0.810248     0
# 201303  A10023859  서울특별시 동작구 대방동  대방동  18  2005   997.0  0.810248     0
# 201304  A10023859  서울특별시 동작구 대방동  대방동   1  2005   997.0  0.810248     0
# ...           ...            ...  ...  ..   ...     ...       ...   ...
# 202103  A15681110  서울특별시 동작구 대방동  대방동   7  1993  1795.0  0.810248     3
# 202105  A15681110  서울특별시 동작구 대방동  대방동  12  1993  1795.0  0.810248     3
# 202106  A15681110  서울특별시 동작구 대방동  대방동  15  1993  1795.0  0.810248     3
# 202107  A15681110  서울특별시 동작구 대방동  대방동   5  1993  1795.0  0.810248     3
# 202109  A15681110  서울특별시 동작구 대방동  대방동  18  1993  1795.0  0.810248     3
#
#         대규모점포_거리  버스정류장_거리  ...  주택시장소비심리지수     미분양  분양형태_분양  분양형태_영구임대  \
# ...

# %%
df = df_대방동
codes = df['아파트구분'].unique()
codes
groups = df.groupby(df.아파트구분)
for i in codes:
    globals()['df_'+i] = groups.get_group(i)
df_all = pd.DataFrame()
for i in codes:
    df1 = globals()['df_'+i]
    df1 = df1[['price','층', '건축년도', '주차대수', '범죄율', '건물연식', 
    '대규모점포_거리','버스정류장_거리', '지하철역_거리', '학교_거리', 
    '유치원_거리', '병원_거리', '아파트매매가격지수', '주택구매력지수','PIR',
    'LIR','GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수','M2통화량(평잔,십억원)', 
    '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', 
    '분양형태_임대','분양형태_임대+분양', 'area', 'date']]
    values = df1.values
    values = values.astype('float32')
    reframed = series_to_supervised(values, 3, 1)
    reframed.drop(reframed.columns[91:119], axis=1, inplace=True)
    reframed.drop(reframed.columns[31:60], axis=1, inplace=True)
    reframed.drop(reframed.columns[1:30], axis=1, inplace=True)
    df_all = pd.concat([reframed,df_all])

# %%
train_set = df_all[df_all['var30(t)']<202000]
df_test = df_A15681110_80
df_test = df_test[['price','층', '건축년도', '주차대수', '범죄율', '건물연식', 
'대규모점포_거리','버스정류장_거리', '지하철역_거리', '학교_거리', 
'유치원_거리', '병원_거리', '아파트매매가격지수', '주택구매력지수','PIR',
'LIR','GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수','M2통화량(평잔,십억원)', 
'주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', 
'분양형태_임대','분양형태_임대+분양', 'area', 'date']]
values = df_test.values
values = values.astype('float32')
reframed = series_to_supervised(values, 3, 1)
reframed
reframed.drop(reframed.columns[91:119], axis=1, inplace=True)
reframed.drop(reframed.columns[31:60], axis=1, inplace=True)
reframed.drop(reframed.columns[1:30], axis=1, inplace=True)
test_set = reframed[reframed['var30(t)']>=202000]
df_set = pd.concat([train_set,test_set])
df_set
df_set.pop('var30(t)')
values=df_set.values
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days, :]
test = values[train_days:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=50, batch_size=72,validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 13/13 - 6s - loss: 0.1081 - val_loss: 0.2080 - 6s/epoch - 433ms/step
# Epoch 2/50
# 13/13 - 0s - loss: 0.0865 - val_loss: 0.2525 - 122ms/epoch - 9ms/step
# Epoch 3/50
# 13/13 - 0s - loss: 0.0669 - val_loss: 0.2017 - 144ms/epoch - 11ms/step
# Epoch 4/50
# 13/13 - 0s - loss: 0.0572 - val_loss: 0.1660 - 134ms/epoch - 10ms/step
# Epoch 5/50
# 13/13 - 0s - loss: 0.0515 - val_loss: 0.1549 - 130ms/epoch - 10ms/step
# Epoch 6/50
# 13/13 - 0s - loss: 0.0450 - val_loss: 0.1498 - 140ms/epoch - 11ms/step
# Epoch 7/50
# 13/13 - 0s - loss: 0.0391 - val_loss: 0.1354 - 125ms/epoch - 10ms/step
# Epoch 8/50
# 13/13 - 0s - loss: 0.0334 - val_loss: 0.1138 - 126ms/epoch - 10ms/step
# Epoch 9/50
# 13/13 - 0s - loss: 0.0290 - val_loss: 0.0990 - 114ms/epoch - 9ms/step
# Epoch 10/50
# 13/13 - 0s - loss: 0.0270 - val_loss: 0.1029 - 117ms/epoch - 9ms/step
# Epoch 11/50
# 13/13 - 0s - loss: 0.0254 - val_loss: 0.1044 - 131ms/epoch - 10ms/step
# Epoch 12/50
# ...

# %%
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
inv_yhat = concatenate((yhat, test_X[:, :]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_y, test_X[:, 0:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]
# Out:
# 1/1 [==============================] - 1s 656ms/step

# %%
import matplotlib.pyplot as plt
plt.plot(inv_y)
plt.plot(inv_yhat)
plt.show()

# %%
inv_y
# Out:
# array([ 94377.88 , 107299.79 , 106376.8  , 112376.24 , 117129.66 ,
#        118837.195, 108684.266, 123452.17 , 126682.65 , 123129.125,
#        136327.94 , 116529.71 , 147450.   , 137758.58 ], dtype=float32)

# %%
inv_yhat
# Out:
# array([ 87007.67 ,  90530.5  ,  92304.62 ,  93762.05 ,  98014.51 ,
#        101029.31 , 104274.92 , 104757.92 , 106305.016, 107121.55 ,
#        113242.23 , 116632.51 , 115033.96 , 121018.44 ], dtype=float32)

# %%
df_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23208\2435861599.py in <module>
# ----> 1 df_test
#
# NameError: name 'df_test' is not defined

# %% [markdown]
# 전체 구하기

# %%
dongs = df['읍면동'].unique()
for i in dongs:
    dong_df = globals()['df_'+i]
    codes = dong_df['아파트구분'].unique()
    groups = dong_df.groupby(dong_df.아파트구분)
    df_all = pd.DataFrame()
    for j in codes:
        for k in codes:
        df1 = globals()['df_'+j]
        df1 = df1[['price','층', '건축년도', '주차대수', '범죄율', '건물연식', 
        '대규모점포_거리','버스정류장_거리', '지하철역_거리', '학교_거리', 
        '유치원_거리', '병원_거리', '아파트매매가격지수', '주택구매력지수','PIR',
        'LIR','GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수','M2통화량(평잔,십억원)', 
        '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', 
        '분양형태_임대','분양형태_임대+분양', 'area', 'date']]
        values = df1.values
        values = values.astype('float32')
        reframed = series_to_supervised(values, 3, 1)
        reframed.drop(reframed.columns[91:119], axis=1, inplace=True)
        reframed.drop(reframed.columns[31:60], axis=1, inplace=True)
        reframed.drop(reframed.columns[1:30], axis=1, inplace=True)
        df_all = pd.concat([reframed,df_all])
        train_set = df_all[df_all['var30(t)']<202000]
        globals()['df_'+j] = groups.get_group(j)
        df_test = globals()['df_'+j]
        df_test = df_test[['price','층', '건축년도', '주차대수', '범죄율', '건물연식', 
        '대규모점포_거리','버스정류장_거리', '지하철역_거리', '학교_거리', 
        '유치원_거리', '병원_거리', '아파트매매가격지수', '주택구매력지수','PIR',
        'LIR','GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수','M2통화량(평잔,십억원)', 
        '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', 
        '분양형태_임대','분양형태_임대+분양', 'area', 'date']]
        values = df_test.values
        values = values.astype('float32')
        reframed = series_to_supervised(values, 3, 1)
        reframed.drop(reframed.columns[91:119], axis=1, inplace=True)
        reframed.drop(reframed.columns[31:60], axis=1, inplace=True)
        reframed.drop(reframed.columns[1:30], axis=1, inplace=True)
        test_set = reframed[reframed['var30(t)']>=202000]
        df_set = pd.concat([train_set,test_set])
        df_set.pop('var30(t)')
        values=df_set.values
        scaled = scaler.fit_transform(values)
        values = scaled
        train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
        train = values[:train_days, :]
        test = values[train_days:, :]
        # split into input and outputs
        train_X, train_y = train[:, :-1], train[:, -1]
        test_X, test_y = test[:, :-1], test[:, -1]
        # reshape input to be 3D [samples, timesteps, features]
        train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
        test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
        model = Sequential()
        model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
        model.add(Dense(1))
        model.compile(loss='mae', optimizer='adam')
        history = model.fit(train_X, train_y, epochs=50, batch_size=72,validation_data=(test_X, test_y), verbose=2, shuffle=False)
        #오류 부분
        yhat = model.predict(test_X)
        test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
        inv_yhat = concatenate((yhat, test_X[:, :]), axis=1)
        inv_yhat = scaler.inverse_transform(inv_yhat)
        inv_yhat = inv_yhat[:,0]
        test_y = test_y.reshape((len(test_y), 1))
        inv_y = concatenate((test_y, test_X[:, 0:]), axis=1)
        inv_y = scaler.inverse_transform(inv_y)
        inv_y = inv_y[:,0]
        #예측값을 데이터 프레임에 추가
        globals()['df_'+j]['예측주택가'] = inv_yhat
        plt.plot(inv_y)
        plt.plot(inv_yhat)
plt.show()
# Out:
# Epoch 1/50
# 1/1 - 3s - loss: 0.2546 - 3s/epoch - 3s/step
# Epoch 2/50
# 1/1 - 0s - loss: 0.2289 - 32ms/epoch - 32ms/step
# Epoch 3/50
# 1/1 - 0s - loss: 0.2033 - 42ms/epoch - 42ms/step
# Epoch 4/50
# 1/1 - 0s - loss: 0.1777 - 66ms/epoch - 66ms/step
# Epoch 5/50
# 1/1 - 0s - loss: 0.1520 - 60ms/epoch - 60ms/step
# Epoch 6/50
# 1/1 - 0s - loss: 0.1362 - 51ms/epoch - 51ms/step
# Epoch 7/50
# 1/1 - 0s - loss: 0.1359 - 50ms/epoch - 50ms/step
# Epoch 8/50
# 1/1 - 0s - loss: 0.1372 - 74ms/epoch - 74ms/step
# Epoch 9/50
# 1/1 - 0s - loss: 0.1409 - 62ms/epoch - 62ms/step
# Epoch 10/50
# 1/1 - 0s - loss: 0.1452 - 68ms/epoch - 68ms/step
# Epoch 11/50
# 1/1 - 0s - loss: 0.1460 - 80ms/epoch - 80ms/step
# Epoch 12/50
# 1/1 - 0s - loss: 0.1441 - 50ms/epoch - 50ms/step
# Epoch 13/50
# 1/1 - 0s - loss: 0.1400 - 72ms/epoch - 72ms/step
# Epoch 14/50
# 1/1 - 0s - loss: 0.1341 - 73ms/epoch - 73ms/step
# Epoch 15/50
# 1/1 - 0s - loss: 0.1283 - 72ms/epoch - 72ms/step
# Epoch 16/50
# ...

# %%
train_set = df_all[df_all['var16(t)']<202000]

# %%
df_all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22052\75778253.py in <module>
# ----> 1 df_all
#
# NameError: name 'df_all' is not defined

# %%
reframed
# Out:
#        var1(t-3)     var1(t-2)     var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  \
# 3   25900.000000  30000.000000  35000.000000        2.0     1972.0      465.0
# 4   30000.000000  35000.000000  34000.000000        5.0     1972.0      465.0
# 5   35000.000000  34000.000000  36500.000000        5.0     1972.0      465.0
# 6   34000.000000  36500.000000  36500.000000        5.0     1972.0      465.0
# 7   36500.000000  36500.000000  36933.332031        3.0     1972.0      465.0
# 8   36500.000000  36933.332031  38000.000000        5.0     1972.0      465.0
# 9   36933.332031  38000.000000  39000.000000        1.0     1972.0      465.0
# 10  38000.000000  39000.000000  40000.000000        4.0     1972.0      465.0
#
#     var5(t-1)  var6(t-1)  var7(t-1)  var8(t-1)  ...  var23(t-1)  var24(t-1)  \
# 3    1.255041        0.0   0.396775   0.063954  ...  120.099998       788.0
# 4    1.255041        0.0   0.396775   0.063954  ...  124.699997       651.0
# ...

# %%
reframed[][:-2]
# Out:
#   File "C:\Users\46861\AppData\Local\Temp\ipykernel_22052\3487284891.py", line 1
#     reframed[][:-2]
#              ^
# SyntaxError: invalid syntax

# %%
df_A10078902_80.keys()
# Out:
# Index(['아파트코드', '시군구', '읍면동', '층', '건축년도', '주차대수', '범죄율', '건물연식', '대규모점포_거리',
#        '버스정류장_거리', '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '아파트매매가격지수', '년도',
#        '월', '주택구매력지수', 'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수',
#        'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', '분양형태_임대',
#        '분양형태_임대+분양', 'area', 'price', '아파트구분', 'date'],
#       dtype='object')

# %%
'price','층', '건축년도', '주차대수', '범죄율', '건물연식', '대규모점포_거리',
       '버스정류장_거리', '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '아파트매매가격지수',
       , '주택구매력지수', 'PIR', 'LIR', 'GDP', 'GDI', 'GNI', '소비자물가지수', '평균코스피지수',
       'M2통화량(평잔,십억원)', '주택시장소비심리지수', '미분양', '분양형태_분양', '분양형태_영구임대', '분양형태_임대',
       '분양형태_임대+분양', 'area', '아파트구분', 'date'
