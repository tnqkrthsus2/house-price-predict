# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final3_english.csv',encoding='cp949')

# %%
df
# Out:
#        apart_code  YYYYMM            apart__name        sigungu town_name  \
# 0       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 1       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 2       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 3       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 4       A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동       종암동
# ...           ...     ...                    ...            ...       ...
# 725063  A15776004  202207                    현대3  서울특별시 강서구 염창동       염창동
# 725064  A15807701  202207                  세양청마루  서울특별시 양천구 신정동       신정동
# 725065  A15882107  202207                    금호1   서울특별시 양천구 목동        목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동       진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동       진관동
#
#                        address sale_type  area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양   101.81      1        1978  ...
# 1            서울특별시 서초구 효령로 391     임대+분양   101.10     11        1978  ...
# 2            서울특별시 서초구 효령로 391     임대+분양    77.71      6        1978  ...
# 3            서울특별시 서초구 효령로 391     임대+분양   101.10      3        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대    84.73      5        2005  ...
# ...                        ...       ...      ...    ...         ...  ...
# 725063     서울특별시 강서구 양천로75길 60        분양    59.92      1        1996  ...
# 725064  서울특별시 양천구 목동남로2길 60-30        분양    84.98      9        2006  ...
# 725065      서울특별시 양천구 목동동로 258        분양    84.96     22        1997  ...
# 725066     서울특별시 은평구 진관2로 57-7        분양    84.54      8        2009  ...
# 725067     서울특별시 은평구 연서로48길 12        분양   101.83      5        2010  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 1       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 2       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 3       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 725063       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725064       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725065       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725066       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725067       NaN       NaN       NaN  108.740           NaN  2,451.50
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 1       1757058.7       106.0  1890.0   81200
# 2       1757058.7       106.0  1890.0   64000
# 3       1757058.7       106.0  1890.0   78800
# 4       1757058.7       106.0  1890.0   46000
# ...           ...         ...     ...     ...
# 725063        NaN         NaN     NaN   64600
# 725064        NaN         NaN     NaN   95000
# 725065        NaN         NaN     NaN  115000
# 725066        NaN         NaN     NaN   93000
# 725067        NaN         NaN     NaN  103000
#
# [725068 rows x 37 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df_vary = df.drop_duplicates(['apart_code'])

# %%
df_vary
# Out:
#        apart_code  YYYYMM apart__name         sigungu town_name  \
# 0       A10024240  201201         무지개   서울특별시 서초구 서초동       서초동
# 4       A10024603  201201   아이파크종암동2차   서울특별시 성북구 종암동       종암동
# 7       A10024621  201201          태흥   서울특별시 관악구 신림동       신림동
# 8       A10024636  201201       세양청마루   서울특별시 노원구 월계동       월계동
# 9       A10024638  201201    관악월드메르디앙   서울특별시 관악구 봉천동       봉천동
# ...           ...     ...         ...             ...       ...
# 721832  A10025013  202204  사당롯데캐슬골든포레   서울특별시 동작구 사당동       사당동
# 723079  A10024098  202205  보라매자이더포레스트  서울특별시 동작구 신대방동      신대방동
# 724205  A10023926  202206    롯데캐슬클라시아   서울특별시 성북구 길음동       길음동
# 724206  A10023959  202206  홍제역해링턴플레이스  서울특별시 서대문구 홍제동       홍제동
# 724210  A10024408  202206    공덕SK리더스뷰   서울특별시 마포구 공덕동       공덕동
#
#                        address sale_type   area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양  101.8100      1        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대   84.7300      5        2005  ...
# 7            서울특별시 관악구 호암로 541        분양   59.8600     18        1995  ...
# 8          서울특별시 노원구 석계로13길 35        분양   64.1830      8        2005  ...
# 9          서울특별시 관악구 관악로28길 80        분양   79.2700      6        2005  ...
# ...                        ...       ...       ...    ...         ...  ...
# 721832        서울특별시 동작구 사당로 90        분양   59.9775      7        2021  ...
# 723079  서울특별시 동작구 여의대방로22길 121     임대+분양   59.9365     15        2021  ...
# 724205      서울특별시 성북구 숭인로8길 80     임대+분양   59.8745     15        2022  ...
# 724206     서울특별시 서대문구 세무서8길 30     임대+분양   59.9900     10        2021  ...
# 724210      서울특별시 마포구 백범로31길 7     임대+분양   84.9300     12        2021  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 7       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 8       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 9       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 721832  492124.3  464761.5       0.0  106.850          3.57  2,695.05
# 723079  492124.3  464761.5       0.0  107.560          3.68  2,685.90
# 724205  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724206  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724210  492124.3  464761.5       0.0  108.220          3.90  2,332.64
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 4       1757058.7       106.0  1890.0   46000
# 7       1757058.7       106.0  1890.0   23100
# 8       1757058.7       106.0  1890.0   25700
# 9       1757058.7       106.0  1890.0   35000
# ...           ...         ...     ...     ...
# 721832  3675828.7       110.8   360.0  110000
# 723079  3694489.3       105.2   688.0  115000
# 724205  3714442.7        99.8   719.0  110800
# 724206  3714442.7        99.8   719.0  116000
# 724210  3714442.7        99.8   719.0  190000
#
# [2385 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# apart_code          0
# YYYYMM              0
# apart__name         0
# sigungu             0
# town_name           0
# address             0
# sale_type        2628
# area_m3             0
# floor               0
# const_year          0
# parking          1926
# GPS_X               0
# GPS_Y               0
# crime_rate          0
# building_year       0
# market_dist         0
# busstop_dist        0
# subway_dist         0
# school_dist         0
# kinder_dist         0
# hospital_dist       0
# ASPI                0
# YYYY                0
# MM                  0
# HAI              3269
# PIR              4222
# LIR              4222
# GDP               228
# GDI               228
# GNI               228
# CPI                 0
# avg_interest      228
# cospi               0
# M2                228
# house_CCSI        228
# unsold            228
# prices              0
# dtype: int64

# %%
df = df[df['sale_type'].notna()]
df = df[df['parking'].notna()]
df = df[df['HAI'].notna()]
df = df[df['M2'].notna()]

# %% [markdown]
# 주변의 아파트 구하기

# %%
df_range = df_vary[['apart_code','GPS_X','GPS_Y']]

# %% [markdown]
# A10024240 단지를 중심으로(다음 행 아파트 코드 하나만 수정할시 전체 값 변화)

# %%
gizun_code = 'A41279923'
gizun = df_range[df_range['apart_code']==gizun_code]

# %%
from haversine import haversine

# %%
start = (float(gizun['GPS_Y']),float(gizun['GPS_X']))
near_apts = []
for i in df_range.index:
    goal = (float(df_range['GPS_Y'][i]),float(df_range['GPS_X'][i]))
    if haversine(start, goal) < 3:
        near_apts.append(df_range['apart_code'][i])
near_df = pd.DataFrame()
near_df['apart_code'] = near_apts

# %%
near_df
# Out:
#    apart_code
# 0   A10024774
# 1   A12204002
# 2   A12204003
# 3   A12204004
# 4   A12204102
# 5   A12205004
# 6   A12275201
# 7   A12275202
# 8   A12281701
# 9   A12282102
# 10  A12284501
# 11  A12284701
# 12  A12285703
# 13  A41279902
# 14  A41279910
# 15  A41279918
# 16  A41279920
# 17  A41279923
# 18  A41279924
# 19  A41279927
# 20  B12204002
# 21  A12205001
# 22  A12205003
# 23  A12220004
# 24  A12271402
# 25  A12281702
# 26  A12283601
# 27  A41279901
# 28  A41279904
# 29  A41279907
# 30  A41279908
# 31  A41279909
# 32  A41279922
# 33  A41279925
# 34  A41279926
# 35  A41279929
# 36  A12220005
# 37  A41279903
# 38  A41279911
# 39  A41279912
# 40  A41279913
# 41  A41279915
# 42  A12220001
# 43  A12281801
# 44  A41279905
# 45  A41279914
# 46  A12204001
# 47  A12220003
# 48  A41279906
# 49  A41279916
# 50  A12220002
# 51  A41279917
# 52  A12204006
# 53  A41279932
# 54  A10026414
# 55  A10025836
# 56  A10025765
# 57  A10025846

# %% [markdown]
# near_df 데이터에서 세대수 찾기

# %%
many_df = pd.read_csv('서울시아파트(기준).csv',encoding='cp949')

# %%
near_df = pd.merge(near_df,many_df,left_on='apart_code',right_on='k-아파트코드',how='left')

# %%
near_df
# Out:
#    apart_code     번호    k-아파트코드  k-전체세대수       k-건설사(시공사)
# 0   A10024774  40088  A10024774    111.0         해주개발주식회사
# 1   A12204002    502  A12204002    256.0             대창건설
# 2   A12204003   1837  A12204003    603.0             현대건설
# 3   A12204004   2054  A12204004   1185.0          현대건설(주)
# 4   A12204102   1285  A12204102    662.0          현대건설(주)
# 5   A12205004    793  A12205004    366.0             현대건설
# 6   A12275201   2104  A12275201    647.0             삼성물산
# 7   A12275202   2164  A12275202    882.0             현대건설
# 8   A12281701    215  A12281701    191.0        코오롱건설주식회사
# 9   A12282102    203  A12282102    189.0          이수건설(주)
# 10  A12284501    772  A12284501    357.0         삼성건설주식회사
# 11  A12284701    252  A12284701    198.0            (주)대호
# 12  A12285703   1591  A12285703   1340.0       라이프주택건설(주)
# 13  A41279902   1808  A41279902    318.0           대우푸르지오
# 14  A41279910   1935  A41279910    947.0               현대
# 15  A41279918   2005  A41279918    472.0             두산건설
# 16  A41279920   2033  A41279920    486.0             삼성건설
# 17  A41279923   2067  A41279923    330.0  (주)대우건설 (주)태영건설
# 18  A41279924   2068  A41279924    571.0          현대건설(주)
# 19  A41279927   2103  A41279927    334.0         벽산건설금호건설
# 20  B12204002   3091  B12204002    135.0             삼성물산
# 21  A12205001    260  A12205001    200.0         (주) 강산건설
# 22  A12205003    703  A12205003    327.0               대림
# 23  A12220004   1149  A12220004    551.0          (주)롯데건설
# 24  A12271402   1761  A12271402    175.0          대교 대앤에스
# 25  A12281702    581  A12281702    278.0           현대산업개발
# 26  A12283601    220  A12283601    192.0        현대산업개발(주)
# 27  A41279901   1798  A41279901    300.0           현대산업개발
# 28  A41279904   1817  A41279904    379.0           대우푸르지오
# 29  A41279907   1832  A41279907    187.0           현대산업개발
# 30  A41279908   1856  A41279908    255.0       현대산업개발주식회사
# 31  A41279909   1934  A41279909    162.0             현대건설
# 32  A41279922   2063  A41279922    175.0          대우건설(주)
# 33  A41279925   2074  A41279925    189.0          대우푸르지오
# 34  A41279926   2077  A41279926    126.0             현대건설
# 35  A41279929   2118  A41279929    412.0             대우건설
# 36  A12220005   1320  A12220005    707.0             삼환기업
# 37  A41279903   1811  A41279903    378.0           대우푸르지오
# 38  A41279911   2284  A41279911    660.0             현대건설
# 39  A41279912   1995  A41279912    659.0            포스코건설
# 40  A41279913   1996  A41279913    469.0          동부건걸(주)
# 41  A41279915   2002  A41279915    448.0             금호건설
# 42  A12220001    316  A12220001    208.0           대우푸르지오
# 43  A12281801    225  A12281801    193.0          한솔건설(주)
# 44  A41279905   1825  A41279905    241.0           현대산업개발
# 45  A41279914   1999  A41279914    434.0             동부건설
# 46  A12204001     37  A12204001    155.0               한양
# 47  A12220003    719  A12220003    335.0          롯데건설(주)
# 48  A41279906   1831  A41279906    230.0           현대산업개발
# 49  A41279916   2003  A41279916    387.0       두산건설포스코 건설
# 50  A12220002    651  A12220002    298.0             SH공사
# 51  A41279917   2004  A41279917    353.0               SH
# 52  A12204006   3541  A12204006    488.0          롯데건설(주)
# 53  A41279932   6381  A41279932    426.0               한라
# 54  A10026414  19260  A10026414    260.0          (주)삼전건설
# 55  A10025836  20761  A10025836    952.0          현대힐스테이트
# 56  A10025765  20822  A10025765    361.0            GS 건설
# 57  A10025846  20741  A10025846   1305.0             삼성물산

# %%
near_df = near_df[['apart_code','k-전체세대수']]

# %% [markdown]
# 더 적은 세대수 아파트 삭제

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 0   A10024774    111.0
# 1   A12204002    256.0
# 2   A12204003    603.0
# 3   A12204004   1185.0
# 4   A12204102    662.0
# 5   A12205004    366.0
# 6   A12275201    647.0
# 7   A12275202    882.0
# 8   A12281701    191.0
# 9   A12282102    189.0
# 10  A12284501    357.0
# 11  A12284701    198.0
# 12  A12285703   1340.0
# 13  A41279902    318.0
# 14  A41279910    947.0
# 15  A41279918    472.0
# 16  A41279920    486.0
# 17  A41279923    330.0
# 18  A41279924    571.0
# 19  A41279927    334.0
# 20  B12204002    135.0
# 21  A12205001    200.0
# 22  A12205003    327.0
# 23  A12220004    551.0
# 24  A12271402    175.0
# 25  A12281702    278.0
# 26  A12283601    192.0
# 27  A41279901    300.0
# 28  A41279904    379.0
# 29  A41279907    187.0
# 30  A41279908    255.0
# 31  A41279909    162.0
# 32  A41279922    175.0
# 33  A41279925    189.0
# 34  A41279926    126.0
# 35  A41279929    412.0
# 36  A12220005    707.0
# 37  A41279903    378.0
# 38  A41279911    660.0
# 39  A41279912    659.0
# 40  A41279913    469.0
# 41  A41279915    448.0
# 42  A12220001    208.0
# 43  A12281801    193.0
# 44  A41279905    241.0
# 45  A41279914    434.0
# 46  A12204001    155.0
# 47  A12220003    335.0
# 48  A41279906    230.0
# 49  A41279916    387.0
# 50  A12220002    298.0
# 51  A41279917    353.0
# 52  A12204006    488.0
# 53  A41279932    426.0
# 54  A10026414    260.0
# 55  A10025836    952.0
# 56  A10025765    361.0
# 57  A10025846   1305.0

# %%
gizun_count = near_df[near_df['apart_code']==gizun_code].iloc[0][1]
gizun_count
# Out:
# 330.0

# %%
indexNames = near_df[near_df['k-전체세대수'] < gizun_count].index
near_df.drop(indexNames , inplace=True)
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 2   A12204003    603.0
# 3   A12204004   1185.0
# 4   A12204102    662.0
# 5   A12205004    366.0
# 6   A12275201    647.0
# 7   A12275202    882.0
# 10  A12284501    357.0
# 12  A12285703   1340.0
# 14  A41279910    947.0
# 15  A41279918    472.0
# 16  A41279920    486.0
# 17  A41279923    330.0
# 18  A41279924    571.0
# 19  A41279927    334.0
# 23  A12220004    551.0
# 28  A41279904    379.0
# 35  A41279929    412.0
# 36  A12220005    707.0
# 37  A41279903    378.0
# 38  A41279911    660.0
# 39  A41279912    659.0
# 40  A41279913    469.0
# 41  A41279915    448.0
# 45  A41279914    434.0
# 47  A12220003    335.0
# 49  A41279916    387.0
# 51  A41279917    353.0
# 52  A12204006    488.0
# 53  A41279932    426.0
# 55  A10025836    952.0
# 56  A10025765    361.0
# 57  A10025846   1305.0

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df = df.astype({'prices':'float64'})

# %%
df['area_m3']=df['area_m3'].round(-1)

# %%
df['prices']=df.groupby(['YYYYMM','apart_code','area_m3'])['prices'].transform('mean')

# %% [markdown]
# 근처에 있는 아파트의 데이터 프레임 생성

# %%
df = pd.merge(near_df,df,on='apart_code')

# %%
df = df.rename(columns={'k-전체세대수':'resident_count'})
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices'],
#       dtype='object')

# %%
df['apart_code_area'] = df['apart_code'].map(str) +'_' +df['area_m3'].map(int).map(str)

# %%
df
# Out:
#      apart_code  resident_count  YYYYMM    apart__name        sigungu  \
# 0     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 1     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 2     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 3     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 4     A12204003           603.0  201202  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# ...         ...             ...     ...            ...            ...
# 7029  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 7030  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 7031  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 7032  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 7033  A10025846          1305.0  202202        래미안베라힐즈  서울특별시 은평구 녹번동
#
#      town_name             address sale_type  area_m3  floor  ...       GDI  \
# 0          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      7  ...  343229.4
# 1          불광동  서울특별시 은평구 불광로2길 33        분양     80.0     10  ...  343229.4
# 2          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      9  ...  343229.4
# 3          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      2  ...  343229.4
# 4          불광동  서울특별시 은평구 불광로2길 33        분양     60.0      4  ...  343229.4
# ...        ...                 ...       ...      ...    ...  ...       ...
# 7029       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0      5  ...  487122.0
# 7030       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0      3  ...  487122.0
# 7031       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0     14  ...  487122.0
# 7032       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0      7  ...  487122.0
# 7033       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0     14  ...  450242.2
#
#            GNI      CPI  avg_interest     cospi         M2  house_CCSI  \
# 0     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 1     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 2     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 3     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 4     345819.5   91.588          5.71  2,030.25  1762988.4       111.3
# ...        ...      ...           ...       ...        ...         ...
# 7029  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 7030  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 7031  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 7032  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 7033  455546.7  105.300          3.51  2,699.18  3656135.8       103.4
#
#       unsold         prices  apart_code_area
# 0     1890.0   49325.000000     A12204003_80
# 1     1890.0   49325.000000     A12204003_80
# 2     1890.0   49325.000000     A12204003_80
# 3     1890.0   49325.000000     A12204003_80
# 4     1703.0   37000.000000     A12204003_60
# ...      ...            ...              ...
# 7029    54.0  107000.000000     A10025846_60
# 7030    54.0  129333.333333     A10025846_80
# 7031    54.0  129333.333333     A10025846_80
# 7032    54.0  129333.333333     A10025846_80
# 7033    47.0  107000.000000     A10025846_60
#
# [7034 rows x 39 columns]

# %%
df = df.drop_duplicates(subset=['apart_code_area','YYYYMM'])

# %%
df = df.sort_values(by=["apart_code_area", "YYYYMM"], ascending=[True, True])

# %%
df
# Out:
#      apart_code  resident_count  YYYYMM   apart__name        sigungu  \
# 6967  A10025765           361.0  202008      은평스카이뷰자이  서울특별시 은평구 진관동
# 6970  A10025765           361.0  202010      은평스카이뷰자이  서울특별시 은평구 진관동
# 6971  A10025765           361.0  202011      은평스카이뷰자이  서울특별시 은평구 진관동
# 6972  A10025765           361.0  202012      은평스카이뷰자이  서울특별시 은평구 진관동
# 6974  A10025765           361.0  202101      은평스카이뷰자이  서울특별시 은평구 진관동
# ...         ...             ...     ...           ...            ...
# 6907  A41279932           426.0  202105  은평뉴타운기자촌11단지  서울특별시 은평구 진관동
# 6909  A41279932           426.0  202106  은평뉴타운기자촌11단지  서울특별시 은평구 진관동
# 6912  A41279932           426.0  202107  은평뉴타운기자촌11단지  서울특별시 은평구 진관동
# 6914  A41279932           426.0  202108  은평뉴타운기자촌11단지  서울특별시 은평구 진관동
# 6915  A41279932           426.0  202112  은평뉴타운기자촌11단지  서울특별시 은평구 진관동
#
#      town_name             address sale_type  area_m3  floor  ...       GDI  \
# 6967       진관동  서울특별시 은평구 통일로 1034        분양     80.0      7  ...  454712.9
# 6970       진관동  서울특별시 은평구 통일로 1034        분양     80.0     33  ...  480138.7
# 6971       진관동  서울특별시 은평구 통일로 1034        분양     80.0     17  ...  480138.7
# 6972       진관동  서울특별시 은평구 통일로 1034        분양     80.0     28  ...  480138.7
# 6974       진관동  서울특별시 은평구 통일로 1034        분양     80.0     10  ...  450518.8
# ...        ...                 ...       ...      ...    ...  ...       ...
# 6907       진관동  서울특별시 은평구 연서로46길 7     임대+분양     80.0      4  ...  467060.3
# 6909       진관동  서울특별시 은평구 연서로46길 7     임대+분양     80.0      6  ...  467060.3
# 6912       진관동  서울특별시 은평구 연서로46길 7     임대+분양     80.0      4  ...  466346.0
# 6914       진관동  서울특별시 은평구 연서로46길 7     임대+분양     80.0      1  ...  466346.0
# 6915       진관동  서울특별시 은평구 연서로46길 7     임대+분양     80.0      9  ...  487122.0
#
#            GNI     CPI  avg_interest     cospi         M2  house_CCSI  unsold  \
# 6967  458855.5  100.19          2.63  2,326.17  3100373.4       127.7    56.0
# 6970  486940.6  100.18          2.66  2,267.15  3152811.6       132.0    52.0
# 6971  486940.6  100.09          2.71  2,591.34  3183500.9       134.5    52.0
# 6972  486940.6  100.33          2.74  2,873.47  3197671.2       133.5    49.0
# 6974  457211.8  101.04          2.72  2,976.21  3223486.7       131.5    49.0
# ...        ...     ...           ...       ...        ...         ...     ...
# 6907  470984.9  102.05          2.72  3,203.92  3379753.9       127.5    71.0
# 6909  470984.9  102.05          2.77  3,296.68  3413899.8       131.3    65.0
# 6912  471235.4  102.26          2.77  3,202.32  3445243.0       133.3    59.0
# 6914  471235.4  102.75          2.87  3,199.27  3487634.1       135.1    55.0
# 6915  492461.1  104.04          3.25  2,977.65  3620057.4       103.2    54.0
#
#              prices  apart_code_area
# 6967  109500.000000     A10025765_80
# 6970  105000.000000     A10025765_80
# 6971  123000.000000     A10025765_80
# 6972  119500.000000     A10025765_80
# 6974  119933.333333     A10025765_80
# ...             ...              ...
# 6907   88625.000000     A41279932_80
# 6909   89245.000000     A41279932_80
# 6912   90500.000000     A41279932_80
# 6914   89000.000000     A41279932_80
# 6915   96000.000000     A41279932_80
#
# [3240 rows x 39 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices', 'apart_code_area'],
#       dtype='object')

# %%
df = df[['apart_code_area','resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
       'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
       'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
       'house_CCSI', 'unsold', 'prices']]

# %% [markdown]
# 분양타입 변경

# %%
df['sale_type']
# Out:
# 6967       분양
# 6970       분양
# 6971       분양
# 6972       분양
# 6974       분양
#         ...
# 6907    임대+분양
# 6909    임대+분양
# 6912    임대+분양
# 6914    임대+분양
# 6915    임대+분양
# Name: sale_type, Length: 3240, dtype: object

# %%
df.loc[df['sale_type'] == '분양', 'sale_type'] = 0
df.loc[df['sale_type'] == '임대+분양', 'sale_type'] = 1
df.loc[df['sale_type'] == '임대', 'sale_type'] = 2
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df
# Out:
#      apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 6967    A10025765_80           361.0         0  202008     80.0      7
# 6970    A10025765_80           361.0         0  202010     80.0     33
# 6971    A10025765_80           361.0         0  202011     80.0     17
# 6972    A10025765_80           361.0         0  202012     80.0     28
# 6974    A10025765_80           361.0         0  202101     80.0     10
# ...              ...             ...       ...     ...      ...    ...
# 6907    A41279932_80           426.0         1  202105     80.0      4
# 6909    A41279932_80           426.0         1  202106     80.0      6
# 6912    A41279932_80           426.0         1  202107     80.0      4
# 6914    A41279932_80           426.0         1  202108     80.0      1
# 6915    A41279932_80           426.0         1  202112     80.0      9
#
#       parking  crime_rate  building_year  market_dist  ...       GDP  \
# 6967    454.0    0.710015              3     0.365229  ...  459981.3
# 6970    454.0    0.710015              3     0.365229  ...  485291.5
# 6971    454.0    0.710015              3     0.365229  ...  485291.5
# 6972    454.0    0.710015              3     0.365229  ...  485291.5
# 6974    454.0    0.710015              3     0.365229  ...  453751.7
# ...       ...         ...            ...          ...  ...       ...
# 6907    495.0    0.710015              7     1.638995  ...  478264.5
# 6909    495.0    0.710015              7     1.638995  ...  478264.5
# 6912    495.0    0.710015              7     1.638995  ...  478189.5
# 6914    495.0    0.710015              7     1.638995  ...  478189.5
# 6915    495.0    0.710015              7     1.638995  ...  505571.7
#
#            GDI       GNI     CPI  avg_interest     cospi         M2  \
# 6967  454712.9  458855.5  100.19          2.63  2,326.17  3100373.4
# 6970  480138.7  486940.6  100.18          2.66  2,267.15  3152811.6
# 6971  480138.7  486940.6  100.09          2.71  2,591.34  3183500.9
# 6972  480138.7  486940.6  100.33          2.74  2,873.47  3197671.2
# 6974  450518.8  457211.8  101.04          2.72  2,976.21  3223486.7
# ...        ...       ...     ...           ...       ...        ...
# 6907  467060.3  470984.9  102.05          2.72  3,203.92  3379753.9
# 6909  467060.3  470984.9  102.05          2.77  3,296.68  3413899.8
# 6912  466346.0  471235.4  102.26          2.77  3,202.32  3445243.0
# 6914  466346.0  471235.4  102.75          2.87  3,199.27  3487634.1
# 6915  487122.0  492461.1  104.04          3.25  2,977.65  3620057.4
#
#       house_CCSI  unsold         prices
# 6967       127.7    56.0  109500.000000
# 6970       132.0    52.0  105000.000000
# 6971       134.5    52.0  123000.000000
# 6972       133.5    49.0  119500.000000
# 6974       131.5    49.0  119933.333333
# ...          ...     ...            ...
# 6907       127.5    71.0   88625.000000
# 6909       131.3    65.0   89245.000000
# 6912       133.3    59.0   90500.000000
# 6914       135.1    55.0   89000.000000
# 6915       103.2    54.0   96000.000000
#
# [3240 rows x 31 columns]

# %% [markdown]
# df를 csv파일로 내보낸다

# %%
#df.to_csv('반경3km위주의 상관관계확인.csv')

# %%
#코스피 행 변환
for i in df.index:
    if type(df['cospi'][i]) == str:
        df['cospi'][i] = df['cospi'][i].replace(',','')
    else: 
        df['cospi'][i] = df['cospi'][i]
df
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 6967    A10025765_80           361.0         0  202008     80.0      7
# 6970    A10025765_80           361.0         0  202010     80.0     33
# 6971    A10025765_80           361.0         0  202011     80.0     17
# 6972    A10025765_80           361.0         0  202012     80.0     28
# 6974    A10025765_80           361.0         0  202101     80.0     10
# ...              ...             ...       ...     ...      ...    ...
# 6907    A41279932_80           426.0         1  202105     80.0      4
# 6909    A41279932_80           426.0         1  202106     80.0      6
# 6912    A41279932_80           426.0         1  202107     80.0      4
# 6914    A41279932_80           426.0         1  202108     80.0      1
# 6915    A41279932_80           426.0         1  202112     80.0      9
#
#       parking  crime_rate  building_year  market_dist  ...       GDP  \
# 6967    454.0    0.710015              3     0.365229  ...  459981.3
# 6970    454.0    0.710015              3     0.365229  ...  485291.5
# 6971    454.0    0.710015              3     0.365229  ...  485291.5
# 6972    454.0    0.710015              3     0.365229  ...  485291.5
# 6974    454.0    0.710015              3     0.365229  ...  453751.7
# ...       ...         ...            ...          ...  ...       ...
# 6907    495.0    0.710015              7     1.638995  ...  478264.5
# 6909    495.0    0.710015              7     1.638995  ...  478264.5
# 6912    495.0    0.710015              7     1.638995  ...  478189.5
# 6914    495.0    0.710015              7     1.638995  ...  478189.5
# 6915    495.0    0.710015              7     1.638995  ...  505571.7
#
#            GDI       GNI     CPI  avg_interest    cospi         M2  \
# 6967  454712.9  458855.5  100.19          2.63  2326.17  3100373.4
# 6970  480138.7  486940.6  100.18          2.66  2267.15  3152811.6
# 6971  480138.7  486940.6  100.09          2.71  2591.34  3183500.9
# 6972  480138.7  486940.6  100.33          2.74  2873.47  3197671.2
# 6974  450518.8  457211.8  101.04          2.72  2976.21  3223486.7
# ...        ...       ...     ...           ...      ...        ...
# 6907  467060.3  470984.9  102.05          2.72  3203.92  3379753.9
# 6909  467060.3  470984.9  102.05          2.77  3296.68  3413899.8
# 6912  466346.0  471235.4  102.26          2.77  3202.32  3445243.0
# 6914  466346.0  471235.4  102.75          2.87  3199.27  3487634.1
# 6915  487122.0  492461.1  104.04          3.25  2977.65  3620057.4
#
#       house_CCSI  unsold         prices
# 6967       127.7    56.0  109500.000000
# 6970       132.0    52.0  105000.000000
# 6971       134.5    52.0  123000.000000
# 6972       133.5    49.0  119500.000000
# 6974       131.5    49.0  119933.333333
# ...          ...     ...            ...
# 6907       127.5    71.0   88625.000000
# 6909       131.3    65.0   89245.000000
# 6912       133.3    59.0   90500.000000
# 6914       135.1    55.0   89000.000000
# 6915       103.2    54.0   96000.000000
#
# [3240 rows x 31 columns]

# %%
codes = df['apart_code_area'].unique()
groups = df.groupby(df.apart_code_area)
for i in codes:
    globals()['df_'+i] = groups.get_group(i)

# %%
codes
# Out:
# array(['A10025765_80', 'A10025836_50', 'A10025836_60', 'A10025836_80',
#        'A10025846_110', 'A10025846_60', 'A10025846_80', 'A12204003_110',
#        'A12204003_60', 'A12204003_80', 'A12204004_120', 'A12204004_130',
#        'A12204004_60', 'A12204004_80', 'A12204006_110', 'A12204006_60',
#        'A12204006_80', 'A12204102_110', 'A12204102_60', 'A12204102_80',
#        'A12205004_110', 'A12205004_50', 'A12205004_60', 'A12205004_80',
#        'A12220003_100', 'A12220003_130', 'A12220003_170', 'A12220003_60',
#        'A12220003_80', 'A12220004_100', 'A12220004_130', 'A12220004_80',
#        'A12220005_100', 'A12220005_130', 'A12220005_80', 'A12275201_110',
#        'A12275201_60', 'A12275201_80', 'A12275202_110', 'A12275202_140',
#        'A12275202_60', 'A12275202_80', 'A12284501_120', 'A12284501_60',
#        'A12284501_80', 'A12285703_130', 'A12285703_70', 'A12285703_80',
#        'A41279903_100', 'A41279903_130', 'A41279903_170', 'A41279903_80',
#        'A41279904_100', 'A41279904_130', 'A41279904_80', 'A41279910_100',
#        'A41279910_130', 'A41279910_60', 'A41279910_80', 'A41279911_130',
#        'A41279911_60', 'A41279911_80', 'A41279912_100', 'A41279912_130',
#        'A41279912_170', 'A41279912_60', 'A41279912_80', 'A41279913_130',
#        'A41279913_170', 'A41279913_80', 'A41279914_100', 'A41279914_130',
#        'A41279914_170', 'A41279914_60', 'A41279914_80', 'A41279915_100',
#        'A41279915_130', 'A41279915_170', 'A41279915_80', 'A41279916_100',
#        'A41279916_130', 'A41279916_60', 'A41279916_80', 'A41279917_100',
#        'A41279917_130', 'A41279917_170', 'A41279917_80', 'A41279918_100',
#        'A41279918_130', 'A41279918_170', 'A41279918_80', 'A41279920_100',
#        'A41279920_130', 'A41279920_170', 'A41279920_80', 'A41279923_100',
#        'A41279923_130', 'A41279923_80', 'A41279924_100', 'A41279924_130',
#        'A41279924_170', 'A41279927_100', 'A41279927_130', 'A41279927_170',
#        'A41279927_80', 'A41279929_100', 'A41279929_130', 'A41279929_80',
#        'A41279932_60', 'A41279932_80'], dtype=object)

# %% [markdown]
# df_A10024240_100를 테스트 데이터로 선택

# %%
gizun_code_area = df[df['apart_code_area'].str.contains(gizun_code)]['apart_code_area'].iloc[0]
gizun_df = globals()['df_'+gizun_code_area]

# %%
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow import keras
import numpy as np
from numpy import concatenate
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
  n_vars = 1 if type(data) is list else data.shape[1]
  df = pd.DataFrame(data)
  cols, names = list(), list()
  # input sequence (t-n, ... t-1)
  for i in range(n_in, 0, -1):
      cols.append(df.shift(i))
      names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
  # forecast sequence (t, t+1, ... t+n)
  for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
          names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
          names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
  # put it all together
  agg = pd.concat(cols, axis=1)
  agg.columns = names
  # drop rows with NaN values
  if dropnan:
      agg.dropna(inplace=True)
  return agg

# %% [markdown]
# 행 변환하기

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df_all = pd.DataFrame()
#코드에서 해당 아파트 제거
deleted_code = 'df_'+gizun_code_area
codes = np.delete(codes, np.where(codes == deleted_code))
for i in codes:
    df1 = globals()['df_'+i]
    df1 = df1[['resident_count','sale_type',
    'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
    'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
    'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
    'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
    'house_CCSI', 'unsold', 'sale_type','prices']]
    values = df1.values
    values = values.astype('float32')
    reframed = series_to_supervised(values, 3, 1)
    reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
    reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
    reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
    df_all = pd.concat([reframed,df_all])

# %%
df_all
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    40735.000000   41402.566406   41198.890625    426.0      1.0  201504.0
# 4    41402.566406   41198.890625   40693.398438    426.0      1.0  201505.0
# 5    41198.890625   40693.398438   39800.000000    426.0      1.0  201506.0
# 6    40693.398438   39800.000000   42000.000000    426.0      1.0  201507.0
# 7    39800.000000   42000.000000   39275.000000    426.0      1.0  201508.0
# ..            ...            ...            ...      ...      ...       ...
# 7   119933.335938  120000.000000  122000.000000    361.0      0.0  202106.0
# 8   120000.000000  122000.000000  118666.664062    361.0      0.0  202108.0
# 9   122000.000000  118666.664062  122100.000000    361.0      0.0  202109.0
# 10  118666.664062  122100.000000  124000.000000    361.0      0.0  202110.0
# 11  122100.000000  124000.000000  125000.000000    361.0      0.0  202201.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 4      80.0     10.0    495.0  0.710015  ...  410707.18750  408330.18750
# 5      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 6      80.0      4.0    495.0  0.710015  ...  415357.40625  417417.31250
# 7      80.0      1.0    495.0  0.710015  ...  415357.40625  417417.31250
# ..      ...      ...      ...       ...  ...           ...           ...
# 7      80.0     13.0    454.0  0.710015  ...  467060.31250  470984.90625
# 8      80.0     28.0    454.0  0.710015  ...  466346.00000  471235.40625
# 9      80.0     19.0    454.0  0.710015  ...  466346.00000  471235.40625
# 10     80.0     13.0    454.0  0.710015  ...  487122.00000  492461.09375
# 11     80.0     18.0    454.0  0.710015  ...  450242.18750  455546.68750
#
#       var24(t)  var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  \
# 3    94.625000      3.36  2127.169922  2148114.75  141.100006     987.0
# 4    94.889999      3.56  2114.800049  2166741.00  137.600006     976.0
# 5    94.908997      3.49  2074.199951  2179561.00  128.600006     638.0
# 6    95.080002      3.43  2030.160034  2200511.00  136.399994     482.0
# 7    95.212997      3.44  1941.489990  2218660.25  135.500000     317.0
# ..         ...       ...          ...         ...         ...       ...
# 7   102.050003      2.77  3296.679932  3413899.75  131.300003      65.0
# 8   102.750000      2.87  3199.270020  3487634.00  135.100006      55.0
# 9   103.169998      2.96  3068.820068  3513680.50  131.800003      55.0
# 10  103.349998      3.07  2970.679932  3543363.75  120.599998      55.0
# 11  104.690002      3.45  2663.340088  3634342.50  101.400002      47.0
#
#     var30(t)       var31(t)
# 3        1.0   40693.398438
# 4        1.0   39800.000000
# 5        1.0   42000.000000
# 6        1.0   39275.000000
# 7        1.0   40000.000000
# ..       ...            ...
# 7        0.0  118666.664062
# 8        0.0  122100.000000
# 9        0.0  124000.000000
# 10       0.0  125000.000000
# 11       0.0  122000.000000
#
# [2915 rows x 34 columns]

# %%
train_set = df_all[df_all['var3(t)']<202000]

# %%
df_test = gizun_df
df_test = df_test[['resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
'house_CCSI', 'unsold', 'sale_type','prices']]
values = df_test.values
values = values.astype('float32')
reframed = series_to_supervised(values, 3, 1)
reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
test_set = reframed[reframed['var3(t)']>=202000]

# %%
df_set = pd.concat([train_set,test_set])
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    40735.000000   41402.566406   41198.890625    426.0      1.0  201504.0
# 4    41402.566406   41198.890625   40693.398438    426.0      1.0  201505.0
# 5    41198.890625   40693.398438   39800.000000    426.0      1.0  201506.0
# 6    40693.398438   39800.000000   42000.000000    426.0      1.0  201507.0
# 7    39800.000000   42000.000000   39275.000000    426.0      1.0  201508.0
# ..            ...            ...            ...      ...      ...       ...
# 48   76100.000000   87000.000000  102750.000000    330.0      0.0  202102.0
# 49   87000.000000  102750.000000  110000.000000    330.0      0.0  202104.0
# 50  102750.000000  110000.000000   90000.000000    330.0      0.0  202106.0
# 51  110000.000000   90000.000000   95000.000000    330.0      0.0  202107.0
# 52   90000.000000   95000.000000  103000.000000    330.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 4      80.0     10.0    495.0  0.710015  ...  410707.18750  408330.18750
# 5      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 6      80.0      4.0    495.0  0.710015  ...  415357.40625  417417.31250
# 7      80.0      1.0    495.0  0.710015  ...  415357.40625  417417.31250
# ..      ...      ...      ...       ...  ...           ...           ...
# 48    100.0     10.0    508.0  0.710015  ...  450518.81250  457211.81250
# 49    100.0      3.0    508.0  0.710015  ...  467060.31250  470984.90625
# 50    100.0      3.0    508.0  0.710015  ...  467060.31250  470984.90625
# 51    100.0      5.0    508.0  0.710015  ...  466346.00000  471235.40625
# 52    100.0      4.0    508.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  \
# 3    94.625000      3.36  2127.169922  2148114.75  141.100006     987.0
# 4    94.889999      3.56  2114.800049  2166741.00  137.600006     976.0
# 5    94.908997      3.49  2074.199951  2179561.00  128.600006     638.0
# 6    95.080002      3.43  2030.160034  2200511.00  136.399994     482.0
# 7    95.212997      3.44  1941.489990  2218660.25  135.500000     317.0
# ..         ...       ...          ...         ...         ...       ...
# 48  101.580002      2.74  3012.949951  3271405.75  129.500000      88.0
# 49  101.980003      2.74  3147.860107  3358875.00  121.800003      76.0
# 50  102.050003      2.77  3296.679932  3413899.75  131.300003      65.0
# 51  102.260002      2.77  3202.320068  3445243.00  133.300003      59.0
# 52  102.750000      2.87  3199.270020  3487634.00  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        1.0   40693.398438
# 4        1.0   39800.000000
# 5        1.0   42000.000000
# 6        1.0   39275.000000
# 7        1.0   40000.000000
# ..       ...            ...
# 48       0.0  110000.000000
# 49       0.0   90000.000000
# 50       0.0   95000.000000
# 51       0.0  103000.000000
# 52       0.0  120500.000000
#
# [2453 rows x 34 columns]

# %%
test_set
# Out:
#     var31(t-3)  var31(t-2)  var31(t-1)  var1(t)  var2(t)   var3(t)  var4(t)  \
# 46     65000.0     71000.0     76100.0    330.0      0.0  202008.0    100.0
# 47     71000.0     76100.0     87000.0    330.0      0.0  202101.0    100.0
# 48     76100.0     87000.0    102750.0    330.0      0.0  202102.0    100.0
# 49     87000.0    102750.0    110000.0    330.0      0.0  202104.0    100.0
# 50    102750.0    110000.0     90000.0    330.0      0.0  202106.0    100.0
# 51    110000.0     90000.0     95000.0    330.0      0.0  202107.0    100.0
# 52     90000.0     95000.0    103000.0    330.0      0.0  202108.0    100.0
#
#     var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)    var24(t)  \
# 46      7.0    508.0  0.710015  ...  454712.90625  458855.50000  100.190002
# 47      6.0    508.0  0.710015  ...  450518.81250  457211.81250  101.040001
# 48     10.0    508.0  0.710015  ...  450518.81250  457211.81250  101.580002
# 49      3.0    508.0  0.710015  ...  467060.31250  470984.90625  101.980003
# 50      3.0    508.0  0.710015  ...  467060.31250  470984.90625  102.050003
# 51      5.0    508.0  0.710015  ...  466346.00000  471235.40625  102.260002
# 52      4.0    508.0  0.710015  ...  466346.00000  471235.40625  102.750000
#
#     var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  var30(t)  \
# 46      2.63  2326.169922  3100373.50  127.699997      56.0       0.0
# 47      2.72  2976.209961  3223486.75  131.500000      49.0       0.0
# 48      2.74  3012.949951  3271405.75  129.500000      88.0       0.0
# 49      2.74  3147.860107  3358875.00  121.800003      76.0       0.0
# 50      2.77  3296.679932  3413899.75  131.300003      65.0       0.0
# 51      2.77  3202.320068  3445243.00  133.300003      59.0       0.0
# 52      2.87  3199.270020  3487634.00  135.100006      55.0       0.0
#
#     var31(t)
# 46   87000.0
# 47  102750.0
# 48  110000.0
# 49   90000.0
# 50   95000.0
# 51  103000.0
# 52  120500.0
#
# [7 rows x 34 columns]

# %% [markdown]
# test

# %%
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    40735.000000   41402.566406   41198.890625    426.0      1.0  201504.0
# 4    41402.566406   41198.890625   40693.398438    426.0      1.0  201505.0
# 5    41198.890625   40693.398438   39800.000000    426.0      1.0  201506.0
# 6    40693.398438   39800.000000   42000.000000    426.0      1.0  201507.0
# 7    39800.000000   42000.000000   39275.000000    426.0      1.0  201508.0
# ..            ...            ...            ...      ...      ...       ...
# 48   76100.000000   87000.000000  102750.000000    330.0      0.0  202102.0
# 49   87000.000000  102750.000000  110000.000000    330.0      0.0  202104.0
# 50  102750.000000  110000.000000   90000.000000    330.0      0.0  202106.0
# 51  110000.000000   90000.000000   95000.000000    330.0      0.0  202107.0
# 52   90000.000000   95000.000000  103000.000000    330.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 4      80.0     10.0    495.0  0.710015  ...  410707.18750  408330.18750
# 5      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.18750
# 6      80.0      4.0    495.0  0.710015  ...  415357.40625  417417.31250
# 7      80.0      1.0    495.0  0.710015  ...  415357.40625  417417.31250
# ..      ...      ...      ...       ...  ...           ...           ...
# 48    100.0     10.0    508.0  0.710015  ...  450518.81250  457211.81250
# 49    100.0      3.0    508.0  0.710015  ...  467060.31250  470984.90625
# 50    100.0      3.0    508.0  0.710015  ...  467060.31250  470984.90625
# 51    100.0      5.0    508.0  0.710015  ...  466346.00000  471235.40625
# 52    100.0      4.0    508.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  \
# 3    94.625000      3.36  2127.169922  2148114.75  141.100006     987.0
# 4    94.889999      3.56  2114.800049  2166741.00  137.600006     976.0
# 5    94.908997      3.49  2074.199951  2179561.00  128.600006     638.0
# 6    95.080002      3.43  2030.160034  2200511.00  136.399994     482.0
# 7    95.212997      3.44  1941.489990  2218660.25  135.500000     317.0
# ..         ...       ...          ...         ...         ...       ...
# 48  101.580002      2.74  3012.949951  3271405.75  129.500000      88.0
# 49  101.980003      2.74  3147.860107  3358875.00  121.800003      76.0
# 50  102.050003      2.77  3296.679932  3413899.75  131.300003      65.0
# 51  102.260002      2.77  3202.320068  3445243.00  133.300003      59.0
# 52  102.750000      2.87  3199.270020  3487634.00  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        1.0   40693.398438
# 4        1.0   39800.000000
# 5        1.0   42000.000000
# 6        1.0   39275.000000
# 7        1.0   40000.000000
# ..       ...            ...
# 48       0.0  110000.000000
# 49       0.0   90000.000000
# 50       0.0   95000.000000
# 51       0.0  103000.000000
# 52       0.0  120500.000000
#
# [2453 rows x 34 columns]

# %%
train_days =  len(train_set)
df_set[:train_days]
# Out:
#       var31(t-3)    var31(t-2)    var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3   40735.000000  41402.566406  41198.890625    426.0      1.0  201504.0
# 4   41402.566406  41198.890625  40693.398438    426.0      1.0  201505.0
# 5   41198.890625  40693.398438  39800.000000    426.0      1.0  201506.0
# 6   40693.398438  39800.000000  42000.000000    426.0      1.0  201507.0
# 7   39800.000000  42000.000000  39275.000000    426.0      1.0  201508.0
# ..           ...           ...           ...      ...      ...       ...
# 19  54250.000000  60000.000000  58100.000000    603.0      0.0  201707.0
# 20  60000.000000  58100.000000  60500.000000    603.0      0.0  201807.0
# 21  58100.000000  60500.000000  61000.000000    603.0      0.0  201808.0
# 22  60500.000000  61000.000000  72811.109375    603.0      0.0  201809.0
# 23  61000.000000  72811.109375  77000.000000    603.0      0.0  201904.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)     var23(t)  \
# 3      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.1875
# 4      80.0     10.0    495.0  0.710015  ...  410707.18750  408330.1875
# 5      80.0     13.0    495.0  0.710015  ...  410707.18750  408330.1875
# 6      80.0      4.0    495.0  0.710015  ...  415357.40625  417417.3125
# 7      80.0      1.0    495.0  0.710015  ...  415357.40625  417417.3125
# ..      ...      ...      ...       ...  ...           ...          ...
# 19    110.0      5.0    680.0  0.710015  ...  451035.18750  455636.8125
# 20    110.0      2.0    680.0  0.710015  ...  452819.18750  456622.6875
# 21    110.0      6.0    680.0  0.710015  ...  452819.18750  456622.6875
# 22    110.0      6.0    680.0  0.710015  ...  452819.18750  456622.6875
# 23    110.0      5.0    680.0  0.710015  ...  451884.50000  451681.3125
#
#       var24(t)  var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  \
# 3    94.625000      3.36  2127.169922  2148114.75  141.100006     987.0
# 4    94.889999      3.56  2114.800049  2166741.00  137.600006     976.0
# 5    94.908997      3.49  2074.199951  2179561.00  128.600006     638.0
# 6    95.080002      3.43  2030.160034  2200511.00  136.399994     482.0
# 7    95.212997      3.44  1941.489990  2218660.25  135.500000     317.0
# ..         ...       ...          ...         ...         ...       ...
# 19   97.499001      3.45  2402.709961  2472110.50  127.599998      41.0
# 20   98.589996      3.67  2295.260010  2637421.75  102.800003      42.0
# 21   99.461998      3.63  2322.879883  2651503.50  115.900002      39.0
# 22  100.221001      3.61  2343.070068  2652829.50  119.300003      29.0
# 23   99.481003      3.65  2203.590088  2763058.00   89.599998     292.0
#
#     var30(t)      var31(t)
# 3        1.0  40693.398438
# 4        1.0  39800.000000
# 5        1.0  42000.000000
# 6        1.0  39275.000000
# 7        1.0  40000.000000
# ..       ...           ...
# 19       0.0  60500.000000
# 20       0.0  61000.000000
# 21       0.0  72811.109375
# 22       0.0  77000.000000
# 23       0.0  72000.000000
#
# [2446 rows x 34 columns]

# %%
values=df_set.values
values.shape
# Out:
# (2453, 34)

# %%
values
# Out:
# array([[4.0735000e+04, 4.1402566e+04, 4.1198891e+04, ..., 9.8700000e+02,
#         1.0000000e+00, 4.0693398e+04],
#        [4.1402566e+04, 4.1198891e+04, 4.0693398e+04, ..., 9.7600000e+02,
#         1.0000000e+00, 3.9800000e+04],
#        [4.1198891e+04, 4.0693398e+04, 3.9800000e+04, ..., 6.3800000e+02,
#         1.0000000e+00, 4.2000000e+04],
#        ...,
#        [1.0275000e+05, 1.1000000e+05, 9.0000000e+04, ..., 6.5000000e+01,
#         0.0000000e+00, 9.5000000e+04],
#        [1.1000000e+05, 9.0000000e+04, 9.5000000e+04, ..., 5.9000000e+01,
#         0.0000000e+00, 1.0300000e+05],
#        [9.0000000e+04, 9.5000000e+04, 1.0300000e+05, ..., 5.5000000e+01,
#         0.0000000e+00, 1.2050000e+05]], dtype=float32)

# %%
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days]
test = values[train_days:]

# %%
test.shape
# Out:
# (7, 34)

# %%
values=df_set.values
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days, :]
test = values[train_days:, :]

# %%
test
# Out:
# array([[0.5217854 , 0.5855473 , 0.63509154, 0.        , 0.        ,
#         0.8893738 , 0.4166667 , 0.4166667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.8905661 , 0.9234694 , 0.8311031 , 0.8523278 ,
#         0.860636  , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        , 0.5100223 ],
#        [0.5855473 , 0.639745  , 0.752422  , 0.        , 0.        ,
#         0.99224854, 0.4166667 , 0.375     , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.78786266, 1.        , 0.        ,
#         0.08701015, 0.87547183, 0.9336735 , 0.77355456, 0.8169291 ,
#         0.846926  , 0.8489132 , 0.02922076, 0.7794744 , 0.84557474,
#         0.8135922 , 0.00511152, 0.        , 0.6269488 ],
#        [0.639745  , 0.75557923, 0.92195904, 0.        , 0.        ,
#         0.9933624 , 0.4166667 , 0.5416667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.8224422 , 1.        , 0.09090909,
#         0.08001018, 1.        , 0.86224496, 0.77355456, 0.8169291 ,
#         0.846926  , 0.89662457, 0.03571427, 0.8047563 , 0.87358904,
#         0.77475715, 0.01417286, 0.        , 0.6807721 ],
#        [0.75557923, 0.9229543 , 1.        , 0.        , 0.        ,
#         0.99557495, 0.4166667 , 0.25      , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.8728794 , 1.        , 0.27272728,
#         0.03768456, 0.9320755 , 0.86224496, 0.99999976, 0.9565418 ,
#         0.96180725, 0.9319668 , 0.03571427, 0.8975924 , 0.9247252 ,
#         0.6252427 , 0.01138476, 0.        , 0.532294  ],
#        [0.9229543 , 1.        , 0.7847147 , 0.        , 0.        ,
#         0.9977875 , 0.4166667 , 0.25      , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8528302 , 0.9030613 , 0.99999976, 0.9565418 ,
#         0.96180725, 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        , 0.56941354],
#        [1.        , 0.7874602 , 0.838536  , 0.        , 0.        ,
#         0.9988861 , 0.4166667 , 0.33333334, 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.9320755 , 0.9234694 , 0.9993069 , 0.9505129 ,
#         0.96389675, 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        , 0.62880474],
#        [0.7874602 , 0.8405951 , 0.9246502 , 0.        , 0.        ,
#         1.        , 0.4166667 , 0.2916667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.96226406, 1.0000001 , 0.9993069 , 0.9505129 ,
#         0.96389675, 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        , 0.7587231 ]], dtype=float32)

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
train_y
# Out:
# array([0.16624647, 0.15961397, 0.17594656, ..., 0.40468532, 0.4357832 ,
#        0.3986637 ], dtype=float32)

# %%
test_y
# Out:
# array([0.5100223 , 0.6269488 , 0.6807721 , 0.532294  , 0.56941354,
#        0.62880474, 0.7587231 ], dtype=float32)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=50, batch_size=72, 
        validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 34/34 - 7s - loss: 0.1073 - val_loss: 0.2251 - 7s/epoch - 196ms/step
# Epoch 2/50
# 34/34 - 0s - loss: 0.0752 - val_loss: 0.1191 - 252ms/epoch - 7ms/step
# Epoch 3/50
# 34/34 - 0s - loss: 0.0581 - val_loss: 0.0784 - 187ms/epoch - 5ms/step
# Epoch 4/50
# 34/34 - 0s - loss: 0.0434 - val_loss: 0.0741 - 247ms/epoch - 7ms/step
# Epoch 5/50
# 34/34 - 0s - loss: 0.0359 - val_loss: 0.0777 - 163ms/epoch - 5ms/step
# Epoch 6/50
# 34/34 - 0s - loss: 0.0317 - val_loss: 0.0817 - 174ms/epoch - 5ms/step
# Epoch 7/50
# 34/34 - 0s - loss: 0.0291 - val_loss: 0.0834 - 211ms/epoch - 6ms/step
# Epoch 8/50
# 34/34 - 0s - loss: 0.0312 - val_loss: 0.0827 - 211ms/epoch - 6ms/step
# Epoch 9/50
# 34/34 - 0s - loss: 0.0261 - val_loss: 0.0838 - 245ms/epoch - 7ms/step
# Epoch 10/50
# 34/34 - 0s - loss: 0.0283 - val_loss: 0.0864 - 175ms/epoch - 5ms/step
# Epoch 11/50
# 34/34 - 0s - loss: 0.0237 - val_loss: 0.0894 - 168ms/epoch - 5ms/step
# Epoch 12/50
# 34/34 - 0s - loss: 0.0256 - val_loss: 0.0914 - 155ms/epoch - 5ms/step
# Epoch 13/50
# 34/34 - 0s - loss: 0.0230 - val_loss: 0.0943 - 169ms/epoch - 5ms/step
# Epoch 14/50
# 34/34 - 0s - loss: 0.0251 - val_loss: 0.0951 - 172ms/epoch - 5ms/step
# Epoch 15/50
# 34/34 - 0s - loss: 0.0261 - val_loss: 0.0965 - 170ms/epoch - 5ms/step
# Epoch 16/50
# 34/34 - 0s - loss: 0.0240 - val_loss: 0.0952 - 237ms/epoch - 7ms/step
# Epoch 17/50
# 34/34 - 0s - loss: 0.0288 - val_loss: 0.0977 - 186ms/epoch - 5ms/step
# Epoch 18/50
# 34/34 - 0s - loss: 0.0281 - val_loss: 0.0920 - 157ms/epoch - 5ms/step
# Epoch 19/50
# 34/34 - 0s - loss: 0.0214 - val_loss: 0.0958 - 257ms/epoch - 8ms/step
# Epoch 20/50
# 34/34 - 0s - loss: 0.0212 - val_loss: 0.0946 - 241ms/epoch - 7ms/step
# Epoch 21/50
# 34/34 - 0s - loss: 0.0222 - val_loss: 0.0953 - 162ms/epoch - 5ms/step
# Epoch 22/50
# 34/34 - 0s - loss: 0.0226 - val_loss: 0.0963 - 169ms/epoch - 5ms/step
# Epoch 23/50
# 34/34 - 0s - loss: 0.0238 - val_loss: 0.0941 - 169ms/epoch - 5ms/step
# Epoch 24/50
# 34/34 - 0s - loss: 0.0223 - val_loss: 0.0946 - 169ms/epoch - 5ms/step
# Epoch 25/50
# 34/34 - 0s - loss: 0.0225 - val_loss: 0.0933 - 187ms/epoch - 5ms/step
# Epoch 26/50
# 34/34 - 0s - loss: 0.0216 - val_loss: 0.0932 - 171ms/epoch - 5ms/step
# Epoch 27/50
# 34/34 - 0s - loss: 0.0210 - val_loss: 0.0925 - 223ms/epoch - 7ms/step
# Epoch 28/50
# 34/34 - 0s - loss: 0.0207 - val_loss: 0.0917 - 171ms/epoch - 5ms/step
# Epoch 29/50
# 34/34 - 0s - loss: 0.0206 - val_loss: 0.0919 - 190ms/epoch - 6ms/step
# Epoch 30/50
# 34/34 - 0s - loss: 0.0202 - val_loss: 0.0901 - 208ms/epoch - 6ms/step
# Epoch 31/50
# 34/34 - 0s - loss: 0.0211 - val_loss: 0.0907 - 317ms/epoch - 9ms/step
# Epoch 32/50
# 34/34 - 0s - loss: 0.0209 - val_loss: 0.0894 - 219ms/epoch - 6ms/step
# Epoch 33/50
# 34/34 - 0s - loss: 0.0202 - val_loss: 0.0881 - 240ms/epoch - 7ms/step
# Epoch 34/50
# 34/34 - 0s - loss: 0.0217 - val_loss: 0.0886 - 215ms/epoch - 6ms/step
# Epoch 35/50
# 34/34 - 0s - loss: 0.0218 - val_loss: 0.0863 - 190ms/epoch - 6ms/step
# Epoch 36/50
# 34/34 - 0s - loss: 0.0216 - val_loss: 0.0857 - 200ms/epoch - 6ms/step
# Epoch 37/50
# 34/34 - 0s - loss: 0.0222 - val_loss: 0.0836 - 203ms/epoch - 6ms/step
# Epoch 38/50
# 34/34 - 0s - loss: 0.0229 - val_loss: 0.0811 - 262ms/epoch - 8ms/step
# Epoch 39/50
# 34/34 - 0s - loss: 0.0255 - val_loss: 0.0802 - 197ms/epoch - 6ms/step
# Epoch 40/50
# 34/34 - 0s - loss: 0.0269 - val_loss: 0.0835 - 214ms/epoch - 6ms/step
# Epoch 41/50
# 34/34 - 0s - loss: 0.0232 - val_loss: 0.0849 - 212ms/epoch - 6ms/step
# Epoch 42/50
# 34/34 - 0s - loss: 0.0202 - val_loss: 0.0864 - 248ms/epoch - 7ms/step
# Epoch 43/50
# 34/34 - 0s - loss: 0.0186 - val_loss: 0.0882 - 268ms/epoch - 8ms/step
# Epoch 44/50
# 34/34 - 0s - loss: 0.0187 - val_loss: 0.0890 - 211ms/epoch - 6ms/step
# Epoch 45/50
# 34/34 - 0s - loss: 0.0189 - val_loss: 0.0886 - 182ms/epoch - 5ms/step
# Epoch 46/50
# 34/34 - 0s - loss: 0.0188 - val_loss: 0.0865 - 173ms/epoch - 5ms/step
# Epoch 47/50
# 34/34 - 0s - loss: 0.0184 - val_loss: 0.0884 - 181ms/epoch - 5ms/step
# Epoch 48/50
# 34/34 - 0s - loss: 0.0188 - val_loss: 0.0898 - 175ms/epoch - 5ms/step
# Epoch 49/50
# 34/34 - 0s - loss: 0.0193 - val_loss: 0.0873 - 176ms/epoch - 5ms/step
# Epoch 50/50
# 34/34 - 0s - loss: 0.0186 - val_loss: 0.0854 - 292ms/epoch - 9ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
test_X.shape
# Out:
# (7, 33)

# %%
yhat
# Out:
# array([[0.45705026],
#        [0.51921344],
#        [0.599022  ],
#        [0.65577483],
#        [0.66855836],
#        [0.66548914],
#        [0.6627805 ]], dtype=float32)

# %%
test_X
# Out:
# array([[0.5217854 , 0.5855473 , 0.63509154, 0.        , 0.        ,
#         0.8893738 , 0.4166667 , 0.4166667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.8905661 , 0.9234694 , 0.8311031 , 0.8523278 ,
#         0.860636  , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        ],
#        [0.5855473 , 0.639745  , 0.752422  , 0.        , 0.        ,
#         0.99224854, 0.4166667 , 0.375     , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.78786266, 1.        , 0.        ,
#         0.08701015, 0.87547183, 0.9336735 , 0.77355456, 0.8169291 ,
#         0.846926  , 0.8489132 , 0.02922076, 0.7794744 , 0.84557474,
#         0.8135922 , 0.00511152, 0.        ],
#        [0.639745  , 0.75557923, 0.92195904, 0.        , 0.        ,
#         0.9933624 , 0.4166667 , 0.5416667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.8224422 , 1.        , 0.09090909,
#         0.08001018, 1.        , 0.86224496, 0.77355456, 0.8169291 ,
#         0.846926  , 0.89662457, 0.03571427, 0.8047563 , 0.87358904,
#         0.77475715, 0.01417286, 0.        ],
#        [0.75557923, 0.9229543 , 1.        , 0.        , 0.        ,
#         0.99557495, 0.4166667 , 0.25      , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.8728794 , 1.        , 0.27272728,
#         0.03768456, 0.9320755 , 0.86224496, 0.99999976, 0.9565418 ,
#         0.96180725, 0.9319668 , 0.03571427, 0.8975924 , 0.9247252 ,
#         0.6252427 , 0.01138476, 0.        ],
#        [0.9229543 , 1.        , 0.7847147 , 0.        , 0.        ,
#         0.9977875 , 0.4166667 , 0.25      , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8528302 , 0.9030613 , 0.99999976, 0.9565418 ,
#         0.96180725, 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        ],
#        [1.        , 0.7874602 , 0.838536  , 0.        , 0.        ,
#         0.9988861 , 0.4166667 , 0.33333334, 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.9320755 , 0.9234694 , 0.9993069 , 0.9505129 ,
#         0.96389675, 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        ],
#        [0.7874602 , 0.8405951 , 0.9246502 , 0.        , 0.        ,
#         1.        , 0.4166667 , 0.2916667 , 0.41067097, 0.        ,
#         1.        , 0.48684284, 0.7257279 , 0.518226  , 0.45183206,
#         0.599727  , 0.8649215 , 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.96226406, 1.0000001 , 0.9993069 , 0.9505129 ,
#         0.96389675, 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        ]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((test_X[:, 0:],yhat), axis=1)

# %%
inv_yhat.shape
# Out:
# (7, 34)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
inv_yhat = inv_yhat[:,-1]
inv_yhat
# Out:
# array([ 79864.67,  88238.05,  98988.26, 106632.87, 108354.81, 107941.38,
#        107576.53], dtype=float32)

# %%
inv_y
# Out:
# array([ 65000.,  71000.,  76100.,  87000., 102750., 110000.,  90000.],
#       dtype=float32)

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_X[:, 0:],test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
# calculate RMSE

# %%
inv_y
# Out:
# array([ 87000., 102750., 110000.,  90000.,  95000., 103000., 120500.],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.plot(inv_y)
plt.plot(inv_yhat)
plt.show()

# %%
#실제값
inv_y
# Out:
# array([ 87000., 102750., 110000.,  90000.,  95000., 103000., 120500.],
#       dtype=float32)

# %%
#예측치
inv_yhat
# Out:
# array([ 79864.67,  88238.05,  98988.26, 106632.87, 108354.81, 107941.38,
#        107576.53], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
RMSE = mean_squared_error(inv_y, inv_yhat)**0.5

# %%
RMSE
# Out:
# 12125.562419945723
