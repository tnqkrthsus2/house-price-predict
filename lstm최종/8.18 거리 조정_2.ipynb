# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('final3_english.csv',encoding='cp949')

# %%
df
# Out:
#        apart_code  YYYYMM            apart__name        sigungu town_name  \
# 0       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 1       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 2       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 3       A10024240  201201                    무지개  서울특별시 서초구 서초동       서초동
# 4       A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동       종암동
# ...           ...     ...                    ...            ...       ...
# 725063  A15776004  202207                    현대3  서울특별시 강서구 염창동       염창동
# 725064  A15807701  202207                  세양청마루  서울특별시 양천구 신정동       신정동
# 725065  A15882107  202207                    금호1   서울특별시 양천구 목동        목동
# 725066  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동       진관동
# 725067  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동       진관동
#
#                        address sale_type  area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양   101.81      1        1978  ...
# 1            서울특별시 서초구 효령로 391     임대+분양   101.10     11        1978  ...
# 2            서울특별시 서초구 효령로 391     임대+분양    77.71      6        1978  ...
# 3            서울특별시 서초구 효령로 391     임대+분양   101.10      3        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대    84.73      5        2005  ...
# ...                        ...       ...      ...    ...         ...  ...
# 725063     서울특별시 강서구 양천로75길 60        분양    59.92      1        1996  ...
# 725064  서울특별시 양천구 목동남로2길 60-30        분양    84.98      9        2006  ...
# 725065      서울특별시 양천구 목동동로 258        분양    84.96     22        1997  ...
# 725066     서울특별시 은평구 진관2로 57-7        분양    84.54      8        2009  ...
# 725067     서울특별시 은평구 연서로48길 12        분양   101.83      5        2010  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 1       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 2       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 3       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 725063       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725064       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725065       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725066       NaN       NaN       NaN  108.740           NaN  2,451.50
# 725067       NaN       NaN       NaN  108.740           NaN  2,451.50
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 1       1757058.7       106.0  1890.0   81200
# 2       1757058.7       106.0  1890.0   64000
# 3       1757058.7       106.0  1890.0   78800
# 4       1757058.7       106.0  1890.0   46000
# ...           ...         ...     ...     ...
# 725063        NaN         NaN     NaN   64600
# 725064        NaN         NaN     NaN   95000
# 725065        NaN         NaN     NaN  115000
# 725066        NaN         NaN     NaN   93000
# 725067        NaN         NaN     NaN  103000
#
# [725068 rows x 37 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df_vary = df.drop_duplicates(['apart_code'])

# %%
df_vary
# Out:
#        apart_code  YYYYMM apart__name         sigungu town_name  \
# 0       A10024240  201201         무지개   서울특별시 서초구 서초동       서초동
# 4       A10024603  201201   아이파크종암동2차   서울특별시 성북구 종암동       종암동
# 7       A10024621  201201          태흥   서울특별시 관악구 신림동       신림동
# 8       A10024636  201201       세양청마루   서울특별시 노원구 월계동       월계동
# 9       A10024638  201201    관악월드메르디앙   서울특별시 관악구 봉천동       봉천동
# ...           ...     ...         ...             ...       ...
# 721832  A10025013  202204  사당롯데캐슬골든포레   서울특별시 동작구 사당동       사당동
# 723079  A10024098  202205  보라매자이더포레스트  서울특별시 동작구 신대방동      신대방동
# 724205  A10023926  202206    롯데캐슬클라시아   서울특별시 성북구 길음동       길음동
# 724206  A10023959  202206  홍제역해링턴플레이스  서울특별시 서대문구 홍제동       홍제동
# 724210  A10024408  202206    공덕SK리더스뷰   서울특별시 마포구 공덕동       공덕동
#
#                        address sale_type   area_m3  floor  const_year  ...  \
# 0            서울특별시 서초구 효령로 391     임대+분양  101.8100      1        1978  ...
# 4           서울특별시 성북구 종암로9길 71        임대   84.7300      5        2005  ...
# 7            서울특별시 관악구 호암로 541        분양   59.8600     18        1995  ...
# 8          서울특별시 노원구 석계로13길 35        분양   64.1830      8        2005  ...
# 9          서울특별시 관악구 관악로28길 80        분양   79.2700      6        2005  ...
# ...                        ...       ...       ...    ...         ...  ...
# 721832        서울특별시 동작구 사당로 90        분양   59.9775      7        2021  ...
# 723079  서울특별시 동작구 여의대방로22길 121     임대+분양   59.9365     15        2021  ...
# 724205      서울특별시 성북구 숭인로8길 80     임대+분양   59.8745     15        2022  ...
# 724206     서울특별시 서대문구 세무서8길 30     임대+분양   59.9900     10        2021  ...
# 724210      서울특별시 마포구 백범로31길 7     임대+분양   84.9300     12        2021  ...
#
#              GDP       GDI       GNI      CPI  avg_interest     cospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 7       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 8       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# 9       361724.2  343229.4  345819.5   91.242          5.79  1,955.79
# ...          ...       ...       ...      ...           ...       ...
# 721832  492124.3  464761.5       0.0  106.850          3.57  2,695.05
# 723079  492124.3  464761.5       0.0  107.560          3.68  2,685.90
# 724205  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724206  492124.3  464761.5       0.0  108.220          3.90  2,332.64
# 724210  492124.3  464761.5       0.0  108.220          3.90  2,332.64
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 4       1757058.7       106.0  1890.0   46000
# 7       1757058.7       106.0  1890.0   23100
# 8       1757058.7       106.0  1890.0   25700
# 9       1757058.7       106.0  1890.0   35000
# ...           ...         ...     ...     ...
# 721832  3675828.7       110.8   360.0  110000
# 723079  3694489.3       105.2   688.0  115000
# 724205  3714442.7        99.8   719.0  110800
# 724206  3714442.7        99.8   719.0  116000
# 724210  3714442.7        99.8   719.0  190000
#
# [2385 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# apart_code          0
# YYYYMM              0
# apart__name         0
# sigungu             0
# town_name           0
# address             0
# sale_type        2628
# area_m3             0
# floor               0
# const_year          0
# parking          1926
# GPS_X               0
# GPS_Y               0
# crime_rate          0
# building_year       0
# market_dist         0
# busstop_dist        0
# subway_dist         0
# school_dist         0
# kinder_dist         0
# hospital_dist       0
# ASPI                0
# YYYY                0
# MM                  0
# HAI              3269
# PIR              4222
# LIR              4222
# GDP               228
# GDI               228
# GNI               228
# CPI                 0
# avg_interest      228
# cospi               0
# M2                228
# house_CCSI        228
# unsold            228
# prices              0
# dtype: int64

# %%
df = df[df['sale_type'].notna()]
df = df[df['parking'].notna()]
df = df[df['HAI'].notna()]
df = df[df['M2'].notna()]

# %% [markdown]
# 주변의 아파트 구하기

# %%
df_range = df_vary[['apart_code','GPS_X','GPS_Y']]

# %% [markdown]
# A10024240 단지를 중심으로(다음 행 아파트 코드 하나만 수정할시 전체 값 변화)

# %%
gizun_code = 'A41279924'
gizun = df_range[df_range['apart_code']==gizun_code]

# %%
from haversine import haversine

# %% [markdown]
# 주변거리 4km로 설정

# %%
start = (float(gizun['GPS_Y']),float(gizun['GPS_X']))
near_apts = []
for i in df_range.index:
    goal = (float(df_range['GPS_Y'][i]),float(df_range['GPS_X'][i]))
    if haversine(start, goal) < 4:
        near_apts.append(df_range['apart_code'][i])
near_df = pd.DataFrame()
near_df['apart_code'] = near_apts

# %%
near_df
# Out:
#    apart_code
# 0   A10024774
# 1   A12204002
# 2   A12204003
# 3   A12204004
# 4   A12204102
# 5   A12205004
# 6   A12275201
# 7   A12275202
# 8   A12281701
# 9   A12282102
# 10  A12284501
# 11  A12284701
# 12  A12285703
# 13  A41279902
# 14  A41279910
# 15  A41279918
# 16  A41279920
# 17  A41279923
# 18  A41279924
# 19  A41279927
# 20  B12204002
# 21  A12205001
# 22  A12205003
# 23  A12220004
# 24  A12271402
# 25  A12281702
# 26  A12283601
# 27  A41279901
# 28  A41279904
# 29  A41279907
# 30  A41279908
# 31  A41279909
# 32  A41279922
# 33  A41279925
# 34  A41279926
# 35  A41279929
# 36  A12220005
# 37  A41279903
# 38  A41279911
# 39  A41279912
# 40  A41279913
# 41  A41279915
# 42  A12220001
# 43  A12281801
# 44  A41279905
# 45  A41279914
# 46  A12204001
# 47  A12220003
# 48  A41279906
# 49  A41279916
# 50  A12220002
# 51  A41279917
# 52  A12282201
# 53  A12204006
# 54  A41279932
# 55  A10026414
# 56  A10025765
# 57  A10025846

# %% [markdown]
# near_df 데이터에서 세대수 찾기

# %%
many_df = pd.read_csv('서울시아파트(기준).csv',encoding='cp949')

# %%
near_df = pd.merge(near_df,many_df,left_on='apart_code',right_on='k-아파트코드',how='left')

# %%
near_df
# Out:
#    apart_code     번호    k-아파트코드  k-전체세대수       k-건설사(시공사)
# 0   A10024774  40088  A10024774    111.0         해주개발주식회사
# 1   A12204002    502  A12204002    256.0             대창건설
# 2   A12204003   1837  A12204003    603.0             현대건설
# 3   A12204004   2054  A12204004   1185.0          현대건설(주)
# 4   A12204102   1285  A12204102    662.0          현대건설(주)
# 5   A12205004    793  A12205004    366.0             현대건설
# 6   A12275201   2104  A12275201    647.0             삼성물산
# 7   A12275202   2164  A12275202    882.0             현대건설
# 8   A12281701    215  A12281701    191.0        코오롱건설주식회사
# 9   A12282102    203  A12282102    189.0          이수건설(주)
# 10  A12284501    772  A12284501    357.0         삼성건설주식회사
# 11  A12284701    252  A12284701    198.0            (주)대호
# 12  A12285703   1591  A12285703   1340.0       라이프주택건설(주)
# 13  A41279902   1808  A41279902    318.0           대우푸르지오
# 14  A41279910   1935  A41279910    947.0               현대
# 15  A41279918   2005  A41279918    472.0             두산건설
# 16  A41279920   2033  A41279920    486.0             삼성건설
# 17  A41279923   2067  A41279923    330.0  (주)대우건설 (주)태영건설
# 18  A41279924   2068  A41279924    571.0          현대건설(주)
# 19  A41279927   2103  A41279927    334.0         벽산건설금호건설
# 20  B12204002   3091  B12204002    135.0             삼성물산
# 21  A12205001    260  A12205001    200.0         (주) 강산건설
# 22  A12205003    703  A12205003    327.0               대림
# 23  A12220004   1149  A12220004    551.0          (주)롯데건설
# 24  A12271402   1761  A12271402    175.0          대교 대앤에스
# 25  A12281702    581  A12281702    278.0           현대산업개발
# 26  A12283601    220  A12283601    192.0        현대산업개발(주)
# 27  A41279901   1798  A41279901    300.0           현대산업개발
# 28  A41279904   1817  A41279904    379.0           대우푸르지오
# 29  A41279907   1832  A41279907    187.0           현대산업개발
# 30  A41279908   1856  A41279908    255.0       현대산업개발주식회사
# 31  A41279909   1934  A41279909    162.0             현대건설
# 32  A41279922   2063  A41279922    175.0          대우건설(주)
# 33  A41279925   2074  A41279925    189.0          대우푸르지오
# 34  A41279926   2077  A41279926    126.0             현대건설
# 35  A41279929   2118  A41279929    412.0             대우건설
# 36  A12220005   1320  A12220005    707.0             삼환기업
# 37  A41279903   1811  A41279903    378.0           대우푸르지오
# 38  A41279911   2284  A41279911    660.0             현대건설
# 39  A41279912   1995  A41279912    659.0            포스코건설
# 40  A41279913   1996  A41279913    469.0          동부건걸(주)
# 41  A41279915   2002  A41279915    448.0             금호건설
# 42  A12220001    316  A12220001    208.0           대우푸르지오
# 43  A12281801    225  A12281801    193.0          한솔건설(주)
# 44  A41279905   1825  A41279905    241.0           현대산업개발
# 45  A41279914   1999  A41279914    434.0             동부건설
# 46  A12204001     37  A12204001    155.0               한양
# 47  A12220003    719  A12220003    335.0          롯데건설(주)
# 48  A41279906   1831  A41279906    230.0           현대산업개발
# 49  A41279916   2003  A41279916    387.0       두산건설포스코 건설
# 50  A12220002    651  A12220002    298.0             SH공사
# 51  A41279917   2004  A41279917    353.0               SH
# 52  A12282201    130  A12282201    171.0             인황건설
# 53  A12204006   3541  A12204006    488.0          롯데건설(주)
# 54  A41279932   6381  A41279932    426.0               한라
# 55  A10026414  19260  A10026414    260.0          (주)삼전건설
# 56  A10025765  20822  A10025765    361.0            GS 건설
# 57  A10025846  20741  A10025846   1305.0             삼성물산

# %%
near_df = near_df[['apart_code','k-전체세대수']]

# %% [markdown]
# 더 적은 세대수 아파트 삭제

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 0   A10024774    111.0
# 1   A12204002    256.0
# 2   A12204003    603.0
# 3   A12204004   1185.0
# 4   A12204102    662.0
# 5   A12205004    366.0
# 6   A12275201    647.0
# 7   A12275202    882.0
# 8   A12281701    191.0
# 9   A12282102    189.0
# 10  A12284501    357.0
# 11  A12284701    198.0
# 12  A12285703   1340.0
# 13  A41279902    318.0
# 14  A41279910    947.0
# 15  A41279918    472.0
# 16  A41279920    486.0
# 17  A41279923    330.0
# 18  A41279924    571.0
# 19  A41279927    334.0
# 20  B12204002    135.0
# 21  A12205001    200.0
# 22  A12205003    327.0
# 23  A12220004    551.0
# 24  A12271402    175.0
# 25  A12281702    278.0
# 26  A12283601    192.0
# 27  A41279901    300.0
# 28  A41279904    379.0
# 29  A41279907    187.0
# 30  A41279908    255.0
# 31  A41279909    162.0
# 32  A41279922    175.0
# 33  A41279925    189.0
# 34  A41279926    126.0
# 35  A41279929    412.0
# 36  A12220005    707.0
# 37  A41279903    378.0
# 38  A41279911    660.0
# 39  A41279912    659.0
# 40  A41279913    469.0
# 41  A41279915    448.0
# 42  A12220001    208.0
# 43  A12281801    193.0
# 44  A41279905    241.0
# 45  A41279914    434.0
# 46  A12204001    155.0
# 47  A12220003    335.0
# 48  A41279906    230.0
# 49  A41279916    387.0
# 50  A12220002    298.0
# 51  A41279917    353.0
# 52  A12282201    171.0
# 53  A12204006    488.0
# 54  A41279932    426.0
# 55  A10026414    260.0
# 56  A10025765    361.0
# 57  A10025846   1305.0

# %%
gizun_count = near_df[near_df['apart_code']==gizun_code].iloc[0][1]
gizun_count
# Out:
# 571.0

# %%
indexNames = near_df[near_df['k-전체세대수'] < gizun_count].index
near_df.drop(indexNames , inplace=True)
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
near_df
# Out:
#    apart_code  k-전체세대수
# 2   A12204003    603.0
# 3   A12204004   1185.0
# 4   A12204102    662.0
# 6   A12275201    647.0
# 7   A12275202    882.0
# 12  A12285703   1340.0
# 14  A41279910    947.0
# 18  A41279924    571.0
# 36  A12220005    707.0
# 38  A41279911    660.0
# 39  A41279912    659.0
# 57  A10025846   1305.0

# %%
df.keys()
# Out:
# Index(['apart_code', 'YYYYMM', 'apart__name', 'sigungu', 'town_name',
#        'address', 'sale_type', 'area_m3', 'floor', 'const_year', 'parking',
#        'GPS_X', 'GPS_Y', 'crime_rate', 'building_year', 'market_dist',
#        'busstop_dist', 'subway_dist', 'school_dist', 'kinder_dist',
#        'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR', 'LIR', 'GDP',
#        'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2', 'house_CCSI',
#        'unsold', 'prices'],
#       dtype='object')

# %%
df = df.astype({'prices':'float64'})

# %%
df['area_m3']=df['area_m3'].round(-1)

# %%
df['prices']=df.groupby(['YYYYMM','apart_code','area_m3'])['prices'].transform('mean')

# %% [markdown]
# 근처에 있는 아파트의 데이터 프레임 생성

# %%
df = pd.merge(near_df,df,on='apart_code')

# %%
df = df.rename(columns={'k-전체세대수':'resident_count'})
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices'],
#       dtype='object')

# %%
df['apart_code_area'] = df['apart_code'].map(str) +'_' +df['area_m3'].map(int).map(str)

# %%
df
# Out:
#      apart_code  resident_count  YYYYMM    apart__name        sigungu  \
# 0     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 1     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 2     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 3     A12204003           603.0  201201  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# 4     A12204003           603.0  201202  북한산힐스테이트1차아파트  서울특별시 은평구 불광동
# ...         ...             ...     ...            ...            ...
# 4085  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 4086  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 4087  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 4088  A10025846          1305.0  202111        래미안베라힐즈  서울특별시 은평구 녹번동
# 4089  A10025846          1305.0  202202        래미안베라힐즈  서울특별시 은평구 녹번동
#
#      town_name             address sale_type  area_m3  floor  ...       GDI  \
# 0          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      7  ...  343229.4
# 1          불광동  서울특별시 은평구 불광로2길 33        분양     80.0     10  ...  343229.4
# 2          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      9  ...  343229.4
# 3          불광동  서울특별시 은평구 불광로2길 33        분양     80.0      2  ...  343229.4
# 4          불광동  서울특별시 은평구 불광로2길 33        분양     60.0      4  ...  343229.4
# ...        ...                 ...       ...      ...    ...  ...       ...
# 4085       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0      5  ...  487122.0
# 4086       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0      3  ...  487122.0
# 4087       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0     14  ...  487122.0
# 4088       녹번동   서울특별시 은평구 통일로 630     임대+분양     80.0      7  ...  487122.0
# 4089       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0     14  ...  450242.2
#
#            GNI      CPI  avg_interest     cospi         M2  house_CCSI  \
# 0     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 1     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 2     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 3     345819.5   91.242          5.79  1,955.79  1757058.7       106.0
# 4     345819.5   91.588          5.71  2,030.25  1762988.4       111.3
# ...        ...      ...           ...       ...        ...         ...
# 4085  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 4086  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 4087  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 4088  492461.1  103.870          3.23  2,839.01  3594723.2       111.6
# 4089  455546.7  105.300          3.51  2,699.18  3656135.8       103.4
#
#       unsold         prices  apart_code_area
# 0     1890.0   49325.000000     A12204003_80
# 1     1890.0   49325.000000     A12204003_80
# 2     1890.0   49325.000000     A12204003_80
# 3     1890.0   49325.000000     A12204003_80
# 4     1703.0   37000.000000     A12204003_60
# ...      ...            ...              ...
# 4085    54.0  107000.000000     A10025846_60
# 4086    54.0  129333.333333     A10025846_80
# 4087    54.0  129333.333333     A10025846_80
# 4088    54.0  129333.333333     A10025846_80
# 4089    47.0  107000.000000     A10025846_60
#
# [4090 rows x 39 columns]

# %%
df = df.drop_duplicates(subset=['apart_code_area','YYYYMM'])

# %%
df = df.sort_values(by=["apart_code_area", "YYYYMM"], ascending=[True, True])

# %%
df
# Out:
#      apart_code  resident_count  YYYYMM         apart__name        sigungu  \
# 4055  A10025846          1305.0  202101             래미안베라힐즈  서울특별시 은평구 녹번동
# 4045  A10025846          1305.0  202008             래미안베라힐즈  서울특별시 은평구 녹번동
# 4047  A10025846          1305.0  202010             래미안베라힐즈  서울특별시 은평구 녹번동
# 4057  A10025846          1305.0  202101             래미안베라힐즈  서울특별시 은평구 녹번동
# 4060  A10025846          1305.0  202102             래미안베라힐즈  서울특별시 은평구 녹번동
# ...         ...             ...     ...                 ...            ...
# 3478  A41279924           571.0  201907  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 3479  A41279924           571.0  202008  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 3482  A41279924           571.0  202101  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 3485  A41279924           571.0  202102  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
# 3486  A41279924           571.0  202103  은평뉴타운폭포동(힐스테이트D-9)  서울특별시 은평구 진관동
#
#      town_name             address sale_type  area_m3  floor  ...       GDI  \
# 4055       녹번동   서울특별시 은평구 통일로 630     임대+분양    110.0      3  ...  450518.8
# 4045       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0      2  ...  454712.9
# 4047       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0     18  ...  480138.7
# 4057       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0     14  ...  450518.8
# 4060       녹번동   서울특별시 은평구 통일로 630     임대+분양     60.0      8  ...  450518.8
# ...        ...                 ...       ...      ...    ...  ...       ...
# 3478       진관동  서울특별시 은평구 연서로44길 7        분양    170.0      4  ...  450519.4
# 3479       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     16  ...  454712.9
# 3482       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     11  ...  450518.8
# 3485       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     10  ...  450518.8
# 3486       진관동  서울특별시 은평구 연서로44길 7        분양    170.0     11  ...  450518.8
#
#            GNI      CPI  avg_interest     cospi         M2  house_CCSI  \
# 4055  457211.8  101.040          2.72  2,976.21  3223486.7       131.5
# 4045  458855.5  100.190          2.63  2,326.17  3100373.4       127.7
# 4047  486940.6  100.180          2.66  2,267.15  3152811.6       132.0
# 4057  457211.8  101.040          2.72  2,976.21  3223486.7       131.5
# 4060  457211.8  101.580          2.74  3,012.95  3271405.8       129.5
# ...        ...      ...           ...       ...        ...         ...
# 3478  458809.4   99.187          3.40  2,024.55  2811543.7       109.4
# 3479  458855.5  100.190          2.63  2,326.17  3100373.4       127.7
# 3482  457211.8  101.040          2.72  2,976.21  3223486.7       131.5
# 3485  457211.8  101.580          2.74  3,012.95  3271405.8       129.5
# 3486  457211.8  101.840          2.77  3,061.42  3313182.2       123.5
#
#       unsold    prices  apart_code_area
# 4055    49.0  140000.0    A10025846_110
# 4045    56.0   89900.0     A10025846_60
# 4047    52.0   95000.0     A10025846_60
# 4057    49.0  107000.0     A10025846_60
# 4060    88.0  107000.0     A10025846_60
# ...      ...       ...              ...
# 3478   190.0  101500.0    A41279924_170
# 3479    56.0  130000.0    A41279924_170
# 3482    49.0  140000.0    A41279924_170
# 3485    88.0  144500.0    A41279924_170
# 3486    82.0  150000.0    A41279924_170
#
# [1607 rows x 39 columns]

# %%
df.keys()
# Out:
# Index(['apart_code', 'resident_count', 'YYYYMM', 'apart__name', 'sigungu',
#        'town_name', 'address', 'sale_type', 'area_m3', 'floor', 'const_year',
#        'parking', 'GPS_X', 'GPS_Y', 'crime_rate', 'building_year',
#        'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
#        'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
#        'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
#        'house_CCSI', 'unsold', 'prices', 'apart_code_area'],
#       dtype='object')

# %%
df = df[['apart_code_area','resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
       'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
       'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
       'house_CCSI', 'unsold', 'prices']]

# %% [markdown]
# 분양타입 변경

# %%
df['sale_type']
# Out:
# 4055    임대+분양
# 4045    임대+분양
# 4047    임대+분양
# 4057    임대+분양
# 4060    임대+분양
#         ...
# 3478       분양
# 3479       분양
# 3482       분양
# 3485       분양
# 3486       분양
# Name: sale_type, Length: 1607, dtype: object

# %%
df.loc[df['sale_type'] == '분양', 'sale_type'] = 0
df.loc[df['sale_type'] == '임대+분양', 'sale_type'] = 1
df.loc[df['sale_type'] == '임대', 'sale_type'] = 2
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df
# Out:
#      apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 4055   A10025846_110          1305.0         1  202101    110.0      3
# 4045    A10025846_60          1305.0         1  202008     60.0      2
# 4047    A10025846_60          1305.0         1  202010     60.0     18
# 4057    A10025846_60          1305.0         1  202101     60.0     14
# 4060    A10025846_60          1305.0         1  202102     60.0      8
# ...              ...             ...       ...     ...      ...    ...
# 3478   A41279924_170           571.0         0  201907    170.0      4
# 3479   A41279924_170           571.0         0  202008    170.0     16
# 3482   A41279924_170           571.0         0  202101    170.0     11
# 3485   A41279924_170           571.0         0  202102    170.0     10
# 3486   A41279924_170           571.0         0  202103    170.0     11
#
#       parking  crime_rate  building_year  market_dist  ...       GDP  \
# 4055   1407.0    0.710015              4     0.858360  ...  453751.7
# 4045   1407.0    0.710015              4     0.858360  ...  459981.3
# 4047   1407.0    0.710015              4     0.858360  ...  485291.5
# 4057   1407.0    0.710015              4     0.858360  ...  453751.7
# 4060   1407.0    0.710015              4     0.858360  ...  453751.7
# ...       ...         ...            ...          ...  ...       ...
# 3478   1119.0    0.710015              9     1.771677  ...  463965.5
# 3479   1119.0    0.710015              9     1.771677  ...  459981.3
# 3482   1119.0    0.710015              9     1.771677  ...  453751.7
# 3485   1119.0    0.710015              9     1.771677  ...  453751.7
# 3486   1119.0    0.710015              9     1.771677  ...  453751.7
#
#            GDI       GNI      CPI  avg_interest     cospi         M2  \
# 4055  450518.8  457211.8  101.040          2.72  2,976.21  3223486.7
# 4045  454712.9  458855.5  100.190          2.63  2,326.17  3100373.4
# 4047  480138.7  486940.6  100.180          2.66  2,267.15  3152811.6
# 4057  450518.8  457211.8  101.040          2.72  2,976.21  3223486.7
# 4060  450518.8  457211.8  101.580          2.74  3,012.95  3271405.8
# ...        ...       ...      ...           ...       ...        ...
# 3478  450519.4  458809.4   99.187          3.40  2,024.55  2811543.7
# 3479  454712.9  458855.5  100.190          2.63  2,326.17  3100373.4
# 3482  450518.8  457211.8  101.040          2.72  2,976.21  3223486.7
# 3485  450518.8  457211.8  101.580          2.74  3,012.95  3271405.8
# 3486  450518.8  457211.8  101.840          2.77  3,061.42  3313182.2
#
#       house_CCSI  unsold    prices
# 4055       131.5    49.0  140000.0
# 4045       127.7    56.0   89900.0
# 4047       132.0    52.0   95000.0
# 4057       131.5    49.0  107000.0
# 4060       129.5    88.0  107000.0
# ...          ...     ...       ...
# 3478       109.4   190.0  101500.0
# 3479       127.7    56.0  130000.0
# 3482       131.5    49.0  140000.0
# 3485       129.5    88.0  144500.0
# 3486       123.5    82.0  150000.0
#
# [1607 rows x 31 columns]

# %% [markdown]
# df를 csv파일로 내보낸다

# %%
#df.to_csv('반경3km위주의 상관관계확인.csv')

# %%
#코스피 행 변환
for i in df.index:
    if type(df['cospi'][i]) == str:
        df['cospi'][i] = df['cospi'][i].replace(',','')
    else: 
        df['cospi'][i] = df['cospi'][i]
df
# Out:
# c:\Users\46861\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#      apart_code_area  resident_count sale_type  YYYYMM  area_m3  floor  \
# 4055   A10025846_110          1305.0         1  202101    110.0      3
# 4045    A10025846_60          1305.0         1  202008     60.0      2
# 4047    A10025846_60          1305.0         1  202010     60.0     18
# 4057    A10025846_60          1305.0         1  202101     60.0     14
# 4060    A10025846_60          1305.0         1  202102     60.0      8
# ...              ...             ...       ...     ...      ...    ...
# 3478   A41279924_170           571.0         0  201907    170.0      4
# 3479   A41279924_170           571.0         0  202008    170.0     16
# 3482   A41279924_170           571.0         0  202101    170.0     11
# 3485   A41279924_170           571.0         0  202102    170.0     10
# 3486   A41279924_170           571.0         0  202103    170.0     11
#
#       parking  crime_rate  building_year  market_dist  ...       GDP  \
# 4055   1407.0    0.710015              4     0.858360  ...  453751.7
# 4045   1407.0    0.710015              4     0.858360  ...  459981.3
# 4047   1407.0    0.710015              4     0.858360  ...  485291.5
# 4057   1407.0    0.710015              4     0.858360  ...  453751.7
# 4060   1407.0    0.710015              4     0.858360  ...  453751.7
# ...       ...         ...            ...          ...  ...       ...
# 3478   1119.0    0.710015              9     1.771677  ...  463965.5
# 3479   1119.0    0.710015              9     1.771677  ...  459981.3
# 3482   1119.0    0.710015              9     1.771677  ...  453751.7
# 3485   1119.0    0.710015              9     1.771677  ...  453751.7
# 3486   1119.0    0.710015              9     1.771677  ...  453751.7
#
#            GDI       GNI      CPI  avg_interest    cospi         M2  \
# 4055  450518.8  457211.8  101.040          2.72  2976.21  3223486.7
# 4045  454712.9  458855.5  100.190          2.63  2326.17  3100373.4
# 4047  480138.7  486940.6  100.180          2.66  2267.15  3152811.6
# 4057  450518.8  457211.8  101.040          2.72  2976.21  3223486.7
# 4060  450518.8  457211.8  101.580          2.74  3012.95  3271405.8
# ...        ...       ...      ...           ...      ...        ...
# 3478  450519.4  458809.4   99.187          3.40  2024.55  2811543.7
# 3479  454712.9  458855.5  100.190          2.63  2326.17  3100373.4
# 3482  450518.8  457211.8  101.040          2.72  2976.21  3223486.7
# 3485  450518.8  457211.8  101.580          2.74  3012.95  3271405.8
# 3486  450518.8  457211.8  101.840          2.77  3061.42  3313182.2
#
#       house_CCSI  unsold    prices
# 4055       131.5    49.0  140000.0
# 4045       127.7    56.0   89900.0
# 4047       132.0    52.0   95000.0
# 4057       131.5    49.0  107000.0
# 4060       129.5    88.0  107000.0
# ...          ...     ...       ...
# 3478       109.4   190.0  101500.0
# 3479       127.7    56.0  130000.0
# 3482       131.5    49.0  140000.0
# 3485       129.5    88.0  144500.0
# 3486       123.5    82.0  150000.0
#
# [1607 rows x 31 columns]

# %%
codes = df['apart_code_area'].unique()
groups = df.groupby(df.apart_code_area)
for i in codes:
    globals()['df_'+i] = groups.get_group(i)

# %%
codes
# Out:
# array(['A10025846_110', 'A10025846_60', 'A10025846_80', 'A12204003_110',
#        'A12204003_60', 'A12204003_80', 'A12204004_120', 'A12204004_130',
#        'A12204004_60', 'A12204004_80', 'A12204102_110', 'A12204102_60',
#        'A12204102_80', 'A12220005_100', 'A12220005_130', 'A12220005_80',
#        'A12275201_110', 'A12275201_60', 'A12275201_80', 'A12275202_110',
#        'A12275202_140', 'A12275202_60', 'A12275202_80', 'A12285703_130',
#        'A12285703_70', 'A12285703_80', 'A41279910_100', 'A41279910_130',
#        'A41279910_60', 'A41279910_80', 'A41279911_130', 'A41279911_60',
#        'A41279911_80', 'A41279912_100', 'A41279912_130', 'A41279912_170',
#        'A41279912_60', 'A41279912_80', 'A41279924_100', 'A41279924_130',
#        'A41279924_170'], dtype=object)

# %% [markdown]
# df_A10024240_100를 테스트 데이터로 선택

# %%
gizun_code_area = df[df['apart_code_area'].str.contains(gizun_code)]['apart_code_area'].iloc[0]
gizun_df = globals()['df_'+gizun_code_area]

# %%
from sklearn import preprocessing
from sklearn.metrics import mean_squared_error
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, LSTM
from tensorflow import keras
import numpy as np
from numpy import concatenate
scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
  n_vars = 1 if type(data) is list else data.shape[1]
  df = pd.DataFrame(data)
  cols, names = list(), list()
  # input sequence (t-n, ... t-1)
  for i in range(n_in, 0, -1):
      cols.append(df.shift(i))
      names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
  # forecast sequence (t, t+1, ... t+n)
  for i in range(0, n_out):
      cols.append(df.shift(-i))
      if i == 0:
          names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
      else:
          names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
  # put it all together
  agg = pd.concat(cols, axis=1)
  agg.columns = names
  # drop rows with NaN values
  if dropnan:
      agg.dropna(inplace=True)
  return agg

# %% [markdown]
# 행 변환하기

# %%
df.dtypes
# Out:
# apart_code_area     object
# resident_count     float64
# sale_type           object
# YYYYMM               int64
# area_m3            float64
# floor                int64
# parking            float64
# crime_rate         float64
# building_year        int64
# market_dist        float64
# busstop_dist       float64
# subway_dist        float64
# school_dist        float64
# kinder_dist        float64
# hospital_dist      float64
# ASPI               float64
# YYYY                 int64
# MM                   int64
# HAI                float64
# PIR                float64
# LIR                float64
# GDP                float64
# GDI                float64
# GNI                float64
# CPI                float64
# avg_interest       float64
# cospi               object
# M2                 float64
# house_CCSI         float64
# unsold             float64
# prices             float64
# dtype: object

# %%
df_all = pd.DataFrame()
#코드에서 해당 아파트 제거
deleted_code = 'df_'+gizun_code_area
codes = np.delete(codes, np.where(codes == deleted_code))
for i in codes:
    df1 = globals()['df_'+i]
    df1 = df1[['resident_count','sale_type',
    'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
    'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
    'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
    'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
    'house_CCSI', 'unsold', 'sale_type','prices']]
    values = df1.values
    values = values.astype('float32')
    reframed = series_to_supervised(values, 3, 1)
    reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
    reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
    reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
    df_all = pd.concat([reframed,df_all])

# %%
df_all
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4    81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5    74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6    73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7    67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..            ...            ...            ...      ...      ...       ...
# 7   109800.000000  102000.000000  110200.000000   1305.0      1.0  202108.0
# 8   102000.000000  110200.000000  109500.000000   1305.0      1.0  202109.0
# 9   110200.000000  109500.000000  108000.000000   1305.0      1.0  202110.0
# 10  109500.000000  108000.000000  112300.000000   1305.0      1.0  202111.0
# 11  108000.000000  112300.000000  107000.000000   1305.0      1.0  202202.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 7      60.0      8.0   1407.0  0.710015  ...  466346.00000  471235.40625
# 8      60.0      3.0   1407.0  0.710015  ...  466346.00000  471235.40625
# 9      60.0      7.0   1407.0  0.710015  ...  487122.00000  492461.09375
# 10     60.0      5.0   1407.0  0.710015  ...  487122.00000  492461.09375
# 11     60.0     14.0   1407.0  0.710015  ...  450242.18750  455546.68750
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 7   102.750000      2.87  3199.270020  3487634.000  135.100006      55.0
# 8   103.169998      2.96  3068.820068  3513680.500  131.800003      55.0
# 9   103.349998      3.07  2970.679932  3543363.750  120.599998      55.0
# 10  103.870003      3.23  2839.010010  3594723.250  111.599998      54.0
# 11  105.300003      3.51  2699.179932  3656135.750  103.400002      47.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 7        1.0  109500.000000
# 8        1.0  108000.000000
# 9        1.0  112300.000000
# 10       1.0  107000.000000
# 11       1.0  107000.000000
#
# [1483 rows x 34 columns]

# %%
train_set = df_all[df_all['var3(t)']<202000]

# %%
df_test = gizun_df
df_test = df_test[['resident_count','sale_type',
'YYYYMM','area_m3','floor','parking','crime_rate', 'building_year',
'market_dist', 'busstop_dist', 'subway_dist', 'school_dist',
'kinder_dist', 'hospital_dist', 'ASPI', 'YYYY', 'MM', 'HAI', 'PIR',
'LIR', 'GDP', 'GDI', 'GNI', 'CPI', 'avg_interest', 'cospi', 'M2',
'house_CCSI', 'unsold', 'sale_type','prices']]
values = df_test.values
values = values.astype('float32')
reframed = series_to_supervised(values, 3, 1)
reframed.drop(reframed.columns[62:92], axis=1, inplace=True)
reframed.drop(reframed.columns[31:61], axis=1, inplace=True)
reframed.drop(reframed.columns[0:30], axis=1, inplace=True)
test_set = reframed[reframed['var3(t)']>=202000]

# %%
df_set = pd.concat([train_set,test_set])
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4    81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5    74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6    73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7    67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..            ...            ...            ...      ...      ...       ...
# 50   79500.000000   84000.000000   90000.000000    571.0      0.0  202010.0
# 51   84000.000000   90000.000000   98000.000000    571.0      0.0  202105.0
# 52   90000.000000   98000.000000  110000.000000    571.0      0.0  202106.0
# 53   98000.000000  110000.000000  114000.000000    571.0      0.0  202107.0
# 54  110000.000000  114000.000000  115000.000000    571.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 50    100.0     12.0   1119.0  0.710015  ...  480138.68750  486940.59375
# 51    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 52    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 53    100.0      9.0   1119.0  0.710015  ...  466346.00000  471235.40625
# 54    100.0     14.0   1119.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 50  100.180000      2.66  2267.149902  3152811.500  132.000000      52.0
# 51  102.050003      2.72  3203.919922  3379754.000  127.500000      71.0
# 52  102.050003      2.77  3296.679932  3413899.750  131.300003      65.0
# 53  102.260002      2.77  3202.320068  3445243.000  133.300003      59.0
# 54  102.750000      2.87  3199.270020  3487634.000  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 50       0.0   98000.000000
# 51       0.0  110000.000000
# 52       0.0  114000.000000
# 53       0.0  115000.000000
# 54       0.0  129000.000000
#
# [1264 rows x 34 columns]

# %%
test_set
# Out:
#     var31(t-3)  var31(t-2)  var31(t-1)  var1(t)  var2(t)   var3(t)  var4(t)  \
# 49     84000.0     79500.0     84000.0    571.0      0.0  202008.0    100.0
# 50     79500.0     84000.0     90000.0    571.0      0.0  202010.0    100.0
# 51     84000.0     90000.0     98000.0    571.0      0.0  202105.0    100.0
# 52     90000.0     98000.0    110000.0    571.0      0.0  202106.0    100.0
# 53     98000.0    110000.0    114000.0    571.0      0.0  202107.0    100.0
# 54    110000.0    114000.0    115000.0    571.0      0.0  202108.0    100.0
#
#     var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)    var24(t)  \
# 49     12.0   1119.0  0.710015  ...  454712.90625  458855.50000  100.190002
# 50     12.0   1119.0  0.710015  ...  480138.68750  486940.59375  100.180000
# 51      9.0   1119.0  0.710015  ...  467060.31250  470984.90625  102.050003
# 52      9.0   1119.0  0.710015  ...  467060.31250  470984.90625  102.050003
# 53      9.0   1119.0  0.710015  ...  466346.00000  471235.40625  102.260002
# 54     14.0   1119.0  0.710015  ...  466346.00000  471235.40625  102.750000
#
#     var25(t)     var26(t)    var27(t)    var28(t)  var29(t)  var30(t)  \
# 49      2.63  2326.169922  3100373.50  127.699997      56.0       0.0
# 50      2.66  2267.149902  3152811.50  132.000000      52.0       0.0
# 51      2.72  3203.919922  3379754.00  127.500000      71.0       0.0
# 52      2.77  3296.679932  3413899.75  131.300003      65.0       0.0
# 53      2.77  3202.320068  3445243.00  133.300003      59.0       0.0
# 54      2.87  3199.270020  3487634.00  135.100006      55.0       0.0
#
#     var31(t)
# 49   90000.0
# 50   98000.0
# 51  110000.0
# 52  114000.0
# 53  115000.0
# 54  129000.0
#
# [6 rows x 34 columns]

# %% [markdown]
# test

# %%
df_set
# Out:
#        var31(t-3)     var31(t-2)     var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3    78008.000000   81027.000000   74729.500000    571.0      0.0  201207.0
# 4    81027.000000   74729.500000   73718.000000    571.0      0.0  201211.0
# 5    74729.500000   73718.000000   67214.664062    571.0      0.0  201212.0
# 6    73718.000000   67214.664062   66197.335938    571.0      0.0  201301.0
# 7    67214.664062   66197.335938   67502.000000    571.0      0.0  201303.0
# ..            ...            ...            ...      ...      ...       ...
# 50   79500.000000   84000.000000   90000.000000    571.0      0.0  202010.0
# 51   84000.000000   90000.000000   98000.000000    571.0      0.0  202105.0
# 52   90000.000000   98000.000000  110000.000000    571.0      0.0  202106.0
# 53   98000.000000  110000.000000  114000.000000    571.0      0.0  202107.0
# 54  110000.000000  114000.000000  115000.000000    571.0      0.0  202108.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 50    100.0     12.0   1119.0  0.710015  ...  480138.68750  486940.59375
# 51    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 52    100.0      9.0   1119.0  0.710015  ...  467060.31250  470984.90625
# 53    100.0      9.0   1119.0  0.710015  ...  466346.00000  471235.40625
# 54    100.0     14.0   1119.0  0.710015  ...  466346.00000  471235.40625
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 50  100.180000      2.66  2267.149902  3152811.500  132.000000      52.0
# 51  102.050003      2.72  3203.919922  3379754.000  127.500000      71.0
# 52  102.050003      2.77  3296.679932  3413899.750  131.300003      65.0
# 53  102.260002      2.77  3202.320068  3445243.000  133.300003      59.0
# 54  102.750000      2.87  3199.270020  3487634.000  135.100006      55.0
#
#     var30(t)       var31(t)
# 3        0.0   73718.000000
# 4        0.0   67214.664062
# 5        0.0   66197.335938
# 6        0.0   67502.000000
# 7        0.0   67592.000000
# ..       ...            ...
# 50       0.0   98000.000000
# 51       0.0  110000.000000
# 52       0.0  114000.000000
# 53       0.0  115000.000000
# 54       0.0  129000.000000
#
# [1264 rows x 34 columns]

# %%
train_days =  len(train_set)
df_set[:train_days]
# Out:
#       var31(t-3)    var31(t-2)    var31(t-1)  var1(t)  var2(t)   var3(t)  \
# 3   78008.000000  81027.000000  74729.500000    571.0      0.0  201207.0
# 4   81027.000000  74729.500000  73718.000000    571.0      0.0  201211.0
# 5   74729.500000  73718.000000  67214.664062    571.0      0.0  201212.0
# 6   73718.000000  67214.664062  66197.335938    571.0      0.0  201301.0
# 7   67214.664062  66197.335938  67502.000000    571.0      0.0  201303.0
# ..           ...           ...           ...      ...      ...       ...
# 19  54250.000000  60000.000000  58100.000000    603.0      0.0  201707.0
# 20  60000.000000  58100.000000  60500.000000    603.0      0.0  201807.0
# 21  58100.000000  60500.000000  61000.000000    603.0      0.0  201808.0
# 22  60500.000000  61000.000000  72811.109375    603.0      0.0  201809.0
# 23  61000.000000  72811.109375  77000.000000    603.0      0.0  201904.0
#
#     var4(t)  var5(t)  var6(t)   var7(t)  ...      var22(t)      var23(t)  \
# 3     170.0      3.0   1119.0  0.710015  ...  361011.40625  364909.68750
# 4     170.0      8.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 5     170.0      4.0   1119.0  0.710015  ...  380150.09375  383998.90625
# 6     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# 7     170.0      6.0   1119.0  0.710015  ...  353728.00000  355674.09375
# ..      ...      ...      ...       ...  ...           ...           ...
# 19    110.0      5.0    680.0  0.710015  ...  451035.18750  455636.81250
# 20    110.0      2.0    680.0  0.710015  ...  452819.18750  456622.68750
# 21    110.0      6.0    680.0  0.710015  ...  452819.18750  456622.68750
# 22    110.0      6.0    680.0  0.710015  ...  452819.18750  456622.68750
# 23    110.0      5.0    680.0  0.710015  ...  451884.50000  451681.31250
#
#       var24(t)  var25(t)     var26(t)     var27(t)    var28(t)  var29(t)  \
# 3    91.431999      5.45  1881.989990  1807289.250   97.800003    3146.0
# 4    92.011002      4.94  1932.900024  1830280.250  104.099998    3594.0
# 5    92.175003      4.84  1984.800049  1835556.750  101.400002    3481.0
# 6    92.727997      5.00  1961.900024  1841128.125  109.800003    3415.0
# 7    92.952003      4.77  2004.900024  1862405.500  114.599998    3168.0
# ..         ...       ...          ...          ...         ...       ...
# 19   97.499001      3.45  2402.709961  2472110.500  127.599998      41.0
# 20   98.589996      3.67  2295.260010  2637421.750  102.800003      42.0
# 21   99.461998      3.63  2322.879883  2651503.500  115.900002      39.0
# 22  100.221001      3.61  2343.070068  2652829.500  119.300003      29.0
# 23   99.481003      3.65  2203.590088  2763058.000   89.599998     292.0
#
#     var30(t)      var31(t)
# 3        0.0  73718.000000
# 4        0.0  67214.664062
# 5        0.0  66197.335938
# 6        0.0  67502.000000
# 7        0.0  67592.000000
# ..       ...           ...
# 19       0.0  60500.000000
# 20       0.0  61000.000000
# 21       0.0  72811.109375
# 22       0.0  77000.000000
# 23       0.0  72000.000000
#
# [1258 rows x 34 columns]

# %%
values=df_set.values
values.shape
# Out:
# (1264, 34)

# %%
values
# Out:
# array([[7.8008000e+04, 8.1027000e+04, 7.4729500e+04, ..., 3.1460000e+03,
#         0.0000000e+00, 7.3718000e+04],
#        [8.1027000e+04, 7.4729500e+04, 7.3718000e+04, ..., 3.5940000e+03,
#         0.0000000e+00, 6.7214664e+04],
#        [7.4729500e+04, 7.3718000e+04, 6.7214664e+04, ..., 3.4810000e+03,
#         0.0000000e+00, 6.6197336e+04],
#        ...,
#        [9.0000000e+04, 9.8000000e+04, 1.1000000e+05, ..., 6.5000000e+01,
#         0.0000000e+00, 1.1400000e+05],
#        [9.8000000e+04, 1.1000000e+05, 1.1400000e+05, ..., 5.9000000e+01,
#         0.0000000e+00, 1.1500000e+05],
#        [1.1000000e+05, 1.1400000e+05, 1.1500000e+05, ..., 5.5000000e+01,
#         0.0000000e+00, 1.2900000e+05]], dtype=float32)

# %%
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days]
test = values[train_days:]

# %%
test.shape
# Out:
# (6, 34)

# %%
values=df_set.values
scaled = scaler.fit_transform(values)
values = scaled
train_days =  len(train_set) #테스트 데이터 얼마나 사용할 건지
train = values[:train_days, :]
test = values[train_days:, :]

# %%
test
# Out:
# array([[0.7075366 , 0.62863296, 0.66986156, 0.        , 0.        ,
#         0.8893738 , 0.36363637, 0.57894737, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.9007633 , 0.9234694 , 0.7804413 , 0.7988639 ,
#         0.7860451 , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        , 0.6385542 ],
#        [0.65691787, 0.6770721 , 0.73375934, 0.        , 0.        ,
#         0.8915863 , 0.36363637, 0.57894737, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.6942791 , 0.8888855 , 0.8181819 ,
#         0.1742487 , 1.        , 0.9183675 , 1.0000002 , 1.0000002 ,
#         1.        , 0.7729273 , 0.00974023, 0.29154766, 0.8042568 ,
#         0.82330084, 0.00580855, 0.        , 0.7126969 ],
#        [0.7075366 , 0.7416577 , 0.8189564 , 0.        , 0.        ,
#         0.9966736 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.8955189 , 1.        , 0.36363637,
#         0.0268203 , 0.8778622 , 0.93877566, 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.02922076, 0.9361688 , 0.9369314 ,
#         0.73592234, 0.01022305, 0.        , 0.8239111 ],
#        [0.7750281 , 0.82777184, 0.94675183, 0.        , 0.        ,
#         0.9977875 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8625951 , 0.9030613 , 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        , 0.8609824 ],
#        [0.86501694, 0.956943  , 0.98935044, 0.        , 0.        ,
#         0.9988861 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.94274783, 0.9234694 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        , 0.8702502 ],
#        [1.        , 1.        , 1.        , 0.        , 0.        ,
#         1.        , 0.36363637, 0.68421054, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.9732821 , 1.0000001 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        , 1.        ]], dtype=float32)

# %%
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
# reshape input to be 3D [samples, timesteps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
train_y
# Out:
# array([0.4876552 , 0.42738333, 0.4179549 , ..., 0.47925028, 0.51807225,
#        0.47173306], dtype=float32)

# %%
test_y
# Out:
# array([0.6385542, 0.7126969, 0.8239111, 0.8609824, 0.8702502, 1.       ],
#       dtype=float32)

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(train_X, train_y, epochs=50, batch_size=72, 
        validation_data=(test_X, test_y), verbose=2, shuffle=False)
# Out:
# Epoch 1/50
# 18/18 - 5s - loss: 0.1457 - val_loss: 0.1579 - 5s/epoch - 300ms/step
# Epoch 2/50
# 18/18 - 0s - loss: 0.0692 - val_loss: 0.2059 - 108ms/epoch - 6ms/step
# Epoch 3/50
# 18/18 - 0s - loss: 0.0593 - val_loss: 0.1321 - 150ms/epoch - 8ms/step
# Epoch 4/50
# 18/18 - 0s - loss: 0.0469 - val_loss: 0.0514 - 228ms/epoch - 13ms/step
# Epoch 5/50
# 18/18 - 0s - loss: 0.0437 - val_loss: 0.0303 - 164ms/epoch - 9ms/step
# Epoch 6/50
# 18/18 - 0s - loss: 0.0531 - val_loss: 0.0394 - 136ms/epoch - 8ms/step
# Epoch 7/50
# 18/18 - 0s - loss: 0.0521 - val_loss: 0.1006 - 159ms/epoch - 9ms/step
# Epoch 8/50
# 18/18 - 0s - loss: 0.0433 - val_loss: 0.1160 - 151ms/epoch - 8ms/step
# Epoch 9/50
# 18/18 - 0s - loss: 0.0336 - val_loss: 0.0724 - 148ms/epoch - 8ms/step
# Epoch 10/50
# 18/18 - 0s - loss: 0.0326 - val_loss: 0.0579 - 214ms/epoch - 12ms/step
# Epoch 11/50
# 18/18 - 0s - loss: 0.0383 - val_loss: 0.0305 - 173ms/epoch - 10ms/step
# Epoch 12/50
# 18/18 - 0s - loss: 0.0538 - val_loss: 0.0825 - 155ms/epoch - 9ms/step
# Epoch 13/50
# 18/18 - 0s - loss: 0.0456 - val_loss: 0.1340 - 173ms/epoch - 10ms/step
# Epoch 14/50
# 18/18 - 0s - loss: 0.0437 - val_loss: 0.0975 - 159ms/epoch - 9ms/step
# Epoch 15/50
# 18/18 - 0s - loss: 0.0288 - val_loss: 0.0706 - 147ms/epoch - 8ms/step
# Epoch 16/50
# 18/18 - 0s - loss: 0.0427 - val_loss: 0.0336 - 174ms/epoch - 10ms/step
# Epoch 17/50
# 18/18 - 0s - loss: 0.0569 - val_loss: 0.1292 - 145ms/epoch - 8ms/step
# Epoch 18/50
# 18/18 - 0s - loss: 0.0405 - val_loss: 0.1341 - 139ms/epoch - 8ms/step
# Epoch 19/50
# 18/18 - 0s - loss: 0.0346 - val_loss: 0.0864 - 171ms/epoch - 9ms/step
# Epoch 20/50
# 18/18 - 0s - loss: 0.0279 - val_loss: 0.0633 - 149ms/epoch - 8ms/step
# Epoch 21/50
# 18/18 - 0s - loss: 0.0365 - val_loss: 0.0532 - 159ms/epoch - 9ms/step
# Epoch 22/50
# 18/18 - 0s - loss: 0.0458 - val_loss: 0.1185 - 150ms/epoch - 8ms/step
# Epoch 23/50
# 18/18 - 0s - loss: 0.0373 - val_loss: 0.1317 - 123ms/epoch - 7ms/step
# Epoch 24/50
# 18/18 - 0s - loss: 0.0322 - val_loss: 0.0868 - 130ms/epoch - 7ms/step
# Epoch 25/50
# 18/18 - 0s - loss: 0.0272 - val_loss: 0.0673 - 131ms/epoch - 7ms/step
# Epoch 26/50
# 18/18 - 0s - loss: 0.0351 - val_loss: 0.0583 - 119ms/epoch - 7ms/step
# Epoch 27/50
# 18/18 - 0s - loss: 0.0435 - val_loss: 0.1223 - 124ms/epoch - 7ms/step
# Epoch 28/50
# 18/18 - 0s - loss: 0.0354 - val_loss: 0.1323 - 118ms/epoch - 7ms/step
# Epoch 29/50
# 18/18 - 0s - loss: 0.0309 - val_loss: 0.0907 - 116ms/epoch - 6ms/step
# Epoch 30/50
# 18/18 - 0s - loss: 0.0265 - val_loss: 0.0671 - 128ms/epoch - 7ms/step
# Epoch 31/50
# 18/18 - 0s - loss: 0.0350 - val_loss: 0.0574 - 134ms/epoch - 7ms/step
# Epoch 32/50
# 18/18 - 0s - loss: 0.0419 - val_loss: 0.1213 - 121ms/epoch - 7ms/step
# Epoch 33/50
# 18/18 - 0s - loss: 0.0337 - val_loss: 0.1317 - 133ms/epoch - 7ms/step
# Epoch 34/50
# 18/18 - 0s - loss: 0.0300 - val_loss: 0.0904 - 133ms/epoch - 7ms/step
# Epoch 35/50
# 18/18 - 0s - loss: 0.0266 - val_loss: 0.0657 - 123ms/epoch - 7ms/step
# Epoch 36/50
# 18/18 - 0s - loss: 0.0344 - val_loss: 0.0612 - 131ms/epoch - 7ms/step
# Epoch 37/50
# 18/18 - 0s - loss: 0.0402 - val_loss: 0.1247 - 126ms/epoch - 7ms/step
# Epoch 38/50
# 18/18 - 0s - loss: 0.0321 - val_loss: 0.1264 - 121ms/epoch - 7ms/step
# Epoch 39/50
# 18/18 - 0s - loss: 0.0282 - val_loss: 0.0860 - 124ms/epoch - 7ms/step
# Epoch 40/50
# 18/18 - 0s - loss: 0.0262 - val_loss: 0.0659 - 126ms/epoch - 7ms/step
# Epoch 41/50
# 18/18 - 0s - loss: 0.0323 - val_loss: 0.0646 - 123ms/epoch - 7ms/step
# Epoch 42/50
# 18/18 - 0s - loss: 0.0375 - val_loss: 0.1172 - 122ms/epoch - 7ms/step
# Epoch 43/50
# 18/18 - 0s - loss: 0.0311 - val_loss: 0.1255 - 123ms/epoch - 7ms/step
# Epoch 44/50
# 18/18 - 0s - loss: 0.0278 - val_loss: 0.0902 - 129ms/epoch - 7ms/step
# Epoch 45/50
# 18/18 - 0s - loss: 0.0255 - val_loss: 0.0704 - 127ms/epoch - 7ms/step
# Epoch 46/50
# 18/18 - 0s - loss: 0.0321 - val_loss: 0.0627 - 128ms/epoch - 7ms/step
# Epoch 47/50
# 18/18 - 0s - loss: 0.0369 - val_loss: 0.1149 - 121ms/epoch - 7ms/step
# Epoch 48/50
# 18/18 - 0s - loss: 0.0301 - val_loss: 0.1237 - 123ms/epoch - 7ms/step
# Epoch 49/50
# 18/18 - 0s - loss: 0.0272 - val_loss: 0.0926 - 134ms/epoch - 7ms/step
# Epoch 50/50
# 18/18 - 0s - loss: 0.0256 - val_loss: 0.0700 - 127ms/epoch - 7ms/step

# %%
# make a prediction
yhat = model.predict(test_X)
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
test_X.shape
# Out:
# (6, 33)

# %%
yhat
# Out:
# array([[0.62500775],
#        [0.64843696],
#        [0.7334838 ],
#        [0.7878121 ],
#        [0.82253844],
#        [0.86929065]], dtype=float32)

# %%
test_X
# Out:
# array([[0.7075366 , 0.62863296, 0.66986156, 0.        , 0.        ,
#         0.8893738 , 0.36363637, 0.57894737, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.6388198 , 0.8888855 , 0.6363636 ,
#         0.2173593 , 0.9007633 , 0.9234694 , 0.7804413 , 0.7988639 ,
#         0.7860451 , 0.77381134, 0.        , 0.3321612 , 0.7736006 ,
#         0.7398057 , 0.00673792, 0.        ],
#        [0.65691787, 0.6770721 , 0.73375934, 0.        , 0.        ,
#         0.8915863 , 0.36363637, 0.57894737, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.6942791 , 0.8888855 , 0.8181819 ,
#         0.1742487 , 1.        , 0.9183675 , 1.0000002 , 1.0000002 ,
#         1.        , 0.7729273 , 0.00974023, 0.29154766, 0.8042568 ,
#         0.82330084, 0.00580855, 0.        ],
#        [0.7075366 , 0.7416577 , 0.8189564 , 0.        , 0.        ,
#         0.9966736 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.8955189 , 1.        , 0.36363637,
#         0.0268203 , 0.8778622 , 0.93877566, 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.02922076, 0.9361688 , 0.9369314 ,
#         0.73592234, 0.01022305, 0.        ],
#        [0.7750281 , 0.82777184, 0.94675183, 0.        , 0.        ,
#         0.9977875 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.93318164, 1.        , 0.45454547,
#         0.        , 0.8625951 , 0.9030613 , 0.9390428 , 0.89654064,
#         0.878448  , 0.93815136, 0.0454545 , 0.9999999 , 0.95689356,
#         0.8097086 , 0.008829  , 0.        ],
#        [0.86501694, 0.956943  , 0.98935044, 0.        , 0.        ,
#         0.9988861 , 0.36363637, 0.42105263, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 0.9627656 , 1.        , 0.5454545 ,
#         0.11928046, 0.94274783, 0.9234694 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 0.95670605, 0.0454545 , 0.935068  , 0.97521746,
#         0.84854364, 0.00743494, 0.        ],
#        [1.        , 1.        , 1.        , 0.        , 0.        ,
#         1.        , 0.36363637, 0.68421054, 0.9046079 , 0.        ,
#         1.        , 1.        , 0.17754662, 0.9999999 , 0.48381335,
#         0.73960245, 0.99999994, 1.0000001 , 1.        , 0.6363636 ,
#         0.08087826, 0.9732821 , 1.0000001 , 0.9383924 , 0.8908901 ,
#         0.8803563 , 1.        , 0.07792199, 0.9329692 , 0.9999999 ,
#         0.8834951 , 0.00650558, 0.        ]], dtype=float32)

# %%
# invert scaling for forecast
inv_yhat = concatenate((test_X[:, 0:],yhat), axis=1)

# %%
inv_yhat.shape
# Out:
# (6, 34)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)

# %%
inv_yhat = inv_yhat[:,-1]
inv_yhat
# Out:
# array([ 88538.336,  91066.35 , 100242.9  , 106104.93 , 109851.91 ,
#        114896.47 ], dtype=float32)

# %%
# invert scaling for actual
test_y = test_y.reshape((len(test_y), 1))
inv_y = concatenate((test_X[:, 0:],test_y), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,-1]
# calculate RMSE

# %%
inv_y
# Out:
# array([ 90000.  ,  98000.  , 110000.01, 114000.01, 115000.  , 129000.  ],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.plot(inv_y)
plt.plot(inv_yhat)
plt.show()

# %%
#실제값
inv_y
# Out:
# array([ 90000.  ,  98000.  , 110000.01, 114000.01, 115000.  , 129000.  ],
#       dtype=float32)

# %%
#예측치
inv_yhat
# Out:
# array([ 88538.336,  91066.35 , 100242.9  , 106104.93 , 109851.91 ,
#        114896.47 ], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
RMSE = mean_squared_error(inv_y, inv_yhat)**0.5

# %%
RMSE
# Out:
# 8496.644514159692
