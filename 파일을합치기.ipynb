# %%
import numpy as np
import pandas as pd
#파일 열기
df_time_price = pd.read_csv('시계열자료.csv')
gizun = pd.read_csv("정리220805.csv")
area_df = pd.read_csv('지역자료.csv')
#파일 결합
#gizun1 = pd.merge(gizun, df_time_price, on = '아파트코드', how = 'left')
# Out:
# C:\Users\46861\AppData\Local\Temp\ipykernel_5112\4216326980.py:5: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   gizun = pd.read_csv("정리220805.csv")

# %%
pd.read_csv('시계열자료.csv')
# Out:
#         Unnamed: 0      아파트코드    계약년월      거래금액(만원)  아파트매매가격지수  년도   월  \
# 0                0  A10023858  201312  25900.000000        NaN NaN NaN
# 1                1  A10023858  201506  30000.000000        NaN NaN NaN
# 2                2  A10023858  201603  35000.000000        NaN NaN NaN
# 3                3  A10023858  201604  34000.000000        NaN NaN NaN
# 4                4  A10023858  201611  36500.000000        NaN NaN NaN
# ...            ...        ...     ...           ...        ...  ..  ..
# 169560      169560  B15281101  202012  32000.000000        NaN NaN NaN
# 169561      169561  B15281101  202101  24000.000000        NaN NaN NaN
# 169562      169562  B15281101  202104  22000.000000        NaN NaN NaN
# 169563      169563  B15281101  202108  35766.666667        NaN NaN NaN
# 169564      169564  B15281101  202111  31000.000000        NaN NaN NaN
#
#         주택구매력지수  PIR  LIR
# 0           NaN  NaN  NaN
# 1           NaN  NaN  NaN
# 2           NaN  NaN  NaN
# ...

# %%
print(gizun)
# Out:
#             아파트코드             단지명            시군구 주소.읍면동.          kapt도로명주소  \
# 0       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 1       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 2       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 3       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 4       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# ...           ...             ...            ...     ...                ...
# 725063  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725064  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725065  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725066  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725067  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
#
# ...

# %%
print(area_df)
# Out:
#      Unnamed: 0                         행정구역  201201  201202  201203  201204  \
# 0             0  서울특별시 종로구 청운효자동(1111051500)  14,933  14,943  14,870  14,830
# 1             1    서울특별시 종로구 사직동(1111053000)   9,759   9,758   9,745   9,721
# 2             2    서울특별시 종로구 삼청동(1111054000)   3,263   3,251   3,214   3,215
# 3             3    서울특별시 종로구 부암동(1111055000)  11,000  10,967  10,974  10,934
# 4             4    서울특별시 종로구 평창동(1111056000)  19,375  19,406  19,435  19,414
# ..          ...                          ...     ...     ...     ...     ...
# 406         406  서울특별시 강동구 성내제2동(1174065000)  26,300  26,357  26,385  26,359
# 407         407  서울특별시 강동구 성내제3동(1174066000)  25,000  24,994  24,924  24,934
# 408         408     서울특별시 강동구 길동(1174068500)  50,558  50,566  50,518  50,478
# 409         409  서울특별시 강동구 둔촌제1동(1174069000)  20,026  20,087  19,999  20,031
# 410         410  서울특별시 강동구 둔촌제2동(1174070000)  29,312  29,401  29,379  29,256
#
# ...

# %%
gizun
# Out:
#             아파트코드             단지명            시군구 주소.읍면동.          kapt도로명주소  \
# 0       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 1       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 2       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 3       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# 4       A13524004          개포우성3차  서울특별시 강남구 개포동     개포동  서울특별시 강남구 개포로 307
# ...           ...             ...            ...     ...                ...
# 725063  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725064  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725065  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725066  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
# 725067  A13187702  한신아파트(103~109)  서울특별시 중랑구 중화동     중화동  서울특별시 중랑구 동일로 752
#
# ...

# %%
gizun['아파트코드'][0]
# Out:
# 'A13524004'

# %%
gizun = gizun.astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\파일을합치기.ipynb 셀 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> gizun = gizun.astype('float')
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# ...

# %%
gizun['인구수']=0
for i in gizun.index:
    gizun['인구수'][i] = area_df[area_df.filter(regex=gizun['계약년월'][i])][area_df['동']==gizun['주소.읍면동.'][i]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\파일을합치기.ipynb 셀 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> gizun['인구수']=0
#       <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#X25sZmlsZQ%3D%3D?line=1'>2</a> for i in gizun.index:
# ...

# %%
gizun['인구수'] = area_df[area_df.filter(regex=gizun['계약년월'])][area_df['동']==gizun['주소.읍면동.']]
gizun
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\파일을합치기.ipynb 셀 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> gizun['인구수'] = area_df[area_df.filter(regex=gizun['계약년월'])][area_df['동']==gizun['주소.읍면동.']]
# ...

# %%
area_df.filter(regex=gizun['계약년월'])

# %%
gizun.keys()
# Out:
# Index(['아파트코드', '단지명', '시군구', '주소.읍면동.', 'kapt도로명주소', '세대타입.분양형태.', '전용면적(㎡)',
#        '계약년월', '층', '건축년도', '주차대수', '좌표X', '좌표Y', '범죄율', '건물연식', '대규모점포_거리',
#        '버스정류장_거리', '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '거래금액(만원)'],
#       dtype='object')

# %%
gizun2 = gizun[['아파트코드', '단지명','kapt도로명주소','전용면적(㎡)','계약년월', '주차대수', '범죄율', '건물연식','대규모점포_거리',
       '버스정류장_거리', '지하철역_거리', '학교_거리', '유치원_거리', '병원_거리', '거래금액(만원)']]

# %%
gizun2
# Out:
#             아파트코드             단지명          kapt도로명주소  전용면적(㎡)      계약년월  \
# 0       A13524004          개포우성3차  서울특별시 강남구 개포로 307   133.46  201608.0
# 1       A13524004          개포우성3차  서울특별시 강남구 개포로 307   104.43  201611.0
# 2       A13524004          개포우성3차  서울특별시 강남구 개포로 307   133.46  201611.0
# 3       A13524004          개포우성3차  서울특별시 강남구 개포로 307   133.46  201612.0
# 4       A13524004          개포우성3차  서울특별시 강남구 개포로 307   161.00  201702.0
# ...           ...             ...                ...      ...       ...
# 725063  A13187702  한신아파트(103~109)  서울특별시 중랑구 동일로 752    84.87  201512.0
# 725064  A13187702  한신아파트(103~109)  서울특별시 중랑구 동일로 752    59.76  201512.0
# 725065  A13187702  한신아파트(103~109)  서울특별시 중랑구 동일로 752    84.03  201512.0
# 725066  A13187702  한신아파트(103~109)  서울특별시 중랑구 동일로 752    50.37  201512.0
# 725067  A13187702  한신아파트(103~109)  서울특별시 중랑구 동일로 752    50.37  201512.0
#
#           주차대수       범죄율  건물연식  대규모점포_거리  버스정류장_거리   지하철역_거리     학교_거리  \
# ...

# %%
gizun
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\파일을합치기.ipynb 셀 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> gizun
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\IPython\core\displayhook.py:262, in DisplayHook.__call__(self, result)
#     260 self.start_displayhook()
#     261 self.write_output_prompt()
# --> 262 format_dict, md_dict = self.compute_format_data(result)
#     263 self.update_user_ns(result)
#     264 self.fill_exec_result(result)
#
# ...

# %%
gizun3= gizun2.astype(dtype='object')

# %%
df_time_price.dtypes
# Out:
# Unnamed: 0      int64
# 아파트코드          object
# 계약년월            int64
# 거래금액(만원)      float64
# 아파트매매가격지수     float64
# 년도            float64
# 월             float64
# 주택구매력지수       float64
# PIR           float64
# LIR           float64
# dtype: object

# %%
gizun4 = pd.merge(gizun3, df_time_price, on = '아파트코드', how = 'right')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\파일을합치기.ipynb 셀 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> gizun4 = pd.merge(gizun3, df_time_price, on = '아파트코드', how = 'right')
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
# ...
