# %%
import pandas as pd

# %%
df = pd.read_csv('final4_english.csv')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\46861\OneDrive\Desktop\부동산예측데이터\파일 합치기\파일을합치기\house-priec-predict\파일준비\파일합치기.ipynb 셀 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/46861/OneDrive/Desktop/%EB%B6%80%EB%8F%99%EC%82%B0%EC%98%88%EC%B8%A1%EB%8D%B0%EC%9D%B4%ED%84%B0/%ED%8C%8C%EC%9D%BC%20%ED%95%A9%EC%B9%98%EA%B8%B0/%ED%8C%8C%EC%9D%BC%EC%9D%84%ED%95%A9%EC%B9%98%EA%B8%B0/house-priec-predict/%ED%8C%8C%EC%9D%BC%EC%A4%80%EB%B9%84/%ED%8C%8C%EC%9D%BC%ED%95%A9%EC%B9%98%EA%B8%B0.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv('final4_english.csv')
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\io\parsers\readers.py:1270, in TextFileReader.read(self, nrows)
#    1267     else:
#    1268         new_rows = len(index)
# -> 1270     df = DataFrame(col_dict, columns=columns, index=index)
#    1272     self._currow += new_rows
#    1274 if self.squeeze and len(df.columns) == 1:
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\construction.py:156, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     153 axes = [columns, index]
#     155 if typ == "block":
# --> 156     return create_block_manager_from_column_arrays(
#     157         arrays, axes, consolidate=consolidate
#     158     )
#     159 elif typ == "array":
#     160     return ArrayManager(arrays, [index, columns])
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py:1954, in create_block_manager_from_column_arrays(arrays, axes, consolidate)
#    1937 def create_block_manager_from_column_arrays(
#    1938     arrays: list[ArrayLike],
#    1939     axes: list[Index],
#    (...)
#    1950     # These last three are sufficient to allow us to safely pass
#    1951     #  verify_integrity=False below.
#    1953     try:
# -> 1954         blocks = _form_blocks(arrays, consolidate)
#    1955         mgr = BlockManager(blocks, axes, verify_integrity=False)
#    1956     except ValueError as e:
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py:2028, in _form_blocks(arrays, consolidate)
#    2025 if issubclass(dtype.type, (str, bytes)):
#    2026     dtype = np.dtype(object)
# -> 2028 values, placement = _stack_arrays(list(tup_block), dtype)
#    2029 if is_dtlike:
#    2030     values = ensure_wrapped_if_datetimelike(values)
#
# File c:\Users\46861\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py:2067, in _stack_arrays(tuples, dtype)
#    2064 first = arrays[0]
#    2065 shape = (len(arrays),) + first.shape
# -> 2067 stacked = np.empty(shape, dtype=dtype)
#    2068 for i, arr in enumerate(arrays):
#    2069     stacked[i] = arr
#
# MemoryError: Unable to allocate 38.7 MiB for an array with shape (7, 725068) and data type float64

# %%
df
# Out:
#         Unnamed: 0 apart_code  YYYYMM            apart__name        sigungu  \
# 0                1  A10024240  201201                    무지개  서울특별시 서초구 서초동
# 1                2  A10024240  201201                    무지개  서울특별시 서초구 서초동
# 2                3  A10024240  201201                    무지개  서울특별시 서초구 서초동
# 3                4  A10024240  201201                    무지개  서울특별시 서초구 서초동
# 4                5  A10024603  201201              아이파크종암동2차  서울특별시 성북구 종암동
# ...            ...        ...     ...                    ...            ...
# 725063      725064  A15776004  202207                    현대3  서울특별시 강서구 염창동
# 725064      725065  A15807701  202207                  세양청마루  서울특별시 양천구 신정동
# 725065      725066  A15882107  202207                    금호1   서울특별시 양천구 목동
# 725066      725067  A41279917  202207      은평뉴타운우물골(두산위브6단지)  서울특별시 은평구 진관동
# 725067      725068  A41279923  202207  은평뉴타운 제각말 푸르지오(5-1단지)  서울특별시 은평구 진관동
#
#        town_name                 address sale_type  area_m3  floor  ...  \
# 0            서초동       서울특별시 서초구 효령로 391     임대+분양   101.81      1  ...
# 1            서초동       서울특별시 서초구 효령로 391     임대+분양   101.10     11  ...
# 2            서초동       서울특별시 서초구 효령로 391     임대+분양    77.71      6  ...
# 3            서초동       서울특별시 서초구 효령로 391     임대+분양   101.10      3  ...
# 4            종암동      서울특별시 성북구 종암로9길 71        임대    84.73      5  ...
# ...          ...                     ...       ...      ...    ...  ...
# 725063       염창동     서울특별시 강서구 양천로75길 60        분양    59.92      1  ...
# 725064       신정동  서울특별시 양천구 목동남로2길 60-30        분양    84.98      9  ...
# 725065        목동      서울특별시 양천구 목동동로 258        분양    84.96     22  ...
# 725066       진관동     서울특별시 은평구 진관2로 57-7        분양    84.54      8  ...
# 725067       진관동     서울특별시 은평구 연서로48길 12        분양   101.83      5  ...
#
#              GDP       GDI       GNI      CPI  avg_interest    kospi  \
# 0       361724.2  343229.4  345819.5   91.242          5.79  1955.79
# 1       361724.2  343229.4  345819.5   91.242          5.79  1955.79
# 2       361724.2  343229.4  345819.5   91.242          5.79  1955.79
# 3       361724.2  343229.4  345819.5   91.242          5.79  1955.79
# 4       361724.2  343229.4  345819.5   91.242          5.79  1955.79
# ...          ...       ...       ...      ...           ...      ...
# 725063       NaN       NaN       NaN  108.740           NaN  2451.50
# 725064       NaN       NaN       NaN  108.740           NaN  2451.50
# 725065       NaN       NaN       NaN  108.740           NaN  2451.50
# 725066       NaN       NaN       NaN  108.740           NaN  2451.50
# 725067       NaN       NaN       NaN  108.740           NaN  2451.50
#
#                M2  house_CCSI  unsold  prices
# 0       1757058.7       106.0  1890.0   79000
# 1       1757058.7       106.0  1890.0   81200
# 2       1757058.7       106.0  1890.0   64000
# 3       1757058.7       106.0  1890.0   78800
# 4       1757058.7       106.0  1890.0   46000
# ...           ...         ...     ...     ...
# 725063        NaN         NaN     NaN   64600
# 725064        NaN         NaN     NaN   95000
# 725065        NaN         NaN     NaN  115000
# 725066        NaN         NaN     NaN   93000
# 725067        NaN         NaN     NaN  103000
#
# [725068 rows x 38 columns]

# %%
school = pd.read_csv('아파트코드기준 가까운 학교(초중고분리).csv')

# %%
school = school[['apart_code','초등학교까지 거리','중학교까지 거리','고등학교까지 거리']]

# %%
school.columns = ['apart_code','near_element','near_middle','near_high']

# %%
school
# Out:
#      apart_code  초등학교까지 거리  중학교까지 거리  고등학교까지 거리
# 0     A10023829   0.361849  0.757172   0.754787
# 1     A10023858   0.127345  0.215405   0.223326
# 2     A10023859   0.418859  0.652291   0.751892
# 3     A10023887   0.323371  0.697751   0.587135
# 4     A10023891   0.432172  0.586452   1.080000
# ...         ...        ...       ...        ...
# 2605  B13307002   0.228220  0.258838   0.183818
# 2606  B13385401   0.252977  1.015514   0.381064
# 2607  B13679401   0.205521  0.471987   0.285695
# 2608  B15281101   0.111526  0.195486   1.249862
# 2609  B15672601   0.409981  0.153698   1.128599
#
# [2610 rows x 4 columns]

# %%
df = pd.merge(df,school,on='apart_code',how='left')

# %%
df
